# %%
import pandas as pd
import numpy as np

# %%
df  = pd.read_csv('workouts.csv')
df.head()
# Out:
#                                                Title WorkoutType  \
# 0  Zwift - Workout of the Week | Ivan Garcia Cort...        Bike
# 1     Zwift - Tempo 15min / Target rpm #3 in Watopia        Bike
# 2                     Zwift - The Wringer in Watopia        Bike
# 3  Zwift - Pacer Group Ride: Volcano Flat in Wato...        Bike
# 4          Zwift - Climb Portal - Volcano in Watopia        Bike
#
#    WorkoutDescription  PlannedDuration  PlannedDistanceInMeters  WorkoutDay  \
# 0                 NaN              NaN                      NaN  2023-07-01
# 1                 NaN              NaN                      NaN  2023-07-02
# 2                 NaN              NaN                      NaN  2023-07-03
# 3                 NaN              NaN                      NaN  2023-07-03
# 4                 NaN              NaN                      NaN  2023-07-04
#
#    CoachComments  DistanceInMeters  PowerAverage  PowerMax  ...  \
# ...

# %%
df.shape
# Out:
# (203, 45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Title                    203 non-null    object
#  1   WorkoutType              203 non-null    object
#  2   WorkoutDescription       0 non-null      float64
#  3   PlannedDuration          0 non-null      float64
#  4   PlannedDistanceInMeters  0 non-null      float64
#  5   WorkoutDay               203 non-null    object
#  6   CoachComments            0 non-null      float64
#  7   DistanceInMeters         203 non-null    float64
#  8   PowerAverage             203 non-null    int64
#  9   PowerMax                 203 non-null    int64
#  10  Energy                   203 non-null    float64
#  11  AthleteComments          0 non-null      float64
#  12  TimeTotalInHours         203 non-null    float64
#  13  VelocityAverage          203 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['Title', 'WorkoutType', 'WorkoutDescription', 'PlannedDuration',
#        'PlannedDistanceInMeters', 'WorkoutDay', 'CoachComments',
#        'DistanceInMeters', 'PowerAverage', 'PowerMax', 'Energy',
#        'AthleteComments', 'TimeTotalInHours', 'VelocityAverage', 'VelocityMax',
#        'CadenceAverage', 'CadenceMax', 'HeartRateAverage', 'HeartRateMax',
#        'TorqueAverage', 'TorqueMax', 'IF', 'TSS', 'HRZone1Minutes',
#        'HRZone2Minutes', 'HRZone3Minutes', 'HRZone4Minutes', 'HRZone5Minutes',
#        'HRZone6Minutes', 'HRZone7Minutes', 'HRZone8Minutes', 'HRZone9Minutes',
#        'HRZone10Minutes', 'PWRZone1Minutes', 'PWRZone2Minutes',
#        'PWRZone3Minutes', 'PWRZone4Minutes', 'PWRZone5Minutes',
#        'PWRZone6Minutes', 'PWRZone7Minutes', 'PWRZone8Minutes',
#        'PWRZone9Minutes', 'PWRZone10Minutes', 'Rpe', 'Feeling'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Title                        0
# WorkoutType                  0
# WorkoutDescription         203
# PlannedDuration            203
# PlannedDistanceInMeters    203
# WorkoutDay                   0
# CoachComments              203
# DistanceInMeters             0
# PowerAverage                 0
# PowerMax                     0
# Energy                       0
# AthleteComments            203
# TimeTotalInHours             0
# VelocityAverage              0
# VelocityMax                203
# CadenceAverage               0
# CadenceMax                 203
# HeartRateAverage             0
# HeartRateMax                 0
# TorqueAverage              203
# TorqueMax                  203
# IF                           0
# TSS                          0
# HRZone1Minutes             171
# HRZone2Minutes             171
# HRZone3Minutes             171
# HRZone4Minutes             171
# HRZone5Minutes             171
# HRZone6Minutes             203
# HRZone7Minutes             203
# ...
