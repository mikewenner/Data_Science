# %%
import pandas as pd
import numpy as np

# %%
# some python lists
names = ['Olga', 'Andrew', 'Brian', 'Telulah', 'Nicole', 'Tilda']
ages = [29, 21, 45, 23, 39, 46]
married = [False, True, True, True, False, True]

# %%
# pandas series
ser = pd.Series(names, name='name')

# %%
# pandas dataframe
df = pd.DataFrame({'name': names, 'age': ages, 'married': married})
df
# Out:
#       name  age  married
# 0     Olga   29    False
# 1   Andrew   21     True
# 2    Brian   45     True
# 3  Telulah   23     True
# 4   Nicole   39    False
# 5    Tilda   46     True

# %%
#df is a 2 dimensional object (rows, columns)
df.shape
# Out:
# (6, 3)

# %%
#each column in a df is a series with its own dtype
# so you need to call .dtypes NOT dtype
df.dtypes
# Out:
# name       object
# age         int64
# married      bool
# dtype: object

# %%
# since we created 3 python lists above, we can create a df using a dict format

pd.DataFrame({'name':names, 'age': ages, 'married':married})
# Out:
#       name  age  married
# 0     Olga   29    False
# 1   Andrew   21     True
# 2    Brian   45     True
# 3  Telulah   23     True
# 4   Nicole   39    False
# 5    Tilda   46     True

# %%
# the length of all lists MUST be equal!!!

# %% [markdown]
# ## Info
# ### can only use for a df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     6 non-null      object
#  1   age      6 non-null      int64
#  2   married  6 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 230.0+ bytes

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Columns: 3 entries, name to married
# dtypes: bool(1), int64(1), object(1)
# memory usage: 230.0+ bytes

# %%
df.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     6 non-null      object
#  1   age      6 non-null      int64
#  2   married  6 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 557.0 bytes

# %% [markdown]
# ## Nutrition Data (from kaggle)
# * we will us this for exercises following

# %%
dataurl = 'https://andybek.com/pandas-nutrition'

# %%
nutrition = pd.read_csv(dataurl)
nutrition.head()
# Out:
#    Unnamed: 0             name serving_size  calories total_fat saturated_fat  \
# 0           0       Cornstarch        100 g       381      0.1g           NaN
# 1           1     Nuts, pecans        100 g       691       72g          6.2g
# 2           2    Eggplant, raw        100 g        25      0.2g           NaN
# 3           3   Teff, uncooked        100 g       367      2.4g          0.4g
# 4           4  Sherbet, orange        100 g       144        2g          1.2g
#
#   cholesterol    sodium  choline     folate  ...      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...   2.38 g
# 4         1mg  46.00 mg   7.7 mg   4.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 77 columns]

# %%
nutrition.info(verbose = False, memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Columns: 77 entries, Unnamed: 0 to water
# dtypes: int64(3), object(74)
# memory usage: 39.2 MB

# %% [markdown]
# ---
# ### clean up and remove dups
# * note the unnamed column

# %%
#drop the unnamed columns
nutrition.drop(columns=['Unnamed: 0'], inplace=True)
nutrition.head()
# Out:
#               name serving_size  calories total_fat saturated_fat cholesterol  \
# 0       Cornstarch        100 g       381      0.1g           NaN           0
# 1     Nuts, pecans        100 g       691       72g          6.2g           0
# 2    Eggplant, raw        100 g        25      0.2g           NaN           0
# 3   Teff, uncooked        100 g       367      2.4g          0.4g           0
# 4  Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#      sodium  choline     folate folic_acid  ...      fat  \
# 0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g
# 1   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g
# 2   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g
# 3  12.00 mg  13.1 mg          0          0  ...   2.38 g
# 4  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 76 columns]

# %%
# set the index to the name columns
nutrition.set_index(['name'], inplace=True)
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
#                      fat saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch        0.05 g               0.009 g                     0.016 g
# Nuts, pecans     71.97 g               6.180 g                    40.801 g
# Eggplant, raw     0.18 g               0.034 g                     0.016 g
# Teff, uncooked    2.38 g               0.449 g                     0.589 g
# Sherbet, orange   2.00 g               1.160 g                     0.530 g
#
#                 polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Cornstarch                          0.025 g                 0.00 mg   0.0 g
# Nuts, pecans                       21.614 g                 0.00 mg   0.0 g
# Eggplant, raw                       0.076 g                 0.00 mg   0.0 g
# Teff, uncooked                      1.071 g                       0       0
# Sherbet, orange                     0.080 g                 1.00 mg   0.0 g
#
#                     ash caffeine theobromine    water
# name
# Cornstarch       0.09 g  0.00 mg     0.00 mg   8.32 g
# Nuts, pecans     1.49 g  0.00 mg     0.00 mg   3.52 g
# Eggplant, raw    0.66 g  0.00 mg     0.00 mg  92.30 g
# Teff, uncooked   2.37 g        0           0   8.82 g
# Sherbet, orange  0.40 g  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 75 columns]

# %%
## Taking random sample from a df

nutrition.sample(random_state=12)
# Out:
#                                                 serving_size  calories  \
# name
# Thuringer, pork, beef, summer sausage, cervelat        100 g       362
#
#                                                 total_fat saturated_fat  \
# name
# Thuringer, pork, beef, summer sausage, cervelat       30g           12g
#
#                                                 cholesterol      sodium  \
# name
# Thuringer, pork, beef, summer sausage, cervelat        74mg  1300.00 mg
#
#                                                  choline    folate folic_acid  \
# name
# Thuringer, pork, beef, summer sausage, cervelat  78.9 mg  2.00 mcg   0.00 mcg
#
#                                                    niacin  ...      fat  \
# name                                                       ...
# Thuringer, pork, beef, summer sausage, cervelat  4.310 mg  ...  30.43 g
#
#                                                 saturated_fatty_acids  \
# name
# Thuringer, pork, beef, summer sausage, cervelat              11.510 g
#
#                                                 monounsaturated_fatty_acids  \
# name
# Thuringer, pork, beef, summer sausage, cervelat                    12.970 g
#
#                                                 polyunsaturated_fatty_acids  \
# name
# Thuringer, pork, beef, summer sausage, cervelat                     1.200 g
#
#                                                 fatty_acids_total_trans  \
# name
# Thuringer, pork, beef, summer sausage, cervelat                74.00 mg
#
#                                                 alcohol     ash caffeine  \
# name
# Thuringer, pork, beef, summer sausage, cervelat   0.0 g  3.63 g  0.00 mg
#
#                                                 theobromine    water
# name
# Thuringer, pork, beef, summer sausage, cervelat     0.00 mg  45.18 g
#
# [1 rows x 75 columns]

# %%
# if we set the random state parm across different users, we should get the same results
# if we want random each time:
nutrition.sample()
# Out:
#                                  serving_size  calories total_fat  \
# name
# Bread, oat bran, reduced-calorie        100 g       201      3.2g
#
#                                  saturated_fat cholesterol     sodium  \
# name
# Bread, oat bran, reduced-calorie          0.4g           0  459.00 mg
#
#                                   choline     folate folic_acid    niacin  \
# name
# Bread, oat bran, reduced-calorie  14.6 mg  81.00 mcg  47.00 mcg  3.763 mg
#
#                                   ...     fat saturated_fatty_acids  \
# name                              ...
# Bread, oat bran, reduced-calorie  ...  3.20 g               0.445 g
#
#                                  monounsaturated_fatty_acids  \
# name
# Bread, oat bran, reduced-calorie                     0.684 g
#
#                                  polyunsaturated_fatty_acids  \
# name
# Bread, oat bran, reduced-calorie                     1.670 g
#
#                                  fatty_acids_total_trans alcohol     ash  \
# name
# Bread, oat bran, reduced-calorie                 0.00 mg   0.0 g  1.50 g
#
#                                  caffeine theobromine    water
# name
# Bread, oat bran, reduced-calorie  0.00 mg     0.00 mg  46.00 g
#
# [1 rows x 75 columns]

# %%
# getting 3 random samples
nutrition.sample(n=3)
# Out:
#                                                    serving_size  calories  \
# name
# Beef, raw, Aust. marble score 4/5, separable le...        100 g       206
# Pork, roasted, heated, separable lean and fat, ...        100 g       191
# Cereals ready-to-eat, and Raisins, Honey, Wheat...        100 g       412
#
#                                                    total_fat saturated_fat  \
# name
# Beef, raw, Aust. marble score 4/5, separable le...       14g          6.1g
# Pork, roasted, heated, separable lean and fat, ...       11g          3.5g
# Cereals ready-to-eat, and Raisins, Honey, Wheat...       10g          1.1g
#
#                                                    cholesterol     sodium  \
# name
# Beef, raw, Aust. marble score 4/5, separable le...        60mg   63.00 mg
# Pork, roasted, heated, separable lean and fat, ...        74mg  801.00 mg
# Cereals ready-to-eat, and Raisins, Honey, Wheat...         2mg   54.00 mg
#
#                                                     choline     folate  \
# name
# Beef, raw, Aust. marble score 4/5, separable le...        0          0
# Pork, roasted, heated, separable lean and fat, ...  91.0 mg   3.00 mcg
# Cereals ready-to-eat, and Raisins, Honey, Wheat...  31.8 mg  33.00 mcg
#
#                                                    folic_acid    niacin  ...  \
# name                                                                     ...
# Beef, raw, Aust. marble score 4/5, separable le...          0         0  ...
# Pork, roasted, heated, separable lean and fat, ...   0.00 mcg  7.190 mg  ...
# Cereals ready-to-eat, and Raisins, Honey, Wheat...   0.00 mcg  2.120 mg  ...
#
#                                                         fat  \
# name
# Beef, raw, Aust. marble score 4/5, separable le...  14.09 g
# Pork, roasted, heated, separable lean and fat, ...  10.93 g
# Cereals ready-to-eat, and Raisins, Honey, Wheat...  10.38 g
#
#                                                    saturated_fatty_acids  \
# name
# Beef, raw, Aust. marble score 4/5, separable le...               6.105 g
# Pork, roasted, heated, separable lean and fat, ...               3.545 g
# Cereals ready-to-eat, and Raisins, Honey, Wheat...               1.120 g
#
#                                                    monounsaturated_fatty_acids  \
# name
# Beef, raw, Aust. marble score 4/5, separable le...                     6.167 g
# Pork, roasted, heated, separable lean and fat, ...                     5.120 g
# Cereals ready-to-eat, and Raisins, Honey, Wheat...                     5.870 g
#
#                                                    polyunsaturated_fatty_acids  \
# name
# Beef, raw, Aust. marble score 4/5, separable le...                     0.531 g
# Pork, roasted, heated, separable lean and fat, ...                     1.351 g
# Cereals ready-to-eat, and Raisins, Honey, Wheat...                     2.390 g
#
#                                                    fatty_acids_total_trans  \
# name
# Beef, raw, Aust. marble score 4/5, separable le...                60.00 mg
# Pork, roasted, heated, separable lean and fat, ...                74.00 mg
# Cereals ready-to-eat, and Raisins, Honey, Wheat...                 2.00 mg
#
#                                                    alcohol     ash caffeine  \
# name
# Beef, raw, Aust. marble score 4/5, separable le...   0.0 g  1.02 g  0.00 mg
# Pork, roasted, heated, separable lean and fat, ...   0.0 g  2.98 g  0.00 mg
# Cereals ready-to-eat, and Raisins, Honey, Wheat...   0.0 g  1.90 g  0.00 mg
#
#                                                    theobromine    water
# name
# Beef, raw, Aust. marble score 4/5, separable le...     0.00 mg  65.20 g
# Pork, roasted, heated, separable lean and fat, ...     0.00 mg  62.94 g
# Cereals ready-to-eat, and Raisins, Honey, Wheat...     0.00 mg   3.39 g
#
# [3 rows x 75 columns]

# %%
# if we wantedd to sample a % of the data use the frac parm
nutrition.sample(frac = 0.01) 
#this would be 1% of the data
# Out:
#                                                    serving_size  calories  \
# name
# Soup, ready-to-serve, canned, chicken and veget...        100 g        33
# Fast foods, and sausage, cheese, with egg, engl...        100 g       286
# Margarine-like, soybean oil and butter, margari...        100 g       727
# Mayonnaise, with olive oil, reduced fat                   100 g       361
# Chicken, skin, BBQ, rotisserie, broiler                   100 g       378
# ...                                                         ...       ...
# Wheat, hard red spring                                    100 g       329
# Waffle, microwaved, ready-to-heat, frozen, butt...        100 g       289
# CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak ...        100 g        51
# Snacks, taro chips                                        100 g       498
# Clementines, raw                                          100 g        47
#
#                                                    total_fat saturated_fat  \
# name
# Soup, ready-to-serve, canned, chicken and veget...      0.7g          0.1g
# Fast foods, and sausage, cheese, with egg, engl...       18g          6.9g
# Margarine-like, soybean oil and butter, margari...       80g           14g
# Mayonnaise, with olive oil, reduced fat                  40g          5.4g
# Chicken, skin, BBQ, rotisserie, broiler                  35g          9.3g
# ...                                                      ...           ...
# Wheat, hard red spring                                  1.9g          0.3g
# Waffle, microwaved, ready-to-heat, frozen, butt...      9.4g          2.1g
# CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak ...      0.8g          0.4g
# Snacks, taro chips                                       25g          6.4g
# Clementines, raw                                        0.2g           NaN
#
#                                                    cholesterol     sodium  \
# name
# Soup, ready-to-serve, canned, chicken and veget...         3mg  229.00 mg
# Fast foods, and sausage, cheese, with egg, engl...       163mg  548.00 mg
# Margarine-like, soybean oil and butter, margari...        12mg  719.00 mg
# Mayonnaise, with olive oil, reduced fat                   33mg  800.00 mg
# Chicken, skin, BBQ, rotisserie, broiler                  120mg  335.00 mg
# ...                                                        ...        ...
# Wheat, hard red spring                                       0    2.00 mg
# Waffle, microwaved, ready-to-heat, frozen, butt...        16mg  663.00 mg
# CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak ...         4mg  363.00 mg
# Snacks, taro chips                                           0  342.00 mg
# Clementines, raw                                             0    1.00 mg
#
#                                                      choline     folate  \
# name
# Soup, ready-to-serve, canned, chicken and veget...    7.7 mg  13.00 mcg
# Fast foods, and sausage, cheese, with egg, engl...  103.3 mg  57.00 mcg
# Margarine-like, soybean oil and butter, margari...    6.5 mg   2.00 mcg
# Mayonnaise, with olive oil, reduced fat               9.0 mg   0.00 mcg
# Chicken, skin, BBQ, rotisserie, broiler              39.3 mg   9.00 mcg
# ...                                                      ...        ...
# Wheat, hard red spring                               31.2 mg  43.00 mcg
# Waffle, microwaved, ready-to-heat, frozen, butt...         0  64.00 mcg
# CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak ...         0          0
# Snacks, taro chips                                   44.3 mg  20.00 mcg
# Clementines, raw                                     14.0 mg  24.00 mcg
#
#                                                    folic_acid    niacin  ...  \
# name                                                                     ...
# Soup, ready-to-serve, canned, chicken and veget...   0.00 mcg  0.906 mg  ...
# Fast foods, and sausage, cheese, with egg, engl...  41.00 mcg  3.192 mg  ...
# Margarine-like, soybean oil and butter, margari...   0.00 mcg  0.022 mg  ...
# Mayonnaise, with olive oil, reduced fat              0.00 mcg  0.010 mg  ...
# Chicken, skin, BBQ, rotisserie, broiler              0.00 mcg  7.082 mg  ...
# ...                                                       ...       ...  ...
# Wheat, hard red spring                               0.00 mcg  5.710 mg  ...
# Waffle, microwaved, ready-to-heat, frozen, butt...  50.00 mcg  6.730 mg  ...
# CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak ...          0         0  ...
# Snacks, taro chips                                   0.00 mcg  0.515 mg  ...
# Clementines, raw                                     0.00 mcg  0.636 mg  ...
#
#                                                         fat  \
# name
# Soup, ready-to-serve, canned, chicken and veget...   0.73 g
# Fast foods, and sausage, cheese, with egg, engl...  18.10 g
# Margarine-like, soybean oil and butter, margari...  80.32 g
# Mayonnaise, with olive oil, reduced fat             40.00 g
# Chicken, skin, BBQ, rotisserie, broiler             35.15 g
# ...                                                     ...
# Wheat, hard red spring                               1.92 g
# Waffle, microwaved, ready-to-heat, frozen, butt...   9.40 g
# CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak ...   0.82 g
# Snacks, taro chips                                  24.90 g
# Clementines, raw                                     0.15 g
#
#                                                    saturated_fatty_acids  \
# name
# Soup, ready-to-serve, canned, chicken and veget...               0.121 g
# Fast foods, and sausage, cheese, with egg, engl...               6.928 g
# Margarine-like, soybean oil and butter, margari...              14.198 g
# Mayonnaise, with olive oil, reduced fat                          5.370 g
# Chicken, skin, BBQ, rotisserie, broiler                          9.333 g
# ...                                                                  ...
# Wheat, hard red spring                                           0.314 g
# Waffle, microwaved, ready-to-heat, frozen, butt...               2.057 g
# CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak ...               0.408 g
# Snacks, taro chips                                               6.430 g
# Clementines, raw                                                       0
#
#                                                    monounsaturated_fatty_acids  \
# name
# Soup, ready-to-serve, canned, chicken and veget...                     0.158 g
# Fast foods, and sausage, cheese, with egg, engl...                     6.765 g
# Margarine-like, soybean oil and butter, margari...                    30.292 g
# Mayonnaise, with olive oil, reduced fat                               29.542 g
# Chicken, skin, BBQ, rotisserie, broiler                               14.464 g
# ...                                                                        ...
# Wheat, hard red spring                                                 0.303 g
# Waffle, microwaved, ready-to-heat, frozen, butt...                     4.864 g
# CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak ...                           0
# Snacks, taro chips                                                     4.430 g
# Clementines, raw                                                             0
#
#                                                    polyunsaturated_fatty_acids  \
# name
# Soup, ready-to-serve, canned, chicken and veget...                     0.134 g
# Fast foods, and sausage, cheese, with egg, engl...                     2.772 g
# Margarine-like, soybean oil and butter, margari...                    24.170 g
# Mayonnaise, with olive oil, reduced fat                                4.006 g
# Chicken, skin, BBQ, rotisserie, broiler                                4.018 g
# ...                                                                        ...
# Wheat, hard red spring                                                 0.765 g
# Waffle, microwaved, ready-to-heat, frozen, butt...                     1.615 g
# CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak ...                           0
# Snacks, taro chips                                                    12.880 g
# Clementines, raw                                                             0
#
#                                                    fatty_acids_total_trans  \
# name
# Soup, ready-to-serve, canned, chicken and veget...                 3.00 mg
# Fast foods, and sausage, cheese, with egg, engl...               163.00 mg
# Margarine-like, soybean oil and butter, margari...                12.00 mg
# Mayonnaise, with olive oil, reduced fat                           33.00 mg
# Chicken, skin, BBQ, rotisserie, broiler                          120.00 mg
# ...                                                                    ...
# Wheat, hard red spring                                             0.00 mg
# Waffle, microwaved, ready-to-heat, frozen, butt...                16.00 mg
# CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak ...                 4.00 mg
# Snacks, taro chips                                                 0.00 mg
# Clementines, raw                                                         0
#
#                                                    alcohol     ash caffeine  \
# name
# Soup, ready-to-serve, canned, chicken and veget...   0.0 g  0.93 g  0.00 mg
# Fast foods, and sausage, cheese, with egg, engl...   0.0 g  2.26 g  0.00 mg
# Margarine-like, soybean oil and butter, margari...   0.0 g  1.53 g  0.00 mg
# Mayonnaise, with olive oil, reduced fat              0.0 g  2.05 g  0.00 mg
# Chicken, skin, BBQ, rotisserie, broiler              0.0 g  1.52 g  0.00 mg
# ...                                                    ...     ...      ...
# Wheat, hard red spring                               0.0 g  1.89 g  0.00 mg
# Waffle, microwaved, ready-to-heat, frozen, butt...       0  3.04 g        0
# CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak ...       0  1.16 g        0
# Snacks, taro chips                                   0.0 g  2.70 g  0.00 mg
# Clementines, raw                                         0  0.40 g        0
#
#                                                    theobromine    water
# name
# Soup, ready-to-serve, canned, chicken and veget...     0.00 mg  91.68 g
# Fast foods, and sausage, cheese, with egg, engl...     0.00 mg  48.82 g
# Margarine-like, soybean oil and butter, margari...     0.00 mg  17.07 g
# Mayonnaise, with olive oil, reduced fat                0.00 mg  57.58 g
# Chicken, skin, BBQ, rotisserie, broiler                0.00 mg  47.81 g
# ...                                                        ...      ...
# Wheat, hard red spring                                 0.00 mg  12.76 g
# Waffle, microwaved, ready-to-heat, frozen, butt...           0  36.48 g
# CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak ...           0  87.00 g
# Snacks, taro chips                                     0.00 mg   2.00 g
# Clementines, raw                                             0  86.58 g
#
# [88 rows x 75 columns]

# %% [markdown]
# ## Axis
#
# ### axis=0 is rows
# ### axis=1 is columns

# %%
nutrition.axes
# Out:
# [Index(['Cornstarch', 'Nuts, pecans', 'Eggplant, raw', 'Teff, uncooked',
#         'Sherbet, orange', 'Cauliflower, raw', 'Taro leaves, raw',
#         'Lamb, raw, ground', 'Cheese, camembert', 'Vegetarian fillets',
#         ...
#         'Beef, braised, cooked, all grades, trimmed to 1/8" fat, separable lean and fat, flat half, brisket',
#         'Beef, raw, select, trimmed to 1/8" fat, separable lean only, lip-on, boneless, rib eye steak/roast',
#         'Beef, raw, choice, trimmed to 1/8" fat, separable lean only, lip-on, boneless, rib eye steak/roast',
#         'Oil, uses similar to 95 degree hard butter, confection fat, palm kernel (hydrogenated), industrial',
#         'Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round steak, round',
#         'Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round',
#         'Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand',
#         'Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand',
#         'Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round roast, round',
#         'Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round'],
#        dtype='object', name='name', length=8789),
#  Index(['serving_size', 'calories', 'total_fat', 'saturated_fat', 'cholesterol',
#         'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#         'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#         'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#         'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#         'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#         'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#         'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#         'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#         'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#         'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#         'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#         'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
#         'fat', 'saturated_fatty_acids', 'monounsaturated_fatty_acids',
#         'polyunsaturated_fatty_acids', 'fatty_acids_total_trans', 'alcohol',
#         'ash', 'caffeine', 'theobromine', 'water'],
#        dtype='object')]

# %%
nutrition.index[3]
# Out:
# 'Teff, uncooked'

# %%
nutrition.columns[50]
# Out:
# 'proline'

# %% [markdown]
# ## Setting Index

# %%
# set the index to the name columns
# nutrition.set_index(['name'], inplace=True)
# nutrition.head()

# this was dome already above

# %%
# To check if there are any duplicates in the indes you can use the parm verify_integrity=True in set_index()
# the default is set to false so that you ARE allowed dups in the index
# if you set to false and it errors ... you know that you have dups in the index

# %% [markdown]
# ## Extracting Data
# ## .loc
#
# * can use BOTH rows and columns

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
#                      fat saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch        0.05 g               0.009 g                     0.016 g
# Nuts, pecans     71.97 g               6.180 g                    40.801 g
# Eggplant, raw     0.18 g               0.034 g                     0.016 g
# Teff, uncooked    2.38 g               0.449 g                     0.589 g
# Sherbet, orange   2.00 g               1.160 g                     0.530 g
#
#                 polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Cornstarch                          0.025 g                 0.00 mg   0.0 g
# Nuts, pecans                       21.614 g                 0.00 mg   0.0 g
# Eggplant, raw                       0.076 g                 0.00 mg   0.0 g
# Teff, uncooked                      1.071 g                       0       0
# Sherbet, orange                     0.080 g                 1.00 mg   0.0 g
#
#                     ash caffeine theobromine    water
# name
# Cornstarch       0.09 g  0.00 mg     0.00 mg   8.32 g
# Nuts, pecans     1.49 g  0.00 mg     0.00 mg   3.52 g
# Eggplant, raw    0.66 g  0.00 mg     0.00 mg  92.30 g
# Teff, uncooked   2.37 g        0           0   8.82 g
# Sherbet, orange  0.40 g  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 75 columns]

# %%
nutrition.loc['Eggplant, raw']
# Out:
# serving_size       100 g
# calories              25
# total_fat           0.2g
# saturated_fat        NaN
# cholesterol            0
#                   ...
# alcohol            0.0 g
# ash               0.66 g
# caffeine         0.00 mg
# theobromine      0.00 mg
# water            92.30 g
# Name: Eggplant, raw, Length: 75, dtype: object

# %%
# note this returns a series, what if we want the whole row
nutrition.loc[['Eggplant, raw'], :]
# Out:
#               serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Eggplant, raw        100 g        25      0.2g           NaN           0
#
#                 sodium choline     folate folic_acid    niacin  ...     fat  \
# name                                                            ...
# Eggplant, raw  2.00 mg  6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...  0.18 g
#
#               saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Eggplant, raw               0.034 g                     0.016 g
#
#               polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Eggplant, raw                     0.076 g                 0.00 mg   0.0 g
#
#                   ash caffeine theobromine    water
# name
# Eggplant, raw  0.66 g  0.00 mg     0.00 mg  92.30 g
#
# [1 rows x 75 columns]

# %%
#just the calories
nutrition.loc['Eggplant, raw', 'calories']
# Out:
# 25

# %%
nutrition.loc[['Eggplant, raw'], ['calories']]
# Out:
#                calories
# name
# Eggplant, raw        25

# %%
# Slicing rows and columns same time
nutrition.loc['Eggplant, raw':'Sherbet, orange', 'calories':'cholesterol']
# Out:
#                  calories total_fat saturated_fat cholesterol
# name
# Eggplant, raw          25      0.2g           NaN           0
# Teff, uncooked        367      2.4g          0.4g           0
# Sherbet, orange       144        2g          1.2g         1mg

# %%
# getting multiple values that ARE NOT consecutive --> double bracets --> passing a list in

# df.loc[['row or list of rows'], ['column1', 'column5', 'column8']]

nutrition.loc[
                ['Raspberries, raw', 'Blackberries, raw'],
                ['protein', 'vitamin_b6', 'water']
    
]
# Out:
#                   protein vitamin_b6    water
# name
# Raspberries, raw   1.20 g   0.055 mg  85.75 g
# Blackberries, raw  1.39 g   0.030 mg  88.15 g

# %% [markdown]
# ## Extracting Data
# ## .iloc
#
# * 0 indexed
# * can use BOTH rows and columns

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
#                      fat saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch        0.05 g               0.009 g                     0.016 g
# Nuts, pecans     71.97 g               6.180 g                    40.801 g
# Eggplant, raw     0.18 g               0.034 g                     0.016 g
# Teff, uncooked    2.38 g               0.449 g                     0.589 g
# Sherbet, orange   2.00 g               1.160 g                     0.530 g
#
#                 polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Cornstarch                          0.025 g                 0.00 mg   0.0 g
# Nuts, pecans                       21.614 g                 0.00 mg   0.0 g
# Eggplant, raw                       0.076 g                 0.00 mg   0.0 g
# Teff, uncooked                      1.071 g                       0       0
# Sherbet, orange                     0.080 g                 1.00 mg   0.0 g
#
#                     ash caffeine theobromine    water
# name
# Cornstarch       0.09 g  0.00 mg     0.00 mg   8.32 g
# Nuts, pecans     1.49 g  0.00 mg     0.00 mg   3.52 g
# Eggplant, raw    0.66 g  0.00 mg     0.00 mg  92.30 g
# Teff, uncooked   2.37 g        0           0   8.82 g
# Sherbet, orange  0.40 g  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 75 columns]

# %%
# getting the 4th item
nutrition.iloc[3]
# Out:
# serving_size      100 g
# calories            367
# total_fat          2.4g
# saturated_fat      0.4g
# cholesterol           0
#                   ...
# alcohol               0
# ash              2.37 g
# caffeine              0
# theobromine           0
# water            8.82 g
# Name: Teff, uncooked, Length: 75, dtype: object

# %%
#if we want the 4th, 6th and 9th position
nutrition.iloc[[4, 6, 9], :]
# Out:
#                    serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Sherbet, orange           100 g       144        2g          1.2g         1mg
# Taro leaves, raw          100 g        42      0.7g          0.2g           0
# Vegetarian fillets        100 g       290       18g          2.8g           0
#
#                        sodium  choline      folate folic_acid     niacin  ...  \
# name                                                                      ...
# Sherbet, orange      46.00 mg   7.7 mg    4.00 mcg   0.00 mcg   0.063 mg  ...
# Taro leaves, raw      3.00 mg  12.8 mg  126.00 mcg   0.00 mcg   1.513 mg  ...
# Vegetarian fillets  490.00 mg  82.0 mg  102.00 mcg   0.00 mcg  12.000 mg  ...
#
#                         fat saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Sherbet, orange      2.00 g               1.160 g                     0.530 g
# Taro leaves, raw     0.74 g               0.151 g                     0.060 g
# Vegetarian fillets  18.00 g               2.849 g                     4.376 g
#
#                    polyunsaturated_fatty_acids fatty_acids_total_trans  \
# name
# Sherbet, orange                        0.080 g                 1.00 mg
# Taro leaves, raw                       0.307 g                 0.00 mg
# Vegetarian fillets                     9.332 g                 0.00 mg
#
#                    alcohol     ash caffeine theobromine    water
# name
# Sherbet, orange      0.0 g  0.40 g  0.00 mg     0.00 mg  66.10 g
# Taro leaves, raw     0.0 g  1.92 g  0.00 mg     0.00 mg  85.66 g
# Vegetarian fillets   0.0 g  5.00 g  0.00 mg     0.00 mg  45.00 g
#
# [3 rows x 75 columns]

# %%
#if we wanted a certian slice of columns
nutrition.iloc[[4, 6, 9], 2:5]
# Out:
#                    total_fat saturated_fat cholesterol
# name
# Sherbet, orange           2g          1.2g         1mg
# Taro leaves, raw        0.7g          0.2g           0
# Vegetarian fillets       18g          2.8g           0

# %%
# or certian individual columns
nutrition.iloc[[4, 6, 9], [2,5,8]]
# Out:
#                    total_fat     sodium folic_acid
# name
# Sherbet, orange           2g   46.00 mg   0.00 mcg
# Taro leaves, raw        0.7g    3.00 mg   0.00 mcg
# Vegetarian fillets       18g  490.00 mg   0.00 mcg

# %%
# if we wanted to see every other row

nutrition.iloc[
    [True if i%2 ==0 else False for i in range(len(nutrition))]
    
]
# Out:
#                                                    serving_size  calories  \
# name
# Cornstarch                                                100 g       381
# Eggplant, raw                                             100 g        25
# Sherbet, orange                                           100 g       144
# Taro leaves, raw                                          100 g        42
# Cheese, camembert                                         100 g       300
# ...                                                         ...       ...
# Beef, raw, select, trimmed to 1/8" fat, separab...        100 g       148
# Oil, uses similar to 95 degree hard butter, con...        100 g       884
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       125
# Lamb, raw, separable lean and fat, composite of...        100 g       277
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       121
#
#                                                    total_fat saturated_fat  \
# name
# Cornstarch                                              0.1g           NaN
# Eggplant, raw                                           0.2g           NaN
# Sherbet, orange                                           2g          1.2g
# Taro leaves, raw                                        0.7g          0.2g
# Cheese, camembert                                        24g           15g
# ...                                                      ...           ...
# Beef, raw, select, trimmed to 1/8" fat, separab...      6.4g          2.3g
# Oil, uses similar to 95 degree hard butter, con...      100g           94g
# Beef, raw, all grades, trimmed to 0" fat, separ...      3.5g          1.4g
# Lamb, raw, separable lean and fat, composite of...       23g           12g
# Beef, raw, all grades, trimmed to 0" fat, separ...        3g          1.1g
#
#                                                    cholesterol     sodium  \
# name
# Cornstarch                                                   0    9.00 mg
# Eggplant, raw                                                0    2.00 mg
# Sherbet, orange                                            1mg   46.00 mg
# Taro leaves, raw                                             0    3.00 mg
# Cheese, camembert                                         72mg  842.00 mg
# ...                                                        ...        ...
# Beef, raw, select, trimmed to 1/8" fat, separab...        70mg   55.00 mg
# Oil, uses similar to 95 degree hard butter, con...           0    6.00 mg
# Beef, raw, all grades, trimmed to 0" fat, separ...        62mg   54.00 mg
# Lamb, raw, separable lean and fat, composite of...        78mg   39.00 mg
# Beef, raw, all grades, trimmed to 0" fat, separ...        60mg   53.00 mg
#
#                                                     choline      folate  \
# name
# Cornstarch                                           0.4 mg    0.00 mcg
# Eggplant, raw                                        6.9 mg   22.00 mcg
# Sherbet, orange                                      7.7 mg    4.00 mcg
# Taro leaves, raw                                    12.8 mg  126.00 mcg
# Cheese, camembert                                   15.4 mg   62.00 mcg
# ...                                                     ...         ...
# Beef, raw, select, trimmed to 1/8" fat, separab...  49.4 mg    4.00 mcg
# Oil, uses similar to 95 degree hard butter, con...   0.2 mg    0.00 mcg
# Beef, raw, all grades, trimmed to 0" fat, separ...  64.5 mg    4.00 mcg
# Lamb, raw, separable lean and fat, composite of...        0    1.00 mcg
# Beef, raw, all grades, trimmed to 0" fat, separ...  64.2 mg    4.00 mcg
#
#                                                    folic_acid    niacin  ...  \
# name                                                                     ...
# Cornstarch                                           0.00 mcg  0.000 mg  ...
# Eggplant, raw                                        0.00 mcg  0.649 mg  ...
# Sherbet, orange                                      0.00 mcg  0.063 mg  ...
# Taro leaves, raw                                     0.00 mcg  1.513 mg  ...
# Cheese, camembert                                    0.00 mcg  0.630 mg  ...
# ...                                                       ...       ...  ...
# Beef, raw, select, trimmed to 1/8" fat, separab...   0.00 mcg  5.580 mg  ...
# Oil, uses similar to 95 degree hard butter, con...   0.00 mcg  0.000 mg  ...
# Beef, raw, all grades, trimmed to 0" fat, separ...   0.00 mcg  6.422 mg  ...
# Lamb, raw, separable lean and fat, composite of...   0.00 mcg  6.550 mg  ...
# Beef, raw, all grades, trimmed to 0" fat, separ...   0.00 mcg  6.720 mg  ...
#
#                                                          fat  \
# name
# Cornstarch                                            0.05 g
# Eggplant, raw                                         0.18 g
# Sherbet, orange                                       2.00 g
# Taro leaves, raw                                      0.74 g
# Cheese, camembert                                    24.26 g
# ...                                                      ...
# Beef, raw, select, trimmed to 1/8" fat, separab...    6.41 g
# Oil, uses similar to 95 degree hard butter, con...  100.00 g
# Beef, raw, all grades, trimmed to 0" fat, separ...    3.50 g
# Lamb, raw, separable lean and fat, composite of...   22.74 g
# Beef, raw, all grades, trimmed to 0" fat, separ...    3.04 g
#
#                                                    saturated_fatty_acids  \
# name
# Cornstarch                                                       0.009 g
# Eggplant, raw                                                    0.034 g
# Sherbet, orange                                                  1.160 g
# Taro leaves, raw                                                 0.151 g
# Cheese, camembert                                               15.259 g
# ...                                                                  ...
# Beef, raw, select, trimmed to 1/8" fat, separab...               2.313 g
# Oil, uses similar to 95 degree hard butter, con...              93.701 g
# Beef, raw, all grades, trimmed to 0" fat, separ...               1.353 g
# Lamb, raw, separable lean and fat, composite of...              11.570 g
# Beef, raw, all grades, trimmed to 0" fat, separ...               1.086 g
#
#                                                    monounsaturated_fatty_acids  \
# name
# Cornstarch                                                             0.016 g
# Eggplant, raw                                                          0.016 g
# Sherbet, orange                                                        0.530 g
# Taro leaves, raw                                                       0.060 g
# Cheese, camembert                                                      7.023 g
# ...                                                                        ...
# Beef, raw, select, trimmed to 1/8" fat, separab...                     2.830 g
# Oil, uses similar to 95 degree hard butter, con...                     0.257 g
# Beef, raw, all grades, trimmed to 0" fat, separ...                     1.554 g
# Lamb, raw, separable lean and fat, composite of...                     8.720 g
# Beef, raw, all grades, trimmed to 0" fat, separ...                     1.266 g
#
#                                                    polyunsaturated_fatty_acids  \
# name
# Cornstarch                                                             0.025 g
# Eggplant, raw                                                          0.076 g
# Sherbet, orange                                                        0.080 g
# Taro leaves, raw                                                       0.307 g
# Cheese, camembert                                                      0.724 g
# ...                                                                        ...
# Beef, raw, select, trimmed to 1/8" fat, separab...                     0.396 g
# Oil, uses similar to 95 degree hard butter, con...                     0.000 g
# Beef, raw, all grades, trimmed to 0" fat, separ...                     0.244 g
# Lamb, raw, separable lean and fat, composite of...                     0.980 g
# Beef, raw, all grades, trimmed to 0" fat, separ...                     0.233 g
#
#                                                    fatty_acids_total_trans  \
# name
# Cornstarch                                                         0.00 mg
# Eggplant, raw                                                      0.00 mg
# Sherbet, orange                                                    1.00 mg
# Taro leaves, raw                                                   0.00 mg
# Cheese, camembert                                                 72.00 mg
# ...                                                                    ...
# Beef, raw, select, trimmed to 1/8" fat, separab...                70.00 mg
# Oil, uses similar to 95 degree hard butter, con...                 0.00 mg
# Beef, raw, all grades, trimmed to 0" fat, separ...                62.00 mg
# Lamb, raw, separable lean and fat, composite of...                78.00 mg
# Beef, raw, all grades, trimmed to 0" fat, separ...                60.00 mg
#
#                                                    alcohol     ash caffeine  \
# name
# Cornstarch                                           0.0 g  0.09 g  0.00 mg
# Eggplant, raw                                        0.0 g  0.66 g  0.00 mg
# Sherbet, orange                                      0.0 g  0.40 g  0.00 mg
# Taro leaves, raw                                     0.0 g  1.92 g  0.00 mg
# Cheese, camembert                                    0.0 g  3.68 g  0.00 mg
# ...                                                    ...     ...      ...
# Beef, raw, select, trimmed to 1/8" fat, separab...   0.0 g  1.03 g  0.00 mg
# Oil, uses similar to 95 degree hard butter, con...   0.0 g  0.01 g  0.00 mg
# Beef, raw, all grades, trimmed to 0" fat, separ...   0.0 g  1.11 g  0.00 mg
# Lamb, raw, separable lean and fat, composite of...       0  0.92 g        0
# Beef, raw, all grades, trimmed to 0" fat, separ...   0.0 g  1.10 g  0.00 mg
#
#                                                    theobromine    water
# name
# Cornstarch                                             0.00 mg   8.32 g
# Eggplant, raw                                          0.00 mg  92.30 g
# Sherbet, orange                                        0.00 mg  66.10 g
# Taro leaves, raw                                       0.00 mg  85.66 g
# Cheese, camembert                                      0.00 mg  51.80 g
# ...                                                        ...      ...
# Beef, raw, select, trimmed to 1/8" fat, separab...     0.00 mg  70.89 g
# Oil, uses similar to 95 degree hard butter, con...     0.00 mg   0.05 g
# Beef, raw, all grades, trimmed to 0" fat, separ...     0.00 mg  72.51 g
# Lamb, raw, separable lean and fat, composite of...           0  59.80 g
# Beef, raw, all grades, trimmed to 0" fat, separ...     0.00 mg  73.43 g
#
# [4395 rows x 75 columns]

# %% [markdown]
# ## Single value access
#
# * .at - by value (like loc)
# * .iat - by position (like iloc)

# %%
nutrition.at['Nuts, pecans', 'calories']
# Out:
# 691

# %%
nutrition.iat[2, 10]
# Out:
# '0.281 mg'

# %%
# at & iat are SAME as using loc & iloc BUT since its a single use function, its much faster

#we can time and compare

# %%
# %timeit nutrition.loc['Nuts, pecans', 'calories']
# Out:
# 7.22 µs ± 140 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit nutrition.at['Nuts, pecans', 'calories']
# Out:
# 3.38 µs ± 25 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## get_loc
#
# -helps us get an integer location from the label

# %%
nutrition.columns.get_loc('vitamin_k')
# Out:
# 26

# %%
# now we know that the column entitled vitamin_k is at position 26

# %% [markdown]
# ---
# # Practice Challenge
# ---

# %% [markdown]
# 1. Randomly select 10 food items and assign the resulting dataframe to a new variable called *nutr_mini*.

# %%
nutr_mini = nutrition.sample(n=10)
nutr_mini
# Out:
#                                                    serving_size  calories  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...        100 g       263
# WORTHINGTON FriPats, unprepared, frozen                   100 g       209
# Fish, raw, Atlantic, wolffish                             100 g        96
# Fish, liver (Alaska Native), chinook, king, salmon        100 g       156
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs           100 g       336
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing           100 g       319
# Pork, braised, cooked, separable lean and fat, ...        100 g       156
# Nuts, with salt added, plain, almond butter               100 g       614
# Frozen novelties, with low calorie sweetener, p...        100 g        24
# Cookies, with added fiber, reduced fat, commerc...        100 g       345
#
#                                                    total_fat saturated_fat  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...       17g          6.8g
# WORTHINGTON FriPats, unprepared, frozen                 9.1g          1.4g
# Fish, raw, Atlantic, wolffish                           2.4g          0.4g
# Fish, liver (Alaska Native), chinook, king, salmon        8g           NaN
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs         2.3g          0.5g
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing          32g          5.9g
# Pork, braised, cooked, separable lean and fat, ...      2.6g          0.8g
# Nuts, with salt added, plain, almond butter              56g          6.6g
# Frozen novelties, with low calorie sweetener, p...        0g           NaN
# Cookies, with added fiber, reduced fat, commerc...      9.7g          2.8g
#
#                                                    cholesterol     sodium  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...        79mg   63.00 mg
# WORTHINGTON FriPats, unprepared, frozen                    2mg  517.00 mg
# Fish, raw, Atlantic, wolffish                             46mg   85.00 mg
# Fish, liver (Alaska Native), chinook, king, salmon           0          0
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs              0    9.00 mg
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing           35mg  851.00 mg
# Pork, braised, cooked, separable lean and fat, ...        84mg   43.00 mg
# Nuts, with salt added, plain, almond butter                  0  227.00 mg
# Frozen novelties, with low calorie sweetener, p...           0   10.00 mg
# Cookies, with added fiber, reduced fat, commerc...           0  290.00 mg
#
#                                                      choline     folate  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...   59.5 mg   6.00 mcg
# WORTHINGTON FriPats, unprepared, frozen                    0          0
# Fish, raw, Atlantic, wolffish                              0   5.00 mcg
# Fish, liver (Alaska Native), chinook, king, salmon         0          0
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs      31.8 mg  27.00 mcg
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing            0   4.00 mcg
# Pork, braised, cooked, separable lean and fat, ...  106.6 mg   1.00 mcg
# Nuts, with salt added, plain, almond butter          52.1 mg  53.00 mcg
# Frozen novelties, with low calorie sweetener, p...    0.0 mg   0.00 mcg
# Cookies, with added fiber, reduced fat, commerc...   13.9 mg  42.00 mcg
#
#                                                    folic_acid    niacin  ...  \
# name                                                                     ...
# Beef, grilled, cooked, select, trimmed to 1/8" ...   0.00 mcg  5.304 mg  ...
# WORTHINGTON FriPats, unprepared, frozen                     0  4.700 mg  ...
# Fish, raw, Atlantic, wolffish                        0.00 mcg  2.133 mg  ...
# Fish, liver (Alaska Native), chinook, king, salmon          0  5.000 mg  ...
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs      0.00 mcg  3.200 mg  ...
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing             0  0.020 mg  ...
# Pork, braised, cooked, separable lean and fat, ...   0.00 mcg  7.685 mg  ...
# Nuts, with salt added, plain, almond butter          0.00 mcg  3.155 mg  ...
# Frozen novelties, with low calorie sweetener, p...   0.00 mcg  0.000 mg  ...
# Cookies, with added fiber, reduced fat, commerc...  34.00 mcg  1.441 mg  ...
#
#                                                         fat  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...  16.75 g
# WORTHINGTON FriPats, unprepared, frozen              9.10 g
# Fish, raw, Atlantic, wolffish                        2.39 g
# Fish, liver (Alaska Native), chinook, king, salmon   8.00 g
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs      2.30 g
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing     31.50 g
# Pork, braised, cooked, separable lean and fat, ...   2.56 g
# Nuts, with salt added, plain, almond butter         55.50 g
# Frozen novelties, with low calorie sweetener, p...   0.00 g
# Cookies, with added fiber, reduced fat, commerc...   9.68 g
#
#                                                    saturated_fatty_acids  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...               6.843 g
# WORTHINGTON FriPats, unprepared, frozen                          1.400 g
# Fish, raw, Atlantic, wolffish                                    0.365 g
# Fish, liver (Alaska Native), chinook, king, salmon                     0
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs                  0.463 g
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing                  5.860 g
# Pork, braised, cooked, separable lean and fat, ...               0.791 g
# Nuts, with salt added, plain, almond butter                      6.550 g
# Frozen novelties, with low calorie sweetener, p...               0.000 g
# Cookies, with added fiber, reduced fat, commerc...               2.766 g
#
#                                                    monounsaturated_fatty_acids  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...                     7.469 g
# WORTHINGTON FriPats, unprepared, frozen                                2.200 g
# Fish, raw, Atlantic, wolffish                                          0.837 g
# Fish, liver (Alaska Native), chinook, king, salmon                           0
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs                        0.580 g
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing                        7.750 g
# Pork, braised, cooked, separable lean and fat, ...                     1.022 g
# Nuts, with salt added, plain, almond butter                           32.445 g
# Frozen novelties, with low calorie sweetener, p...                     0.000 g
# Cookies, with added fiber, reduced fat, commerc...                     3.432 g
#
#                                                    polyunsaturated_fatty_acids  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...                     0.737 g
# WORTHINGTON FriPats, unprepared, frozen                                5.200 g
# Fish, raw, Atlantic, wolffish                                          0.845 g
# Fish, liver (Alaska Native), chinook, king, salmon                           0
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs                        1.053 g
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing                       16.300 g
# Pork, braised, cooked, separable lean and fat, ...                     0.474 g
# Nuts, with salt added, plain, almond butter                           13.613 g
# Frozen novelties, with low calorie sweetener, p...                     0.000 g
# Cookies, with added fiber, reduced fat, commerc...                     2.581 g
#
#                                                    fatty_acids_total_trans  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...                79.00 mg
# WORTHINGTON FriPats, unprepared, frozen                            2.00 mg
# Fish, raw, Atlantic, wolffish                                     46.00 mg
# Fish, liver (Alaska Native), chinook, king, salmon                       0
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs                    0.00 mg
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing                   35.00 mg
# Pork, braised, cooked, separable lean and fat, ...                84.00 mg
# Nuts, with salt added, plain, almond butter                        0.00 mg
# Frozen novelties, with low calorie sweetener, p...                 0.00 mg
# Cookies, with added fiber, reduced fat, commerc...                 0.00 mg
#
#                                                    alcohol     ash  caffeine  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...   0.0 g  1.03 g   0.00 mg
# WORTHINGTON FriPats, unprepared, frozen                  0  2.40 g         0
# Fish, raw, Atlantic, wolffish                            0  1.16 g         0
# Fish, liver (Alaska Native), chinook, king, salmon       0  1.30 g         0
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs      0.0 g  2.10 g   0.00 mg
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing          0  3.19 g         0
# Pork, braised, cooked, separable lean and fat, ...   0.0 g  1.14 g   0.00 mg
# Nuts, with salt added, plain, almond butter          0.0 g  3.09 g   0.00 mg
# Frozen novelties, with low calorie sweetener, p...   0.0 g  0.06 g   0.00 mg
# Cookies, with added fiber, reduced fat, commerc...   0.0 g  1.14 g  10.00 mg
#
#                                                    theobromine    water
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...     0.00 mg  56.87 g
# WORTHINGTON FriPats, unprepared, frozen                      0  56.80 g
# Fish, raw, Atlantic, wolffish                                0  79.90 g
# Fish, liver (Alaska Native), chinook, king, salmon           0  69.80 g
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs        0.00 mg   4.00 g
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing              0  54.90 g
# Pork, braised, cooked, separable lean and fat, ...     0.00 mg  66.99 g
# Nuts, with salt added, plain, almond butter            0.00 mg   1.64 g
# Frozen novelties, with low calorie sweetener, p...     0.00 mg  94.03 g
# Cookies, with added fiber, reduced fat, commerc...    97.00 mg  24.83 g
#
# [10 rows x 75 columns]

# %% [markdown]
# ---
# 2. From *nutr_mini*, extract the **total_fat** and **cholesterol** columns for all rows.

# %%
nutr_mini.loc[:, ['total_fat', 'cholesterol']]
# Out:
#                                                    total_fat cholesterol
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...       17g        79mg
# WORTHINGTON FriPats, unprepared, frozen                 9.1g         2mg
# Fish, raw, Atlantic, wolffish                           2.4g        46mg
# Fish, liver (Alaska Native), chinook, king, salmon        8g           0
# Cereals ready-to-eat, KASHI 7 Whole Grain Puffs         2.3g           0
# McDONALD'S, NEWMAN'S OWN Creamy Caesar Dressing          32g        35mg
# Pork, braised, cooked, separable lean and fat, ...      2.6g        84mg
# Nuts, with salt added, plain, almond butter              56g           0
# Frozen novelties, with low calorie sweetener, p...        0g           0
# Cookies, with added fiber, reduced fat, commerc...      9.7g           0

# %% [markdown]
# ---
# 3. Extract all the columns from **vitamin_b12** to the end, for the first, second, and third rows.

# %%
nutr_mini.columns.get_loc('vitamin_b12')
# Out:
# 20

# %%
nutr_mini.iloc[0:3, 20:]
# Out:
#                                                    vitamin_b12 vitamin_b6  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...    2.07 mcg   0.572 mg
# WORTHINGTON FriPats, unprepared, frozen               1.90 mcg   0.900 mg
# Fish, raw, Atlantic, wolffish                         2.03 mcg   0.400 mg
#
#                                                    vitamin_c vitamin_d  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...    0.0 mg   5.00 IU
# WORTHINGTON FriPats, unprepared, frozen               0.0 mg         0
# Fish, raw, Atlantic, wolffish                         0.0 mg         0
#
#                                                    vitamin_e tocopherol_alpha  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...   0.21 mg          0.21 mg
# WORTHINGTON FriPats, unprepared, frozen                    0                0
# Fish, raw, Atlantic, wolffish                              0                0
#
#                                                    vitamin_k   calcium  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...   1.6 mcg  20.00 mg
# WORTHINGTON FriPats, unprepared, frozen                    0  97.00 mg
# Fish, raw, Atlantic, wolffish                              0   6.00 mg
#
#                                                       copper     irom  ...  \
# name                                                                   ...
# Beef, grilled, cooked, select, trimmed to 1/8" ...  0.068 mg  3.20 mg  ...
# WORTHINGTON FriPats, unprepared, frozen                    0  2.80 mg  ...
# Fish, raw, Atlantic, wolffish                       0.029 mg  0.09 mg  ...
#
#                                                         fat  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...  16.75 g
# WORTHINGTON FriPats, unprepared, frozen              9.10 g
# Fish, raw, Atlantic, wolffish                        2.39 g
#
#                                                    saturated_fatty_acids  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...               6.843 g
# WORTHINGTON FriPats, unprepared, frozen                          1.400 g
# Fish, raw, Atlantic, wolffish                                    0.365 g
#
#                                                    monounsaturated_fatty_acids  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...                     7.469 g
# WORTHINGTON FriPats, unprepared, frozen                                2.200 g
# Fish, raw, Atlantic, wolffish                                          0.837 g
#
#                                                    polyunsaturated_fatty_acids  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...                     0.737 g
# WORTHINGTON FriPats, unprepared, frozen                                5.200 g
# Fish, raw, Atlantic, wolffish                                          0.845 g
#
#                                                    fatty_acids_total_trans  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...                79.00 mg
# WORTHINGTON FriPats, unprepared, frozen                            2.00 mg
# Fish, raw, Atlantic, wolffish                                     46.00 mg
#
#                                                    alcohol     ash caffeine  \
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...   0.0 g  1.03 g  0.00 mg
# WORTHINGTON FriPats, unprepared, frozen                  0  2.40 g        0
# Fish, raw, Atlantic, wolffish                            0  1.16 g        0
#
#                                                    theobromine    water
# name
# Beef, grilled, cooked, select, trimmed to 1/8" ...     0.00 mg  56.87 g
# WORTHINGTON FriPats, unprepared, frozen                      0  56.80 g
# Fish, raw, Atlantic, wolffish                                0  79.90 g
#
# [3 rows x 55 columns]

# %% [markdown]
# ---
# 4. Get the calories for the third food in *nutr_mini* using an attribute-based approach that is faster than .loc or .iloc.

# %%
nutr_mini.at['Fish, raw, Atlantic, wolffish', 'calories']
# Out:
# 96

# %% [markdown]
# ## Numeric cleanup
#
# ### note alot of data has the units in cells

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
#                      fat saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch        0.05 g               0.009 g                     0.016 g
# Nuts, pecans     71.97 g               6.180 g                    40.801 g
# Eggplant, raw     0.18 g               0.034 g                     0.016 g
# Teff, uncooked    2.38 g               0.449 g                     0.589 g
# Sherbet, orange   2.00 g               1.160 g                     0.530 g
#
#                 polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Cornstarch                          0.025 g                 0.00 mg   0.0 g
# Nuts, pecans                       21.614 g                 0.00 mg   0.0 g
# Eggplant, raw                       0.076 g                 0.00 mg   0.0 g
# Teff, uncooked                      1.071 g                       0       0
# Sherbet, orange                     0.080 g                 1.00 mg   0.0 g
#
#                     ash caffeine theobromine    water
# name
# Cornstarch       0.09 g  0.00 mg     0.00 mg   8.32 g
# Nuts, pecans     1.49 g  0.00 mg     0.00 mg   3.52 g
# Eggplant, raw    0.66 g  0.00 mg     0.00 mg  92.30 g
# Teff, uncooked   2.37 g        0           0   8.82 g
# Sherbet, orange  0.40 g  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 75 columns]

# %% [markdown]
# ## these values are considered as strings
# ## we need to conver these to numeric values so can perform operations/analysis

# %% [markdown]
# ## use the astype() method
# * first need to remove the units from each value --> .replace()
# * can change entire column or df

# %%
df_mini = nutrition.iloc[:6, :1]
df_mini
# Out:
#                  serving_size
# name
# Cornstarch              100 g
# Nuts, pecans            100 g
# Eggplant, raw           100 g
# Teff, uncooked          100 g
# Sherbet, orange         100 g
# Cauliflower, raw        100 g

# %%
df_mini.replace(to_replace='100 g', value=100)
# Out:
#                   serving_size
# name
# Cornstarch                 100
# Nuts, pecans               100
# Eggplant, raw              100
# Teff, uncooked             100
# Sherbet, orange            100
# Cauliflower, raw           100

# %%
#this can also be written as:
df_mini.replace('100 g', 100)
#but this is very specific to 100g

# %% [markdown]
# ## Regex
#
# ### Regular expression can use specifics on regex
# * regex101.com
#
# ### \s will find white space
#
# * so \sg will find all the with space and the letter g

# %%
# Putting that into the replace method

# .replace('pattern_to_be_replace', 'what_replace_with', regex=True)

df_mini.replace('\sg', '', regex=True)
# Out:
#                  serving_size
# name
# Cornstarch                100
# Nuts, pecans              100
# Eggplant, raw             100
# Teff, uncooked            100
# Sherbet, orange           100
# Cauliflower, raw          100

# %%
# this is great for single column that has same units and space
# we have many types of units with varying spaces

# %% [markdown]
# ## Put the units in the header column labels

# %% [markdown]
# ### 1. Remove the numerics so just left with the units labels
#
# ## the regex to grab the just the units is
# * [a-zA-Z]
# ## to negate that and get everything BUT the units (all numbers), add a ^ before
# *[^a-zA-Z]

# %%
nutrition.replace('[^a-zA-Z]', '', regex=True).head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch                 g       381         g           NaN
# Nuts, pecans               g       691         g             g
# Eggplant, raw              g        25         g           NaN
# Teff, uncooked             g       367         g             g
# Sherbet, orange            g       144         g             g          mg
#
#                 sodium choline folate folic_acid niacin  ... fat  \
# name                                                     ...
# Cornstarch          mg      mg    mcg        mcg     mg  ...   g
# Nuts, pecans        mg      mg    mcg        mcg     mg  ...   g
# Eggplant, raw       mg      mg    mcg        mcg     mg  ...   g
# Teff, uncooked      mg      mg                       mg  ...   g
# Sherbet, orange     mg      mg    mcg        mcg     mg  ...   g
#
#                 saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch                          g                           g
# Nuts, pecans                        g                           g
# Eggplant, raw                       g                           g
# Teff, uncooked                      g                           g
# Sherbet, orange                     g                           g
#
#                 polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Cornstarch                                g                      mg       g
# Nuts, pecans                              g                      mg       g
# Eggplant, raw                             g                      mg       g
# Teff, uncooked                            g
# Sherbet, orange                           g                      mg       g
#
#                 ash caffeine theobromine  water
# name
# Cornstarch        g       mg          mg      g
# Nuts, pecans      g       mg          mg      g
# Eggplant, raw     g       mg          mg      g
# Teff, uncooked    g                           g
# Sherbet, orange   g       mg          mg      g
#
# [5 rows x 75 columns]

# %%
## Note that calories is still numeric because it didnt have any units initially
## It was an integer not a string intially
## cast everything as a sting first

units = nutrition.astype(str).replace('[^a-zA-Z]', '', regex=True)
units.head()
# Out:
#                 serving_size calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch                 g                  g           nan
# Nuts, pecans               g                  g             g
# Eggplant, raw              g                  g           nan
# Teff, uncooked             g                  g             g
# Sherbet, orange            g                  g             g          mg
#
#                 sodium choline folate folic_acid niacin  ... fat  \
# name                                                     ...
# Cornstarch          mg      mg    mcg        mcg     mg  ...   g
# Nuts, pecans        mg      mg    mcg        mcg     mg  ...   g
# Eggplant, raw       mg      mg    mcg        mcg     mg  ...   g
# Teff, uncooked      mg      mg                       mg  ...   g
# Sherbet, orange     mg      mg    mcg        mcg     mg  ...   g
#
#                 saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch                          g                           g
# Nuts, pecans                        g                           g
# Eggplant, raw                       g                           g
# Teff, uncooked                      g                           g
# Sherbet, orange                     g                           g
#
#                 polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Cornstarch                                g                      mg       g
# Nuts, pecans                              g                      mg       g
# Eggplant, raw                             g                      mg       g
# Teff, uncooked                            g
# Sherbet, orange                           g                      mg       g
#
#                 ash caffeine theobromine water
# name
# Cornstarch        g       mg          mg     g
# Nuts, pecans      g       mg          mg     g
# Eggplant, raw     g       mg          mg     g
# Teff, uncooked    g                          g
# Sherbet, orange   g       mg          mg     g
#
# [5 rows x 75 columns]

# %% [markdown]
# ### 2. How to get the unit to column label header
#
# ### some NaN's, some empties, some mix of the two
# * Cant pick a single row to use
# * Need to find the mode of each column
#     * Recall the mode is the value that appears the most

# %%
units.mode()
# Out:
#   serving_size calories total_fat saturated_fat cholesterol sodium choline  \
# 0            g                  g             g          mg     mg      mg
#
#   folate folic_acid niacin  ... fat saturated_fatty_acids  \
# 0    mcg        mcg     mg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine water
# 0                      mg       g   g       mg          mg     g
#
# [1 rows x 75 columns]

# %%
headers = units.mode()
headers
# Out:
#   serving_size calories total_fat saturated_fat cholesterol sodium choline  \
# 0            g                  g             g          mg     mg      mg
#
#   folate folic_acid niacin  ... fat saturated_fatty_acids  \
# 0    mcg        mcg     mg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine water
# 0                      mg       g   g       mg          mg     g
#
# [1 rows x 75 columns]

# %% [markdown]
# ### dropna() quick overview
# * df.dropna() --> will drop all rows with a single NaN value (default)
# * the parms are df.dropna(how='any', axis=0) (default)
# * changing any to all will only drop rows that are ALL NaN values
# * Can add a subset to the parm as well:
#     - df.dropna(how='any', axis=0, subset=['column_name'])
#     - this will only use the column in the subset as the na filter

# %% [markdown]
# ### 3. Merging the header units to column labels
#
# ### use rename method with map
# * iterate over the newly created headers

# %%
# for k in headers:
#     print(k, headers[k])
    
#this will return a series for each column in the df --> each column is a series

#look at just col and units
for k in headers:
    print(k, headers[k].iloc[0])
# Out:
# serving_size g
# calories
# total_fat g
# saturated_fat g
# cholesterol mg
# sodium mg
# choline mg
# folate mcg
# folic_acid mcg
# niacin mg
# pantothenic_acid mg
# riboflavin mg
# thiamin mg
# vitamin_a IU
# vitamin_a_rae mcg
# carotene_alpha mcg
# carotene_beta mcg
# cryptoxanthin_beta mcg
# lutein_zeaxanthin mcg
# lucopene
# vitamin_b12 mcg
# vitamin_b6 mg
# vitamin_c mg
# vitamin_d IU
# vitamin_e mg
# tocopherol_alpha mg
# vitamin_k mcg
# calcium mg
# copper mg
# irom mg
# magnesium mg
# manganese mg
# phosphorous mg
# potassium mg
# selenium mcg
# zink mg
# protein g
# alanine g
# arginine g
# aspartic_acid g
# cystine g
# glutamic_acid g
# glycine g
# histidine g
# hydroxyproline
# isoleucine g
# leucine g
# lysine g
# methionine g
# phenylalanine g
# proline g
# serine g
# threonine g
# tryptophan g
# tyrosine g
# valine g
# carbohydrate g
# fiber g
# sugars g
# fructose
# galactose
# glucose
# lactose
# maltose
# sucrose
# fat g
# saturated_fatty_acids g
# monounsaturated_fatty_acids g
# polyunsaturated_fatty_acids g
# fatty_acids_total_trans mg
# alcohol g
# ash g
# caffeine mg
# theobromine mg
# water g

# %%
# but we know that some names DONT have unit values, see sucrose just above
# we can replace these with an NaN

headers = headers.replace('', np.nan)
headers
# Out:
#   serving_size  calories total_fat saturated_fat cholesterol sodium choline  \
# 0            g       NaN         g             g          mg     mg      mg
#
#   folate folic_acid niacin  ... fat saturated_fatty_acids  \
# 0    mcg        mcg     mg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine  water
# 0                      mg       g   g       mg          mg      g
#
# [1 rows x 75 columns]

# %%
#then if we wanted to drop out the NaN columns

headers = headers.dropna(axis=1)
headers
# Out:
#   serving_size total_fat saturated_fat cholesterol sodium choline folate  \
# 0            g         g             g          mg     mg      mg    mcg
#
#   folic_acid niacin pantothenic_acid  ... fat saturated_fatty_acids  \
# 0        mcg     mg               mg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine water
# 0                      mg       g   g       mg          mg     g
#
# [1 rows x 66 columns]

# %%
#we can see that we dropped 9 columns from the dataFrame
# we drop them because when we map and combine, those columns in the final df will remain unchanged (original)

# %% [markdown]
# ### create a mapper
# * dict of key:value pairs
# * {'old_col_namw' : 'new_name'}
# * we can pass to rename()

# %%
#use a dict comprehension
mapper = {k: k + "_" + headers[k].iloc[0] for k in headers}

mapper
# Out:
# {'serving_size': 'serving_size_g',
#  'total_fat': 'total_fat_g',
#  'saturated_fat': 'saturated_fat_g',
#  'cholesterol': 'cholesterol_mg',
#  'sodium': 'sodium_mg',
#  'choline': 'choline_mg',
#  'folate': 'folate_mcg',
#  'folic_acid': 'folic_acid_mcg',
#  'niacin': 'niacin_mg',
#  'pantothenic_acid': 'pantothenic_acid_mg',
#  'riboflavin': 'riboflavin_mg',
#  'thiamin': 'thiamin_mg',
#  'vitamin_a': 'vitamin_a_IU',
#  'vitamin_a_rae': 'vitamin_a_rae_mcg',
#  'carotene_alpha': 'carotene_alpha_mcg',
#  'carotene_beta': 'carotene_beta_mcg',
#  'cryptoxanthin_beta': 'cryptoxanthin_beta_mcg',
#  'lutein_zeaxanthin': 'lutein_zeaxanthin_mcg',
#  'vitamin_b12': 'vitamin_b12_mcg',
#  'vitamin_b6': 'vitamin_b6_mg',
#  'vitamin_c': 'vitamin_c_mg',
#  'vitamin_d': 'vitamin_d_IU',
#  'vitamin_e': 'vitamin_e_mg',
#  'tocopherol_alpha': 'tocopherol_alpha_mg',
#  'vitamin_k': 'vitamin_k_mcg',
#  'calcium': 'calcium_mg',
#  'copper': 'copper_mg',
#  'irom': 'irom_mg',
#  'magnesium': 'magnesium_mg',
#  'manganese': 'manganese_mg',
#  'phosphorous': 'phosphorous_mg',
#  'potassium': 'potassium_mg',
#  'selenium': 'selenium_mcg',
#  'zink': 'zink_mg',
#  'protein': 'protein_g',
#  'alanine': 'alanine_g',
#  'arginine': 'arginine_g',
#  'aspartic_acid': 'aspartic_acid_g',
#  'cystine': 'cystine_g',
#  'glutamic_acid': 'glutamic_acid_g',
#  'glycine': 'glycine_g',
#  'histidine': 'histidine_g',
#  'isoleucine': 'isoleucine_g',
#  'leucine': 'leucine_g',
#  'lysine': 'lysine_g',
#  'methionine': 'methionine_g',
#  'phenylalanine': 'phenylalanine_g',
#  'proline': 'proline_g',
#  'serine': 'serine_g',
#  'threonine': 'threonine_g',
#  'tryptophan': 'tryptophan_g',
#  'tyrosine': 'tyrosine_g',
#  'valine': 'valine_g',
#  'carbohydrate': 'carbohydrate_g',
#  'fiber': 'fiber_g',
#  'sugars': 'sugars_g',
#  'fat': 'fat_g',
#  'saturated_fatty_acids': 'saturated_fatty_acids_g',
#  'monounsaturated_fatty_acids': 'monounsaturated_fatty_acids_g',
#  'polyunsaturated_fatty_acids': 'polyunsaturated_fatty_acids_g',
#  'fatty_acids_total_trans': 'fatty_acids_total_trans_mg',
#  'alcohol': 'alcohol_g',
#  'ash': 'ash_g',
#  'caffeine': 'caffeine_mg',
#  'theobromine': 'theobromine_mg',
#  'water': 'water_g'}

# %%
nutrition.rename(columns=mapper, inplace=True)
nutrition.head()
# Out:
#                 serving_size_g  calories total_fat_g saturated_fat_g  \
# name
# Cornstarch               100 g       381        0.1g             NaN
# Nuts, pecans             100 g       691         72g            6.2g
# Eggplant, raw            100 g        25        0.2g             NaN
# Teff, uncooked           100 g       367        2.4g            0.4g
# Sherbet, orange          100 g       144          2g            1.2g
#
#                 cholesterol_mg sodium_mg choline_mg folate_mcg folic_acid_mcg  \
# name
# Cornstarch                   0   9.00 mg     0.4 mg   0.00 mcg       0.00 mcg
# Nuts, pecans                 0   0.00 mg    40.5 mg  22.00 mcg       0.00 mcg
# Eggplant, raw                0   2.00 mg     6.9 mg  22.00 mcg       0.00 mcg
# Teff, uncooked               0  12.00 mg    13.1 mg          0              0
# Sherbet, orange            1mg  46.00 mg     7.7 mg   4.00 mcg       0.00 mcg
#
#                 niacin_mg  ...    fat_g saturated_fatty_acids_g  \
# name                       ...
# Cornstarch       0.000 mg  ...   0.05 g                 0.009 g
# Nuts, pecans     1.167 mg  ...  71.97 g                 6.180 g
# Eggplant, raw    0.649 mg  ...   0.18 g                 0.034 g
# Teff, uncooked   3.363 mg  ...   2.38 g                 0.449 g
# Sherbet, orange  0.063 mg  ...   2.00 g                 1.160 g
#
#                 monounsaturated_fatty_acids_g polyunsaturated_fatty_acids_g  \
# name
# Cornstarch                            0.016 g                       0.025 g
# Nuts, pecans                         40.801 g                      21.614 g
# Eggplant, raw                         0.016 g                       0.076 g
# Teff, uncooked                        0.589 g                       1.071 g
# Sherbet, orange                       0.530 g                       0.080 g
#
#                 fatty_acids_total_trans_mg alcohol_g   ash_g caffeine_mg  \
# name
# Cornstarch                         0.00 mg     0.0 g  0.09 g     0.00 mg
# Nuts, pecans                       0.00 mg     0.0 g  1.49 g     0.00 mg
# Eggplant, raw                      0.00 mg     0.0 g  0.66 g     0.00 mg
# Teff, uncooked                           0         0  2.37 g           0
# Sherbet, orange                    1.00 mg     0.0 g  0.40 g     0.00 mg
#
#                 theobromine_mg  water_g
# name
# Cornstarch             0.00 mg   8.32 g
# Nuts, pecans           0.00 mg   3.52 g
# Eggplant, raw          0.00 mg  92.30 g
# Teff, uncooked               0   8.82 g
# Sherbet, orange        0.00 mg  66.10 g
#
# [5 rows x 75 columns]

# %% [markdown]
# ### 4. Final clean up of the units in the data fields
# * we can use .replace() with a regex pattern

# %%
# replace( 'what to replace', 'what replace with', regex=True)
nutrition.replace('[a-z A-Z]', '', regex=True, inplace=True)
nutrition.head()
# Out:
#                 serving_size_g  calories total_fat_g saturated_fat_g  \
# name
# Cornstarch                 100       381         0.1             NaN
# Nuts, pecans               100       691          72             6.2
# Eggplant, raw              100        25         0.2             NaN
# Teff, uncooked             100       367         2.4             0.4
# Sherbet, orange            100       144           2             1.2
#
#                 cholesterol_mg sodium_mg choline_mg folate_mcg folic_acid_mcg  \
# name
# Cornstarch                   0      9.00        0.4       0.00           0.00
# Nuts, pecans                 0      0.00       40.5      22.00           0.00
# Eggplant, raw                0      2.00        6.9      22.00           0.00
# Teff, uncooked               0     12.00       13.1          0              0
# Sherbet, orange              1     46.00        7.7       4.00           0.00
#
#                 niacin_mg  ...  fat_g saturated_fatty_acids_g  \
# name                       ...
# Cornstarch          0.000  ...   0.05                   0.009
# Nuts, pecans        1.167  ...  71.97                   6.180
# Eggplant, raw       0.649  ...   0.18                   0.034
# Teff, uncooked      3.363  ...   2.38                   0.449
# Sherbet, orange     0.063  ...   2.00                   1.160
#
#                 monounsaturated_fatty_acids_g polyunsaturated_fatty_acids_g  \
# name
# Cornstarch                              0.016                         0.025
# Nuts, pecans                           40.801                        21.614
# Eggplant, raw                           0.016                         0.076
# Teff, uncooked                          0.589                         1.071
# Sherbet, orange                         0.530                         0.080
#
#                 fatty_acids_total_trans_mg alcohol_g ash_g caffeine_mg  \
# name
# Cornstarch                            0.00       0.0  0.09        0.00
# Nuts, pecans                          0.00       0.0  1.49        0.00
# Eggplant, raw                         0.00       0.0  0.66        0.00
# Teff, uncooked                           0         0  2.37           0
# Sherbet, orange                       1.00       0.0  0.40        0.00
#
#                 theobromine_mg  water_g
# name
# Cornstarch                0.00     8.32
# Nuts, pecans              0.00     3.52
# Eggplant, raw             0.00    92.30
# Teff, uncooked               0     8.82
# Sherbet, orange           0.00    66.10
#
# [5 rows x 75 columns]

# %%
nutrition.dtypes.value_counts()
# Out:
# object    73
# int64      2
# dtype: int64

# %%
#so 73 of the 75 columns are still objects ... we want integers
nutrition = nutrition.astype(float)

# %%
#now check
nutrition.dtypes.value_counts()
# Out:
# float64    75
# dtype: int64

# %%
nutrition.describe().T
# Out:
#                   count        mean         std    min     25%     50%  \
# serving_size_g   8789.0  100.000000    0.000000  100.0  100.00  100.00
# calories         8789.0  226.283878  169.862001    0.0   91.00  191.00
# total_fat_g      8789.0   10.556855   15.818247    0.0    1.00    5.10
# saturated_fat_g  7199.0    4.192791    6.877009    0.1    0.70    2.20
# cholesterol_mg   8789.0   38.723063  117.358944    0.0    0.00    2.00
# ...                 ...         ...         ...    ...     ...     ...
# alcohol_g        8789.0    0.117522    1.600127    0.0    0.00    0.00
# ash_g            8789.0    1.717408    2.967751    0.0    0.77    1.17
# caffeine_mg      8789.0    2.608829   82.070233    0.0    0.00    0.00
# theobromine_mg   8789.0    4.695642   60.962608    0.0    0.00    0.00
# water_g          8789.0   54.112074   30.772999    0.0   29.70   63.08
#
#                     75%     max
# serving_size_g   100.00   100.0
# calories         337.00   902.0
# total_fat_g       14.00   100.0
# saturated_fat_g    5.00    96.0
# cholesterol_mg    65.00  3100.0
# ...                 ...     ...
# alcohol_g          0.00    42.5
# ash_g              2.02    99.8
# caffeine_mg        0.00  5714.0
# theobromine_mg     0.00  2634.0
# water_g           77.96   100.0
#
# [75 rows x 8 columns]

# %%
#test a calcualation
nutrition.calories.sum()
# Out:
# 1988809.0

# %% [markdown]
# ## Flitering in 2D

# %%
nutrition.shape
# Out:
# (8789, 75)

# %%
#we know that we have 8789 rows in the df
#what if we wanted to find octopus info??

nutrition.filter(like='Octopus', axis=0) #axis=0 because we want to look for rows
# Out:
#                          serving_size_g  calories  total_fat_g  \
# name
# Octopus (Alaska Native)           100.0      56.0          0.8
#
#                          saturated_fat_g  cholesterol_mg  sodium_mg  \
# name
# Octopus (Alaska Native)              0.2            41.0        0.0
#
#                          choline_mg  folate_mcg  folic_acid_mcg  niacin_mg  \
# name
# Octopus (Alaska Native)         0.0         0.0             0.0        2.0
#
#                          ...  fat_g  saturated_fatty_acids_g  \
# name                     ...
# Octopus (Alaska Native)  ...    0.8                      0.2
#
#                          monounsaturated_fatty_acids_g  \
# name
# Octopus (Alaska Native)                            0.0
#
#                          polyunsaturated_fatty_acids_g  \
# name
# Octopus (Alaska Native)                            0.2
#
#                          fatty_acids_total_trans_mg  alcohol_g  ash_g  \
# name
# Octopus (Alaska Native)                        41.0        0.0    1.5
#
#                          caffeine_mg  theobromine_mg  water_g
# name
# Octopus (Alaska Native)          0.0             0.0     84.0
#
# [1 rows x 75 columns]

# %%
# This is CASE SENSITIVE ..
nutrition.filter(like='octopus', axis=0)
# Out:
#                                                serving_size_g  calories  \
# name
# Mollusks, raw, common, octopus                          100.0      82.0
# Mollusks, moist heat, cooked, common, octopus           100.0     164.0
#
#                                                total_fat_g  saturated_fat_g  \
# name
# Mollusks, raw, common, octopus                         1.0              0.2
# Mollusks, moist heat, cooked, common, octopus          2.1              0.5
#
#                                                cholesterol_mg  sodium_mg  \
# name
# Mollusks, raw, common, octopus                           48.0      230.0
# Mollusks, moist heat, cooked, common, octopus            96.0      460.0
#
#                                                choline_mg  folate_mcg  \
# name
# Mollusks, raw, common, octopus                       65.0        16.0
# Mollusks, moist heat, cooked, common, octopus        81.0        24.0
#
#                                                folic_acid_mcg  niacin_mg  ...  \
# name                                                                      ...
# Mollusks, raw, common, octopus                            0.0       2.10  ...
# Mollusks, moist heat, cooked, common, octopus             0.0       3.78  ...
#
#                                                fat_g  saturated_fatty_acids_g  \
# name
# Mollusks, raw, common, octopus                  1.04                    0.227
# Mollusks, moist heat, cooked, common, octopus   2.08                    0.453
#
#                                                monounsaturated_fatty_acids_g  \
# name
# Mollusks, raw, common, octopus                                         0.162
# Mollusks, moist heat, cooked, common, octopus                          0.324
#
#                                                polyunsaturated_fatty_acids_g  \
# name
# Mollusks, raw, common, octopus                                         0.239
# Mollusks, moist heat, cooked, common, octopus                          0.477
#
#                                                fatty_acids_total_trans_mg  \
# name
# Mollusks, raw, common, octopus                                       48.0
# Mollusks, moist heat, cooked, common, octopus                        96.0
#
#                                                alcohol_g  ash_g  caffeine_mg  \
# name
# Mollusks, raw, common, octopus                       0.0    1.6          0.0
# Mollusks, moist heat, cooked, common, octopus        0.0    3.2          0.0
#
#                                                theobromine_mg  water_g
# name
# Mollusks, raw, common, octopus                            0.0    80.25
# Mollusks, moist heat, cooked, common, octopus             0.0    60.50
#
# [2 rows x 75 columns]

# %%
# We can filter with regex to get ALL octopus
nutrition.filter(regex='[Oo]ctopus', axis=0)
# Out:
#                                                serving_size_g  calories  \
# name
# Octopus (Alaska Native)                                 100.0      56.0
# Mollusks, raw, common, octopus                          100.0      82.0
# Mollusks, moist heat, cooked, common, octopus           100.0     164.0
#
#                                                total_fat_g  saturated_fat_g  \
# name
# Octopus (Alaska Native)                                0.8              0.2
# Mollusks, raw, common, octopus                         1.0              0.2
# Mollusks, moist heat, cooked, common, octopus          2.1              0.5
#
#                                                cholesterol_mg  sodium_mg  \
# name
# Octopus (Alaska Native)                                  41.0        0.0
# Mollusks, raw, common, octopus                           48.0      230.0
# Mollusks, moist heat, cooked, common, octopus            96.0      460.0
#
#                                                choline_mg  folate_mcg  \
# name
# Octopus (Alaska Native)                               0.0         0.0
# Mollusks, raw, common, octopus                       65.0        16.0
# Mollusks, moist heat, cooked, common, octopus        81.0        24.0
#
#                                                folic_acid_mcg  niacin_mg  ...  \
# name                                                                      ...
# Octopus (Alaska Native)                                   0.0       2.00  ...
# Mollusks, raw, common, octopus                            0.0       2.10  ...
# Mollusks, moist heat, cooked, common, octopus             0.0       3.78  ...
#
#                                                fat_g  saturated_fatty_acids_g  \
# name
# Octopus (Alaska Native)                         0.80                    0.200
# Mollusks, raw, common, octopus                  1.04                    0.227
# Mollusks, moist heat, cooked, common, octopus   2.08                    0.453
#
#                                                monounsaturated_fatty_acids_g  \
# name
# Octopus (Alaska Native)                                                0.000
# Mollusks, raw, common, octopus                                         0.162
# Mollusks, moist heat, cooked, common, octopus                          0.324
#
#                                                polyunsaturated_fatty_acids_g  \
# name
# Octopus (Alaska Native)                                                0.200
# Mollusks, raw, common, octopus                                         0.239
# Mollusks, moist heat, cooked, common, octopus                          0.477
#
#                                                fatty_acids_total_trans_mg  \
# name
# Octopus (Alaska Native)                                              41.0
# Mollusks, raw, common, octopus                                       48.0
# Mollusks, moist heat, cooked, common, octopus                        96.0
#
#                                                alcohol_g  ash_g  caffeine_mg  \
# name
# Octopus (Alaska Native)                              0.0    1.5          0.0
# Mollusks, raw, common, octopus                       0.0    1.6          0.0
# Mollusks, moist heat, cooked, common, octopus        0.0    3.2          0.0
#
#                                                theobromine_mg  water_g
# name
# Octopus (Alaska Native)                                   0.0    84.00
# Mollusks, raw, common, octopus                            0.0    80.25
# Mollusks, moist heat, cooked, common, octopus             0.0    60.50
#
# [3 rows x 75 columns]

# %%
# we can use the regex case insensitive modifier --> (?i)
nutrition.filter(regex='(?i)Octopus', axis=0)
# Out:
#                                                serving_size_g  calories  \
# name
# Octopus (Alaska Native)                                 100.0      56.0
# Mollusks, raw, common, octopus                          100.0      82.0
# Mollusks, moist heat, cooked, common, octopus           100.0     164.0
#
#                                                total_fat_g  saturated_fat_g  \
# name
# Octopus (Alaska Native)                                0.8              0.2
# Mollusks, raw, common, octopus                         1.0              0.2
# Mollusks, moist heat, cooked, common, octopus          2.1              0.5
#
#                                                cholesterol_mg  sodium_mg  \
# name
# Octopus (Alaska Native)                                  41.0        0.0
# Mollusks, raw, common, octopus                           48.0      230.0
# Mollusks, moist heat, cooked, common, octopus            96.0      460.0
#
#                                                choline_mg  folate_mcg  \
# name
# Octopus (Alaska Native)                               0.0         0.0
# Mollusks, raw, common, octopus                       65.0        16.0
# Mollusks, moist heat, cooked, common, octopus        81.0        24.0
#
#                                                folic_acid_mcg  niacin_mg  ...  \
# name                                                                      ...
# Octopus (Alaska Native)                                   0.0       2.00  ...
# Mollusks, raw, common, octopus                            0.0       2.10  ...
# Mollusks, moist heat, cooked, common, octopus             0.0       3.78  ...
#
#                                                fat_g  saturated_fatty_acids_g  \
# name
# Octopus (Alaska Native)                         0.80                    0.200
# Mollusks, raw, common, octopus                  1.04                    0.227
# Mollusks, moist heat, cooked, common, octopus   2.08                    0.453
#
#                                                monounsaturated_fatty_acids_g  \
# name
# Octopus (Alaska Native)                                                0.000
# Mollusks, raw, common, octopus                                         0.162
# Mollusks, moist heat, cooked, common, octopus                          0.324
#
#                                                polyunsaturated_fatty_acids_g  \
# name
# Octopus (Alaska Native)                                                0.200
# Mollusks, raw, common, octopus                                         0.239
# Mollusks, moist heat, cooked, common, octopus                          0.477
#
#                                                fatty_acids_total_trans_mg  \
# name
# Octopus (Alaska Native)                                              41.0
# Mollusks, raw, common, octopus                                       48.0
# Mollusks, moist heat, cooked, common, octopus                        96.0
#
#                                                alcohol_g  ash_g  caffeine_mg  \
# name
# Octopus (Alaska Native)                              0.0    1.5          0.0
# Mollusks, raw, common, octopus                       0.0    1.6          0.0
# Mollusks, moist heat, cooked, common, octopus        0.0    3.2          0.0
#
#                                                theobromine_mg  water_g
# name
# Octopus (Alaska Native)                                   0.0    84.00
# Mollusks, raw, common, octopus                            0.0    80.25
# Mollusks, moist heat, cooked, common, octopus             0.0    60.50
#
# [3 rows x 75 columns]

# %%
# We can filter along both rows AND columns
# we can also use the items func in filter to select certian columns of interest

nutrition.filter(regex='(?i)Octopus', axis=0).filter(items=['serving_size_g', 'total_fat_g', 'calories'], axis=1)
# Out:
#                                                serving_size_g  total_fat_g  \
# name
# Octopus (Alaska Native)                                 100.0          0.8
# Mollusks, raw, common, octopus                          100.0          1.0
# Mollusks, moist heat, cooked, common, octopus           100.0          2.1
#
#                                                calories
# name
# Octopus (Alaska Native)                            56.0
# Mollusks, raw, common, octopus                     82.0
# Mollusks, moist heat, cooked, common, octopus     164.0

# %%
# You could also use the .loc to add column filtering

nutrition.filter(regex='(?i)Octopus', axis=0).loc[:, ['serving_size_g', 'total_fat_g', 'calories']]
# Out:
#                                                serving_size_g  total_fat_g  \
# name
# Octopus (Alaska Native)                                 100.0          0.8
# Mollusks, raw, common, octopus                          100.0          1.0
# Mollusks, moist heat, cooked, common, octopus           100.0          2.1
#
#                                                calories
# name
# Octopus (Alaska Native)                            56.0
# Mollusks, raw, common, octopus                     82.0
# Mollusks, moist heat, cooked, common, octopus     164.0

# %% [markdown]
# ## Sorting
# * sort by column

# %%
nutrition.sort_values(by=['calories'], ascending=False).head()
# Out:
#                      serving_size_g  calories  total_fat_g  saturated_fat_g  \
# name
# Fat, mutton tallow            100.0     902.0        100.0             47.0
# Fish oil, salmon              100.0     902.0        100.0             20.0
# Lard                          100.0     902.0        100.0             39.0
# Fat, beef tallow              100.0     902.0        100.0             50.0
# Fish oil, cod liver           100.0     902.0        100.0             23.0
#
#                      cholesterol_mg  sodium_mg  choline_mg  folate_mcg  \
# name
# Fat, mutton tallow            102.0        0.0        79.8         0.0
# Fish oil, salmon              485.0        0.0         0.0         0.0
# Lard                           95.0        0.0        49.7         0.0
# Fat, beef tallow              109.0        0.0        79.8         0.0
# Fish oil, cod liver           570.0        0.0         0.0         0.0
#
#                      folic_acid_mcg  niacin_mg  ...  fat_g  \
# name                                            ...
# Fat, mutton tallow              0.0        0.0  ...  100.0
# Fish oil, salmon                0.0        0.0  ...  100.0
# Lard                            0.0        0.0  ...  100.0
# Fat, beef tallow                0.0        0.0  ...  100.0
# Fish oil, cod liver             0.0        0.0  ...  100.0
#
#                      saturated_fatty_acids_g  monounsaturated_fatty_acids_g  \
# name
# Fat, mutton tallow                    47.300                         40.600
# Fish oil, salmon                      19.872                         29.037
# Lard                                  39.200                         45.100
# Fat, beef tallow                      49.800                         41.800
# Fish oil, cod liver                   22.608                         46.711
#
#                      polyunsaturated_fatty_acids_g  \
# name
# Fat, mutton tallow                           7.800
# Fish oil, salmon                            40.324
# Lard                                        11.200
# Fat, beef tallow                             4.000
# Fish oil, cod liver                         22.541
#
#                      fatty_acids_total_trans_mg  alcohol_g  ash_g  \
# name
# Fat, mutton tallow                        102.0        0.0    0.0
# Fish oil, salmon                          485.0        0.0    0.0
# Lard                                       95.0        0.0    0.0
# Fat, beef tallow                          109.0        0.0    0.0
# Fish oil, cod liver                       570.0        0.0    0.0
#
#                      caffeine_mg  theobromine_mg  water_g
# name
# Fat, mutton tallow           0.0             0.0      0.0
# Fish oil, salmon             0.0             0.0      0.0
# Lard                         0.0             0.0      0.0
# Fat, beef tallow             0.0             0.0      0.0
# Fish oil, cod liver          0.0             0.0      0.0
#
# [5 rows x 75 columns]

# %%
#sorting by 2 columns
nutrition.sort_values(by=['cholesterol_mg', 'sodium_mg'], ascending=False).head()
# Out:
#                                                     serving_size_g  calories  \
# name
# Veal, braised, cooked, brain, variety meats and...           100.0     136.0
# Beef, simmered, cooked, brain, variety meats an...           100.0     151.0
# Beef, raw, brain, variety meats and by-products              100.0     143.0
# Lamb, soaked and fried, cooked, brains, importe...           100.0     154.0
# Pork, braised, cooked, brain, variety meats and...           100.0     138.0
#
#                                                     total_fat_g  \
# name
# Veal, braised, cooked, brain, variety meats and...          9.6
# Beef, simmered, cooked, brain, variety meats an...         11.0
# Beef, raw, brain, variety meats and by-products            10.0
# Lamb, soaked and fried, cooked, brains, importe...         11.0
# Pork, braised, cooked, brain, variety meats and...          9.5
#
#                                                     saturated_fat_g  \
# name
# Veal, braised, cooked, brain, variety meats and...              2.2
# Beef, simmered, cooked, brain, variety meats an...              2.4
# Beef, raw, brain, variety meats and by-products                 2.3
# Lamb, soaked and fried, cooked, brains, importe...              1.4
# Pork, braised, cooked, brain, variety meats and...              2.2
#
#                                                     cholesterol_mg  sodium_mg  \
# name
# Veal, braised, cooked, brain, variety meats and...          3100.0      156.0
# Beef, simmered, cooked, brain, variety meats an...          3100.0      108.0
# Beef, raw, brain, variety meats and by-products             3010.0      126.0
# Lamb, soaked and fried, cooked, brains, importe...          2559.0      101.0
# Pork, braised, cooked, brain, variety meats and...          2552.0       91.0
#
#                                                     choline_mg  folate_mcg  \
# name
# Veal, braised, cooked, brain, variety meats and...         0.0         3.0
# Beef, simmered, cooked, brain, variety meats an...       490.9         5.0
# Beef, raw, brain, variety meats and by-products            0.0         3.0
# Lamb, soaked and fried, cooked, brains, importe...         0.0         0.0
# Pork, braised, cooked, brain, variety meats and...         0.0         4.0
#
#                                                     folic_acid_mcg  niacin_mg  \
# name
# Veal, braised, cooked, brain, variety meats and...             0.0      2.430
# Beef, simmered, cooked, brain, variety meats an...             0.0      3.620
# Beef, raw, brain, variety meats and by-products                0.0      3.550
# Lamb, soaked and fried, cooked, brains, importe...             0.0      2.995
# Pork, braised, cooked, brain, variety meats and...             0.0      3.330
#
#                                                     ...  fat_g  \
# name                                                ...
# Veal, braised, cooked, brain, variety meats and...  ...   9.63
# Beef, simmered, cooked, brain, variety meats an...  ...  10.53
# Beef, raw, brain, variety meats and by-products     ...  10.30
# Lamb, soaked and fried, cooked, brains, importe...  ...  10.92
# Pork, braised, cooked, brain, variety meats and...  ...   9.51
#
#                                                     saturated_fatty_acids_g  \
# name
# Veal, braised, cooked, brain, variety meats and...                    2.180
# Beef, simmered, cooked, brain, variety meats an...                    2.394
# Beef, raw, brain, variety meats and by-products                       2.300
# Lamb, soaked and fried, cooked, brains, importe...                    1.365
# Pork, braised, cooked, brain, variety meats and...                    2.150
#
#                                                     monounsaturated_fatty_acids_g  \
# name
# Veal, braised, cooked, brain, variety meats and...                          1.740
# Beef, simmered, cooked, brain, variety meats an...                          1.882
# Beef, raw, brain, variety meats and by-products                             1.890
# Lamb, soaked and fried, cooked, brains, importe...                          4.168
# Pork, braised, cooked, brain, variety meats and...                          1.720
#
#                                                     polyunsaturated_fatty_acids_g  \
# name
# Veal, braised, cooked, brain, variety meats and...                          1.490
# Beef, simmered, cooked, brain, variety meats an...                          1.632
# Beef, raw, brain, variety meats and by-products                             1.586
# Lamb, soaked and fried, cooked, brains, importe...                          0.999
# Pork, braised, cooked, brain, variety meats and...                          1.470
#
#                                                     fatty_acids_total_trans_mg  \
# name
# Veal, braised, cooked, brain, variety meats and...                      3100.0
# Beef, simmered, cooked, brain, variety meats an...                      3100.0
# Beef, raw, brain, variety meats and by-products                         3010.0
# Lamb, soaked and fried, cooked, brains, importe...                      2559.0
# Pork, braised, cooked, brain, variety meats and...                      2552.0
#
#                                                     alcohol_g  ash_g  \
# name
# Veal, braised, cooked, brain, variety meats and...        0.0   1.40
# Beef, simmered, cooked, brain, variety meats an...        0.0   1.46
# Beef, raw, brain, variety meats and by-products           0.0   1.51
# Lamb, soaked and fried, cooked, brains, importe...        0.0   3.39
# Pork, braised, cooked, brain, variety meats and...        0.0   1.40
#
#                                                     caffeine_mg  \
# name
# Veal, braised, cooked, brain, variety meats and...          0.0
# Beef, simmered, cooked, brain, variety meats an...          0.0
# Beef, raw, brain, variety meats and by-products             0.0
# Lamb, soaked and fried, cooked, brains, importe...          0.0
# Pork, braised, cooked, brain, variety meats and...          0.0
#
#                                                     theobromine_mg  water_g
# name
# Veal, braised, cooked, brain, variety meats and...             0.0    76.89
# Beef, simmered, cooked, brain, variety meats an...             0.0    74.86
# Beef, raw, brain, variety meats and by-products                0.0    76.29
# Lamb, soaked and fried, cooked, brains, importe...             0.0    73.11
# Pork, braised, cooked, brain, variety meats and...             0.0    75.88
#
# [5 rows x 75 columns]

# %%
# can also pass a py list to the ascending parm
# it will sort in order of the columns passed in list

nutrition.sort_values(by=['cholesterol_mg', 'sodium_mg'], ascending=[False, True]).head()
# Out:
#                                                     serving_size_g  calories  \
# name
# Beef, simmered, cooked, brain, variety meats an...           100.0     151.0
# Veal, braised, cooked, brain, variety meats and...           100.0     136.0
# Beef, raw, brain, variety meats and by-products              100.0     143.0
# Lamb, soaked and fried, cooked, brains, importe...           100.0     154.0
# Pork, braised, cooked, brain, variety meats and...           100.0     138.0
#
#                                                     total_fat_g  \
# name
# Beef, simmered, cooked, brain, variety meats an...         11.0
# Veal, braised, cooked, brain, variety meats and...          9.6
# Beef, raw, brain, variety meats and by-products            10.0
# Lamb, soaked and fried, cooked, brains, importe...         11.0
# Pork, braised, cooked, brain, variety meats and...          9.5
#
#                                                     saturated_fat_g  \
# name
# Beef, simmered, cooked, brain, variety meats an...              2.4
# Veal, braised, cooked, brain, variety meats and...              2.2
# Beef, raw, brain, variety meats and by-products                 2.3
# Lamb, soaked and fried, cooked, brains, importe...              1.4
# Pork, braised, cooked, brain, variety meats and...              2.2
#
#                                                     cholesterol_mg  sodium_mg  \
# name
# Beef, simmered, cooked, brain, variety meats an...          3100.0      108.0
# Veal, braised, cooked, brain, variety meats and...          3100.0      156.0
# Beef, raw, brain, variety meats and by-products             3010.0      126.0
# Lamb, soaked and fried, cooked, brains, importe...          2559.0      101.0
# Pork, braised, cooked, brain, variety meats and...          2552.0       91.0
#
#                                                     choline_mg  folate_mcg  \
# name
# Beef, simmered, cooked, brain, variety meats an...       490.9         5.0
# Veal, braised, cooked, brain, variety meats and...         0.0         3.0
# Beef, raw, brain, variety meats and by-products            0.0         3.0
# Lamb, soaked and fried, cooked, brains, importe...         0.0         0.0
# Pork, braised, cooked, brain, variety meats and...         0.0         4.0
#
#                                                     folic_acid_mcg  niacin_mg  \
# name
# Beef, simmered, cooked, brain, variety meats an...             0.0      3.620
# Veal, braised, cooked, brain, variety meats and...             0.0      2.430
# Beef, raw, brain, variety meats and by-products                0.0      3.550
# Lamb, soaked and fried, cooked, brains, importe...             0.0      2.995
# Pork, braised, cooked, brain, variety meats and...             0.0      3.330
#
#                                                     ...  fat_g  \
# name                                                ...
# Beef, simmered, cooked, brain, variety meats an...  ...  10.53
# Veal, braised, cooked, brain, variety meats and...  ...   9.63
# Beef, raw, brain, variety meats and by-products     ...  10.30
# Lamb, soaked and fried, cooked, brains, importe...  ...  10.92
# Pork, braised, cooked, brain, variety meats and...  ...   9.51
#
#                                                     saturated_fatty_acids_g  \
# name
# Beef, simmered, cooked, brain, variety meats an...                    2.394
# Veal, braised, cooked, brain, variety meats and...                    2.180
# Beef, raw, brain, variety meats and by-products                       2.300
# Lamb, soaked and fried, cooked, brains, importe...                    1.365
# Pork, braised, cooked, brain, variety meats and...                    2.150
#
#                                                     monounsaturated_fatty_acids_g  \
# name
# Beef, simmered, cooked, brain, variety meats an...                          1.882
# Veal, braised, cooked, brain, variety meats and...                          1.740
# Beef, raw, brain, variety meats and by-products                             1.890
# Lamb, soaked and fried, cooked, brains, importe...                          4.168
# Pork, braised, cooked, brain, variety meats and...                          1.720
#
#                                                     polyunsaturated_fatty_acids_g  \
# name
# Beef, simmered, cooked, brain, variety meats an...                          1.632
# Veal, braised, cooked, brain, variety meats and...                          1.490
# Beef, raw, brain, variety meats and by-products                             1.586
# Lamb, soaked and fried, cooked, brains, importe...                          0.999
# Pork, braised, cooked, brain, variety meats and...                          1.470
#
#                                                     fatty_acids_total_trans_mg  \
# name
# Beef, simmered, cooked, brain, variety meats an...                      3100.0
# Veal, braised, cooked, brain, variety meats and...                      3100.0
# Beef, raw, brain, variety meats and by-products                         3010.0
# Lamb, soaked and fried, cooked, brains, importe...                      2559.0
# Pork, braised, cooked, brain, variety meats and...                      2552.0
#
#                                                     alcohol_g  ash_g  \
# name
# Beef, simmered, cooked, brain, variety meats an...        0.0   1.46
# Veal, braised, cooked, brain, variety meats and...        0.0   1.40
# Beef, raw, brain, variety meats and by-products           0.0   1.51
# Lamb, soaked and fried, cooked, brains, importe...        0.0   3.39
# Pork, braised, cooked, brain, variety meats and...        0.0   1.40
#
#                                                     caffeine_mg  \
# name
# Beef, simmered, cooked, brain, variety meats an...          0.0
# Veal, braised, cooked, brain, variety meats and...          0.0
# Beef, raw, brain, variety meats and by-products             0.0
# Lamb, soaked and fried, cooked, brains, importe...          0.0
# Pork, braised, cooked, brain, variety meats and...          0.0
#
#                                                     theobromine_mg  water_g
# name
# Beef, simmered, cooked, brain, variety meats an...             0.0    74.86
# Veal, braised, cooked, brain, variety meats and...             0.0    76.89
# Beef, raw, brain, variety meats and by-products                0.0    76.29
# Lamb, soaked and fried, cooked, brains, importe...             0.0    73.11
# Pork, braised, cooked, brain, variety meats and...             0.0    75.88
#
# [5 rows x 75 columns]

# %% [markdown]
# ## Between Method
# * select a row or column
# * then we can apply between criteria

# %%
# grab the calories between 20 and 60
nutrition.calories.between(20,60)
# Out:
# name
# Cornstarch                                                                                            False
# Nuts, pecans                                                                                          False
# Eggplant, raw                                                                                          True
# Teff, uncooked                                                                                        False
# Sherbet, orange                                                                                       False
#                                                                                                       ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    False
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round roast, round    False
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round    False
# Name: calories, Length: 8789, dtype: bool

# %%
# Note it returns a bool where it meets the criteria

# %%
# If we now pass that as a Boolean Mask for the whole df
nutrition[nutrition.calories.between(20,60)]
# Out:
#                                                     serving_size_g  calories  \
# name
# Eggplant, raw                                                100.0      25.0
# Cauliflower, raw                                             100.0      25.0
# Taro leaves, raw                                             100.0      42.0
# PACE, Picante Sauce                                          100.0      25.0
# Mango nectar, canned                                         100.0      51.0
# ...                                                            ...       ...
# Beverages, added calcium, high vitamin C, great...           100.0      29.0
# Ruby Red grapefruit juice blend (grapefruit, gr...           100.0      44.0
# Beverages, prepared with water, frozen concentr...           100.0      45.0
# Apple juice, diluted with 3 volume water withou...           100.0      47.0
# Apple juice, with added ascorbic acid, diluted ...           100.0      47.0
#
#                                                     total_fat_g  \
# name
# Eggplant, raw                                               0.2
# Cauliflower, raw                                            0.3
# Taro leaves, raw                                            0.7
# PACE, Picante Sauce                                         0.0
# Mango nectar, canned                                        0.1
# ...                                                         ...
# Beverages, added calcium, high vitamin C, great...          0.4
# Ruby Red grapefruit juice blend (grapefruit, gr...          0.1
# Beverages, prepared with water, frozen concentr...          0.0
# Apple juice, diluted with 3 volume water withou...          0.1
# Apple juice, with added ascorbic acid, diluted ...          0.1
#
#                                                     saturated_fat_g  \
# name
# Eggplant, raw                                                   NaN
# Cauliflower, raw                                                0.1
# Taro leaves, raw                                                0.2
# PACE, Picante Sauce                                             NaN
# Mango nectar, canned                                            NaN
# ...                                                             ...
# Beverages, added calcium, high vitamin C, great...              NaN
# Ruby Red grapefruit juice blend (grapefruit, gr...              NaN
# Beverages, prepared with water, frozen concentr...              NaN
# Apple juice, diluted with 3 volume water withou...              NaN
# Apple juice, with added ascorbic acid, diluted ...              NaN
#
#                                                     cholesterol_mg  sodium_mg  \
# name
# Eggplant, raw                                                  0.0        2.0
# Cauliflower, raw                                               0.0       30.0
# Taro leaves, raw                                               0.0        3.0
# PACE, Picante Sauce                                            0.0      781.0
# Mango nectar, canned                                           0.0        5.0
# ...                                                            ...        ...
# Beverages, added calcium, high vitamin C, great...             0.0       25.0
# Ruby Red grapefruit juice blend (grapefruit, gr...             0.0        8.0
# Beverages, prepared with water, frozen concentr...             0.0       10.0
# Apple juice, diluted with 3 volume water withou...             0.0        7.0
# Apple juice, with added ascorbic acid, diluted ...             0.0        7.0
#
#                                                     choline_mg  folate_mcg  \
# name
# Eggplant, raw                                              6.9        22.0
# Cauliflower, raw                                          44.3        57.0
# Taro leaves, raw                                          12.8       126.0
# PACE, Picante Sauce                                        0.0         0.0
# Mango nectar, canned                                       1.5         7.0
# ...                                                        ...         ...
# Beverages, added calcium, high vitamin C, great...         0.1         2.0
# Ruby Red grapefruit juice blend (grapefruit, gr...         0.0         0.0
# Beverages, prepared with water, frozen concentr...         0.0         0.0
# Apple juice, diluted with 3 volume water withou...         1.8         0.0
# Apple juice, with added ascorbic acid, diluted ...         0.0         0.0
#
#                                                     folic_acid_mcg  niacin_mg  \
# name
# Eggplant, raw                                                  0.0      0.649
# Cauliflower, raw                                               0.0      0.507
# Taro leaves, raw                                               0.0      1.513
# PACE, Picante Sauce                                            0.0      0.000
# Mango nectar, canned                                           0.0      0.080
# ...                                                            ...        ...
# Beverages, added calcium, high vitamin C, great...             0.0      0.000
# Ruby Red grapefruit juice blend (grapefruit, gr...             0.0      0.000
# Beverages, prepared with water, frozen concentr...             0.0      0.253
# Apple juice, diluted with 3 volume water withou...             0.0      0.038
# Apple juice, with added ascorbic acid, diluted ...             0.0      0.038
#
#                                                     ...  fat_g  \
# name                                                ...
# Eggplant, raw                                       ...   0.18
# Cauliflower, raw                                    ...   0.28
# Taro leaves, raw                                    ...   0.74
# PACE, Picante Sauce                                 ...   0.00
# Mango nectar, canned                                ...   0.06
# ...                                                 ...    ...
# Beverages, added calcium, high vitamin C, great...  ...   0.37
# Ruby Red grapefruit juice blend (grapefruit, gr...  ...   0.10
# Beverages, prepared with water, frozen concentr...  ...   0.00
# Apple juice, diluted with 3 volume water withou...  ...   0.10
# Apple juice, with added ascorbic acid, diluted ...  ...   0.10
#
#                                                     saturated_fatty_acids_g  \
# name
# Eggplant, raw                                                         0.034
# Cauliflower, raw                                                      0.130
# Taro leaves, raw                                                      0.151
# PACE, Picante Sauce                                                   0.000
# Mango nectar, canned                                                  0.014
# ...                                                                     ...
# Beverages, added calcium, high vitamin C, great...                    0.000
# Ruby Red grapefruit juice blend (grapefruit, gr...                    0.008
# Beverages, prepared with water, frozen concentr...                    0.001
# Apple juice, diluted with 3 volume water withou...                    0.018
# Apple juice, with added ascorbic acid, diluted ...                    0.018
#
#                                                     monounsaturated_fatty_acids_g  \
# name
# Eggplant, raw                                                               0.016
# Cauliflower, raw                                                            0.034
# Taro leaves, raw                                                            0.060
# PACE, Picante Sauce                                                         0.000
# Mango nectar, canned                                                        0.022
# ...                                                                           ...
# Beverages, added calcium, high vitamin C, great...                          0.000
# Ruby Red grapefruit juice blend (grapefruit, gr...                          0.008
# Beverages, prepared with water, frozen concentr...                          0.001
# Apple juice, diluted with 3 volume water withou...                          0.002
# Apple juice, with added ascorbic acid, diluted ...                          0.002
#
#                                                     polyunsaturated_fatty_acids_g  \
# name
# Eggplant, raw                                                               0.076
# Cauliflower, raw                                                            0.031
# Taro leaves, raw                                                            0.307
# PACE, Picante Sauce                                                         0.000
# Mango nectar, canned                                                        0.011
# ...                                                                           ...
# Beverages, added calcium, high vitamin C, great...                          0.000
# Ruby Red grapefruit juice blend (grapefruit, gr...                          0.014
# Beverages, prepared with water, frozen concentr...                          0.001
# Apple juice, diluted with 3 volume water withou...                          0.031
# Apple juice, with added ascorbic acid, diluted ...                          0.031
#
#                                                     fatty_acids_total_trans_mg  \
# name
# Eggplant, raw                                                              0.0
# Cauliflower, raw                                                           0.0
# Taro leaves, raw                                                           0.0
# PACE, Picante Sauce                                                        0.0
# Mango nectar, canned                                                       0.0
# ...                                                                        ...
# Beverages, added calcium, high vitamin C, great...                         0.0
# Ruby Red grapefruit juice blend (grapefruit, gr...                         0.0
# Beverages, prepared with water, frozen concentr...                         0.0
# Apple juice, diluted with 3 volume water withou...                         0.0
# Apple juice, with added ascorbic acid, diluted ...                         0.0
#
#                                                     alcohol_g  ash_g  \
# name
# Eggplant, raw                                             0.0   0.66
# Cauliflower, raw                                          0.0   0.76
# Taro leaves, raw                                          0.0   1.92
# PACE, Picante Sauce                                       0.0   3.85
# Mango nectar, canned                                      0.0   0.08
# ...                                                       ...    ...
# Beverages, added calcium, high vitamin C, great...        0.0   0.06
# Ruby Red grapefruit juice blend (grapefruit, gr...        0.0   0.27
# Beverages, prepared with water, frozen concentr...        0.0   0.48
# Apple juice, diluted with 3 volume water withou...        0.0   0.32
# Apple juice, with added ascorbic acid, diluted ...        0.0   0.32
#
#                                                     caffeine_mg  \
# name
# Eggplant, raw                                               0.0
# Cauliflower, raw                                            0.0
# Taro leaves, raw                                            0.0
# PACE, Picante Sauce                                         0.0
# Mango nectar, canned                                        0.0
# ...                                                         ...
# Beverages, added calcium, high vitamin C, great...          0.0
# Ruby Red grapefruit juice blend (grapefruit, gr...          0.0
# Beverages, prepared with water, frozen concentr...          0.0
# Apple juice, diluted with 3 volume water withou...          0.0
# Apple juice, with added ascorbic acid, diluted ...          0.0
#
#                                                     theobromine_mg  water_g
# name
# Eggplant, raw                                                  0.0    92.30
# Cauliflower, raw                                               0.0    92.07
# Taro leaves, raw                                               0.0    85.66
# PACE, Picante Sauce                                            0.0    89.90
# Mango nectar, canned                                           0.0    86.63
# ...                                                            ...      ...
# Beverages, added calcium, high vitamin C, great...             0.0    93.00
# Ruby Red grapefruit juice blend (grapefruit, gr...             0.0    88.60
# Beverages, prepared with water, frozen concentr...             0.0    88.08
# Apple juice, diluted with 3 volume water withou...             0.0    87.90
# Apple juice, with added ascorbic acid, diluted ...             0.0    87.90
#
# [1190 rows x 75 columns]

# %%
# this returns 1190 possibilities, if we wanted a sample of that
nutrition[nutrition.calories.between(20,60)].sample(5)
# Out:
#                                                     serving_size_g  calories  \
# name
# Pear nectar, without added ascorbic acid, canned             100.0      60.0
# Broccoli, with salt, drained, boiled, cooked, c...           100.0      28.0
# Beverages, Mango Peach, V8 SPLASH Juice Drinks               100.0      33.0
# Beverages, prepared with water, frozen concentr...           100.0      45.0
# Tomato products, with mushrooms, sauce, canned               100.0      35.0
#
#                                                     total_fat_g  \
# name
# Pear nectar, without added ascorbic acid, canned            0.0
# Broccoli, with salt, drained, boiled, cooked, c...          0.1
# Beverages, Mango Peach, V8 SPLASH Juice Drinks              0.0
# Beverages, prepared with water, frozen concentr...          0.0
# Tomato products, with mushrooms, sauce, canned              0.1
#
#                                                     saturated_fat_g  \
# name
# Pear nectar, without added ascorbic acid, canned                NaN
# Broccoli, with salt, drained, boiled, cooked, c...              NaN
# Beverages, Mango Peach, V8 SPLASH Juice Drinks                  NaN
# Beverages, prepared with water, frozen concentr...              NaN
# Tomato products, with mushrooms, sauce, canned                  NaN
#
#                                                     cholesterol_mg  sodium_mg  \
# name
# Pear nectar, without added ascorbic acid, canned               0.0        4.0
# Broccoli, with salt, drained, boiled, cooked, c...             0.0      260.0
# Beverages, Mango Peach, V8 SPLASH Juice Drinks                 0.0       16.0
# Beverages, prepared with water, frozen concentr...             0.0       10.0
# Tomato products, with mushrooms, sauce, canned                 0.0      452.0
#
#                                                     choline_mg  folate_mcg  \
# name
# Pear nectar, without added ascorbic acid, canned           2.0         1.0
# Broccoli, with salt, drained, boiled, cooked, c...        16.2        56.0
# Beverages, Mango Peach, V8 SPLASH Juice Drinks             0.0         0.0
# Beverages, prepared with water, frozen concentr...         0.0         0.0
# Tomato products, with mushrooms, sauce, canned             0.0         9.0
#
#                                                     folic_acid_mcg  niacin_mg  \
# name
# Pear nectar, without added ascorbic acid, canned               0.0      0.128
# Broccoli, with salt, drained, boiled, cooked, c...             0.0      0.458
# Beverages, Mango Peach, V8 SPLASH Juice Drinks                 0.0      0.000
# Beverages, prepared with water, frozen concentr...             0.0      0.253
# Tomato products, with mushrooms, sauce, canned                 0.0      1.265
#
#                                                     ...  fat_g  \
# name                                                ...
# Pear nectar, without added ascorbic acid, canned    ...   0.01
# Broccoli, with salt, drained, boiled, cooked, c...  ...   0.12
# Beverages, Mango Peach, V8 SPLASH Juice Drinks      ...   0.00
# Beverages, prepared with water, frozen concentr...  ...   0.00
# Tomato products, with mushrooms, sauce, canned      ...   0.13
#
#                                                     saturated_fatty_acids_g  \
# name
# Pear nectar, without added ascorbic acid, canned                      0.001
# Broccoli, with salt, drained, boiled, cooked, c...                    0.018
# Beverages, Mango Peach, V8 SPLASH Juice Drinks                        0.000
# Beverages, prepared with water, frozen concentr...                    0.001
# Tomato products, with mushrooms, sauce, canned                        0.017
#
#                                                     monounsaturated_fatty_acids_g  \
# name
# Pear nectar, without added ascorbic acid, canned                            0.003
# Broccoli, with salt, drained, boiled, cooked, c...                          0.008
# Beverages, Mango Peach, V8 SPLASH Juice Drinks                              0.000
# Beverages, prepared with water, frozen concentr...                          0.001
# Tomato products, with mushrooms, sauce, canned                              0.010
#
#                                                     polyunsaturated_fatty_acids_g  \
# name
# Pear nectar, without added ascorbic acid, canned                            0.003
# Broccoli, with salt, drained, boiled, cooked, c...                          0.055
# Beverages, Mango Peach, V8 SPLASH Juice Drinks                              0.000
# Beverages, prepared with water, frozen concentr...                          0.001
# Tomato products, with mushrooms, sauce, canned                              0.050
#
#                                                     fatty_acids_total_trans_mg  \
# name
# Pear nectar, without added ascorbic acid, canned                           0.0
# Broccoli, with salt, drained, boiled, cooked, c...                         0.0
# Beverages, Mango Peach, V8 SPLASH Juice Drinks                             0.0
# Beverages, prepared with water, frozen concentr...                         0.0
# Tomato products, with mushrooms, sauce, canned                             0.0
#
#                                                     alcohol_g  ash_g  \
# name
# Pear nectar, without added ascorbic acid, canned          0.0   0.10
# Broccoli, with salt, drained, boiled, cooked, c...        0.0   0.71
# Beverages, Mango Peach, V8 SPLASH Juice Drinks            0.0   0.17
# Beverages, prepared with water, frozen concentr...        0.0   0.48
# Tomato products, with mushrooms, sauce, canned            0.0   2.02
#
#                                                     caffeine_mg  \
# name
# Pear nectar, without added ascorbic acid, canned            0.0
# Broccoli, with salt, drained, boiled, cooked, c...          0.0
# Beverages, Mango Peach, V8 SPLASH Juice Drinks              0.0
# Beverages, prepared with water, frozen concentr...          0.0
# Tomato products, with mushrooms, sauce, canned              0.0
#
#                                                     theobromine_mg  water_g
# name
# Pear nectar, without added ascorbic acid, canned               0.0    84.01
# Broccoli, with salt, drained, boiled, cooked, c...             0.0    90.72
# Beverages, Mango Peach, V8 SPLASH Juice Drinks                 0.0    91.60
# Beverages, prepared with water, frozen concentr...             0.0    88.08
# Tomato products, with mushrooms, sauce, canned                 0.0    87.97
#
# [5 rows x 75 columns]

# %% [markdown]
# ## Min, Max & Idx[MinMax]

# %%
nutrition.max()
# Out:
# serving_size_g      100.0
# calories            902.0
# total_fat_g         100.0
# saturated_fat_g      96.0
# cholesterol_mg     3100.0
#                     ...
# alcohol_g            42.5
# ash_g                99.8
# caffeine_mg        5714.0
# theobromine_mg     2634.0
# water_g             100.0
# Length: 75, dtype: float64

# %%
#this gives a series with all the cols max values
# we can do the same for rows
nutrition.max(axis=1)
# Out:
# name
# Cornstarch                                                                                            381.0
# Nuts, pecans                                                                                          691.0
# Eggplant, raw                                                                                         229.0
# Teff, uncooked                                                                                        429.0
# Sherbet, orange                                                                                       144.0
#                                                                                                       ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    311.0
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    246.0
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    277.0
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round roast, round    319.0
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round    319.0
# Length: 8789, dtype: float64

# %%
# What food has the most potassium?
nutrition.potassium_mg.max()
# Out:
# 16500.0

# %%
#what does this correspond to?
nutrition.potassium_mg.idxmax()
# Out:
# 'Leavening agents, cream of tartar'

# %%
# look at the potassium
nutrition.potassium_mg.sort_values(ascending=False)
# Out:
# name
# Leavening agents, cream of tartar                              16500.0
# Leavening agents, low-sodium, baking powder                    10100.0
# Parsley, freeze-dried                                           6300.0
# Beverages, unsweetened, decaffeinated, instant, tea             6040.0
# Beverages, powder, unsweetened, instant, tea                    6040.0
#                                                                 ...
# CAMPBELL'S CHUNKY Soups, Beef with White and Wild Rice Soup        0.0
# Alcoholic beverage, Pinot Gris (Grigio), white, table, wine        0.0
# Cloudberries, raw (Alaska Native)                                  0.0
# Oil, all purpose, soy ( partially hydrogenated), industrial        0.0
# Oil, sunflower, mid-oleic, industrial                              0.0
# Name: potassium_mg, Length: 8789, dtype: float64

# %%
# want to find the items with a potassium to sodium ratio of 16
# the replace(0, 1) allows to not have a divide/multiply by 0 error
pot_sod = ((nutrition.potassium_mg.replace(0,1)) / (nutrition.sodium_mg.replace(0,1))).sort_values(ascending=False)
pot_sod.head()
# Out:
# name
# Peanut flour, low fat                                         1358.0
# Nuts, raw, pistachio nuts                                     1025.0
# Beverages, reduced calorie, with whitener, instant, coffee     909.0
# Soybeans, raw, mature seeds                                    898.5
# Soy meal, raw, defatted                                        830.0
# dtype: float64

# %%
# Now if we want to look at foods with the ratio in a range between 14-18
pot_sod.between(14, 18)
# Out:
# name
# Peanut flour, low fat                                         False
# Nuts, raw, pistachio nuts                                     False
# Beverages, reduced calorie, with whitener, instant, coffee    False
# Soybeans, raw, mature seeds                                   False
# Soy meal, raw, defatted                                       False
#                                                               ...
# Seasoning mix, original, chili, dry                           False
# Salt, table                                                   False
# PACE, Dry Taco Seasoning Mix                                  False
# Seasoning mix, coriander & annatto, sazon, dry                False
# Leavening agents, baking soda                                 False
# Length: 8789, dtype: bool

# %%
# this again gives us a Bool Mask we can apply to the entire series
pot_sod[pot_sod.between(14, 18)].sample(10)
# Out:
# name
# Lima beans, without salt, drained, boiled, cooked, baby, frozen, immature seeds    14.172414
# Juice, with added ascorbic acid and calcium, grape and pear blend, apple           17.800000
# Asparagus, drained, boiled, cooked                                                 16.000000
# Sapodilla, raw                                                                     16.083333
# Turnip greens, unprepared, frozen                                                  15.333333
# Cereals, without salt, prepared with water, plain, original, MALT-O-MEAL           14.000000
# Nuts, canned (liquid expressed from grated meat and water), coconut milk           16.923077
# Peppers, without salt, drained, boiled, chopped, frozen, green, sweet              18.000000
# Potatoes, dry form, flakes without milk, dehydrated, mashed                        14.259740
# Beverages, high vitamin C, greater than 3% juice, fruit juice drink                15.250000
# dtype: float64

# %% [markdown]
# ## nlargest & nsmallest

# %%
nutrition.nlargest(10, columns='potassium_mg')
# Out:
#                                                     serving_size_g  calories  \
# name
# Leavening agents, cream of tartar                            100.0     258.0
# Leavening agents, low-sodium, baking powder                  100.0      97.0
# Parsley, freeze-dried                                        100.0     271.0
# Beverages, powder, unsweetened, instant, tea                 100.0     315.0
# Beverages, unsweetened, decaffeinated, instant,...           100.0     315.0
# Spices, dried, chervil                                       100.0     237.0
# Spices, dried, coriander leaf                                100.0     279.0
# Celery flakes, dried                                         100.0     319.0
# Beverages, powder, regular, instant, coffee                  100.0     353.0
# Beverages, half the caffeine, regular, instant,...           100.0     352.0
#
#                                                     total_fat_g  \
# name
# Leavening agents, cream of tartar                           0.0
# Leavening agents, low-sodium, baking powder                 0.4
# Parsley, freeze-dried                                       5.2
# Beverages, powder, unsweetened, instant, tea                0.0
# Beverages, unsweetened, decaffeinated, instant,...          0.0
# Spices, dried, chervil                                      3.9
# Spices, dried, coriander leaf                               4.8
# Celery flakes, dried                                        2.1
# Beverages, powder, regular, instant, coffee                 0.5
# Beverages, half the caffeine, regular, instant,...          0.5
#
#                                                     saturated_fat_g  \
# name
# Leavening agents, cream of tartar                               NaN
# Leavening agents, low-sodium, baking powder                     0.1
# Parsley, freeze-dried                                           NaN
# Beverages, powder, unsweetened, instant, tea                    NaN
# Beverages, unsweetened, decaffeinated, instant,...              NaN
# Spices, dried, chervil                                          0.2
# Spices, dried, coriander leaf                                   0.1
# Celery flakes, dried                                            0.6
# Beverages, powder, regular, instant, coffee                     0.2
# Beverages, half the caffeine, regular, instant,...              0.2
#
#                                                     cholesterol_mg  sodium_mg  \
# name
# Leavening agents, cream of tartar                              0.0       52.0
# Leavening agents, low-sodium, baking powder                    0.0       90.0
# Parsley, freeze-dried                                          0.0      391.0
# Beverages, powder, unsweetened, instant, tea                   0.0       72.0
# Beverages, unsweetened, decaffeinated, instant,...             0.0       72.0
# Spices, dried, chervil                                         0.0       83.0
# Spices, dried, coriander leaf                                  0.0      211.0
# Celery flakes, dried                                           0.0     1435.0
# Beverages, powder, regular, instant, coffee                    0.0       37.0
# Beverages, half the caffeine, regular, instant,...             0.0       37.0
#
#                                                     choline_mg  folate_mcg  \
# name
# Leavening agents, cream of tartar                          0.0         0.0
# Leavening agents, low-sodium, baking powder                0.0         0.0
# Parsley, freeze-dried                                      0.0       194.0
# Beverages, powder, unsweetened, instant, tea             118.3       103.0
# Beverages, unsweetened, decaffeinated, instant,...       118.3       103.0
# Spices, dried, chervil                                     0.0       274.0
# Spices, dried, coriander leaf                             97.1       274.0
# Celery flakes, dried                                     122.3       107.0
# Beverages, powder, regular, instant, coffee              101.9         0.0
# Beverages, half the caffeine, regular, instant,...       101.9         0.0
#
#                                                     folic_acid_mcg  niacin_mg  \
# name
# Leavening agents, cream of tartar                              0.0      0.000
# Leavening agents, low-sodium, baking powder                    0.0      0.000
# Parsley, freeze-dried                                          0.0     10.400
# Beverages, powder, unsweetened, instant, tea                   0.0     10.800
# Beverages, unsweetened, decaffeinated, instant,...             0.0     10.800
# Spices, dried, chervil                                         0.0      5.400
# Spices, dried, coriander leaf                                  0.0     10.707
# Celery flakes, dried                                           0.0      4.640
# Beverages, powder, regular, instant, coffee                    0.0     28.173
# Beverages, half the caffeine, regular, instant,...             0.0     28.173
#
#                                                     ...  fat_g  \
# name                                                ...
# Leavening agents, cream of tartar                   ...   0.00
# Leavening agents, low-sodium, baking powder         ...   0.40
# Parsley, freeze-dried                               ...   5.20
# Beverages, powder, unsweetened, instant, tea        ...   0.00
# Beverages, unsweetened, decaffeinated, instant,...  ...   0.00
# Spices, dried, chervil                              ...   3.90
# Spices, dried, coriander leaf                       ...   4.78
# Celery flakes, dried                                ...   2.10
# Beverages, powder, regular, instant, coffee         ...   0.50
# Beverages, half the caffeine, regular, instant,...  ...   0.50
#
#                                                     saturated_fatty_acids_g  \
# name
# Leavening agents, cream of tartar                                     0.000
# Leavening agents, low-sodium, baking powder                           0.073
# Parsley, freeze-dried                                                 0.000
# Beverages, powder, unsweetened, instant, tea                          0.000
# Beverages, unsweetened, decaffeinated, instant,...                    0.000
# Spices, dried, chervil                                                0.169
# Spices, dried, coriander leaf                                         0.115
# Celery flakes, dried                                                  0.555
# Beverages, powder, regular, instant, coffee                           0.197
# Beverages, half the caffeine, regular, instant,...                    0.197
#
#                                                     monounsaturated_fatty_acids_g  \
# name
# Leavening agents, cream of tartar                                           0.000
# Leavening agents, low-sodium, baking powder                                 0.006
# Parsley, freeze-dried                                                       0.000
# Beverages, powder, unsweetened, instant, tea                                0.000
# Beverages, unsweetened, decaffeinated, instant,...                          0.000
# Spices, dried, chervil                                                      1.399
# Spices, dried, coriander leaf                                               2.232
# Celery flakes, dried                                                        0.405
# Beverages, powder, regular, instant, coffee                                 0.041
# Beverages, half the caffeine, regular, instant,...                          0.041
#
#                                                     polyunsaturated_fatty_acids_g  \
# name
# Leavening agents, cream of tartar                                           0.000
# Leavening agents, low-sodium, baking powder                                 0.121
# Parsley, freeze-dried                                                       0.000
# Beverages, powder, unsweetened, instant, tea                                0.000
# Beverages, unsweetened, decaffeinated, instant,...                          0.000
# Spices, dried, chervil                                                      1.800
# Spices, dried, coriander leaf                                               0.328
# Celery flakes, dried                                                        1.035
# Beverages, powder, regular, instant, coffee                                 0.196
# Beverages, half the caffeine, regular, instant,...                          0.196
#
#                                                     fatty_acids_total_trans_mg  \
# name
# Leavening agents, cream of tartar                                          0.0
# Leavening agents, low-sodium, baking powder                                0.0
# Parsley, freeze-dried                                                      0.0
# Beverages, powder, unsweetened, instant, tea                               0.0
# Beverages, unsweetened, decaffeinated, instant,...                         0.0
# Spices, dried, chervil                                                     0.0
# Spices, dried, coriander leaf                                              0.0
# Celery flakes, dried                                                       0.0
# Beverages, powder, regular, instant, coffee                                0.0
# Beverages, half the caffeine, regular, instant,...                         0.0
#
#                                                     alcohol_g  ash_g  \
# name
# Leavening agents, cream of tartar                         0.0  36.80
# Leavening agents, low-sodium, baking powder               0.0  46.40
# Parsley, freeze-dried                                     0.0  19.12
# Beverages, powder, unsweetened, instant, tea              0.0  16.04
# Beverages, unsweetened, decaffeinated, instant,...        0.0  16.04
# Spices, dried, chervil                                    0.0  16.60
# Spices, dried, coriander leaf                             0.0  14.08
# Celery flakes, dried                                      0.0  13.90
# Beverages, powder, regular, instant, coffee               0.0   8.80
# Beverages, half the caffeine, regular, instant,...        0.0   8.80
#
#                                                     caffeine_mg  \
# name
# Leavening agents, cream of tartar                           0.0
# Leavening agents, low-sodium, baking powder                 0.0
# Parsley, freeze-dried                                       0.0
# Beverages, powder, unsweetened, instant, tea             5714.0
# Beverages, unsweetened, decaffeinated, instant,...        169.0
# Spices, dried, chervil                                      0.0
# Spices, dried, coriander leaf                               0.0
# Celery flakes, dried                                        0.0
# Beverages, powder, regular, instant, coffee              3142.0
# Beverages, half the caffeine, regular, instant,...       1571.0
#
#                                                     theobromine_mg  water_g
# name
# Leavening agents, cream of tartar                              0.0     1.70
# Leavening agents, low-sodium, baking powder                    0.0     6.20
# Parsley, freeze-dried                                          0.0     2.00
# Beverages, powder, unsweetened, instant, tea                  71.0     5.09
# Beverages, unsweetened, decaffeinated, instant,...            11.0     5.09
# Spices, dried, chervil                                         0.0     7.20
# Spices, dried, coriander leaf                                  0.0     7.30
# Celery flakes, dried                                           0.0     9.00
# Beverages, powder, regular, instant, coffee                    0.0     3.10
# Beverages, half the caffeine, regular, instant,...             0.0     3.10
#
# [10 rows x 75 columns]

# %%
# this returns the entire data frame worth of columns, if we just wanted to see th posassium
nutrition.nlargest(10, columns='potassium_mg').potassium_mg
# Out:
# name
# Leavening agents, cream of tartar                         16500.0
# Leavening agents, low-sodium, baking powder               10100.0
# Parsley, freeze-dried                                      6300.0
# Beverages, powder, unsweetened, instant, tea               6040.0
# Beverages, unsweetened, decaffeinated, instant, tea        6040.0
# Spices, dried, chervil                                     4740.0
# Spices, dried, coriander leaf                              4466.0
# Celery flakes, dried                                       4388.0
# Beverages, powder, regular, instant, coffee                3535.0
# Beverages, half the caffeine, regular, instant, coffee     3535.0
# Name: potassium_mg, dtype: float64

# %%
#can also just access the potassium column first
nutrition.potassium_mg.nlargest(10)
# Out:
# name
# Leavening agents, cream of tartar                         16500.0
# Leavening agents, low-sodium, baking powder               10100.0
# Parsley, freeze-dried                                      6300.0
# Beverages, powder, unsweetened, instant, tea               6040.0
# Beverages, unsweetened, decaffeinated, instant, tea        6040.0
# Spices, dried, chervil                                     4740.0
# Spices, dried, coriander leaf                              4466.0
# Celery flakes, dried                                       4388.0
# Beverages, powder, regular, instant, coffee                3535.0
# Beverages, half the caffeine, regular, instant, coffee     3535.0
# Name: potassium_mg, dtype: float64

# %%
# can also sort with in the nlargest and nsmllest methods

nutrition.nsmallest(10, ['sodium_mg', 'calories', 'total_fat_g'])
# Out:
#                                                     serving_size_g  calories  \
# name
# Beverages, well, tap, water                                  100.0       0.0
# Water, NAYA, non-carbonated, bottled                         100.0       0.0
# Beverages, decaffeinated, brewed, green, tea                 100.0       0.0
# Beverages, EVIAN, non-carbonated, bottled, water             100.0       0.0
# Beverages, CALISTOGA, non-carbonated, bottled, ...           100.0       0.0
# Beverages, DANNON, non-carbonated, bottled, water            100.0       0.0
# Sweetener, herbal extract powder from Stevia leaf            100.0       0.0
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...           100.0       0.0
# Babyfood, without added fluoride., GERBER, bott...           100.0       0.0
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...           100.0       0.0
#
#                                                     total_fat_g  \
# name
# Beverages, well, tap, water                                 0.0
# Water, NAYA, non-carbonated, bottled                        0.0
# Beverages, decaffeinated, brewed, green, tea                0.0
# Beverages, EVIAN, non-carbonated, bottled, water            0.0
# Beverages, CALISTOGA, non-carbonated, bottled, ...          0.0
# Beverages, DANNON, non-carbonated, bottled, water           0.0
# Sweetener, herbal extract powder from Stevia leaf           0.0
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...          0.0
# Babyfood, without added fluoride., GERBER, bott...          0.0
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...          0.0
#
#                                                     saturated_fat_g  \
# name
# Beverages, well, tap, water                                     NaN
# Water, NAYA, non-carbonated, bottled                            NaN
# Beverages, decaffeinated, brewed, green, tea                    NaN
# Beverages, EVIAN, non-carbonated, bottled, water                NaN
# Beverages, CALISTOGA, non-carbonated, bottled, ...              NaN
# Beverages, DANNON, non-carbonated, bottled, water               NaN
# Sweetener, herbal extract powder from Stevia leaf               NaN
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...              NaN
# Babyfood, without added fluoride., GERBER, bott...              NaN
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...              NaN
#
#                                                     cholesterol_mg  sodium_mg  \
# name
# Beverages, well, tap, water                                    0.0        0.0
# Water, NAYA, non-carbonated, bottled                           0.0        0.0
# Beverages, decaffeinated, brewed, green, tea                   0.0        0.0
# Beverages, EVIAN, non-carbonated, bottled, water               0.0        0.0
# Beverages, CALISTOGA, non-carbonated, bottled, ...             0.0        0.0
# Beverages, DANNON, non-carbonated, bottled, water              0.0        0.0
# Sweetener, herbal extract powder from Stevia leaf              0.0        0.0
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...             0.0        0.0
# Babyfood, without added fluoride., GERBER, bott...             0.0        0.0
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...             0.0        0.0
#
#                                                     choline_mg  folate_mcg  \
# name
# Beverages, well, tap, water                                0.0         0.0
# Water, NAYA, non-carbonated, bottled                       0.0         0.0
# Beverages, decaffeinated, brewed, green, tea               0.0         0.0
# Beverages, EVIAN, non-carbonated, bottled, water           0.0         0.0
# Beverages, CALISTOGA, non-carbonated, bottled, ...         0.0         0.0
# Beverages, DANNON, non-carbonated, bottled, water          0.0         0.0
# Sweetener, herbal extract powder from Stevia leaf          0.0         0.0
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...         0.0         0.0
# Babyfood, without added fluoride., GERBER, bott...         0.0         0.0
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...         0.0         0.0
#
#                                                     folic_acid_mcg  niacin_mg  \
# name
# Beverages, well, tap, water                                    0.0       0.00
# Water, NAYA, non-carbonated, bottled                           0.0       0.00
# Beverages, decaffeinated, brewed, green, tea                   0.0       0.03
# Beverages, EVIAN, non-carbonated, bottled, water               0.0       0.00
# Beverages, CALISTOGA, non-carbonated, bottled, ...             0.0       0.00
# Beverages, DANNON, non-carbonated, bottled, water              0.0       0.00
# Sweetener, herbal extract powder from Stevia leaf              0.0       0.00
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...             0.0       0.00
# Babyfood, without added fluoride., GERBER, bott...             0.0       0.00
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...             0.0       0.00
#
#                                                     ...  fat_g  \
# name                                                ...
# Beverages, well, tap, water                         ...    0.0
# Water, NAYA, non-carbonated, bottled                ...    0.0
# Beverages, decaffeinated, brewed, green, tea        ...    0.0
# Beverages, EVIAN, non-carbonated, bottled, water    ...    0.0
# Beverages, CALISTOGA, non-carbonated, bottled, ...  ...    0.0
# Beverages, DANNON, non-carbonated, bottled, water   ...    0.0
# Sweetener, herbal extract powder from Stevia leaf   ...    0.0
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...  ...    0.0
# Babyfood, without added fluoride., GERBER, bott...  ...    0.0
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...  ...    0.0
#
#                                                     saturated_fatty_acids_g  \
# name
# Beverages, well, tap, water                                             0.0
# Water, NAYA, non-carbonated, bottled                                    0.0
# Beverages, decaffeinated, brewed, green, tea                            0.0
# Beverages, EVIAN, non-carbonated, bottled, water                        0.0
# Beverages, CALISTOGA, non-carbonated, bottled, ...                      0.0
# Beverages, DANNON, non-carbonated, bottled, water                       0.0
# Sweetener, herbal extract powder from Stevia leaf                       0.0
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...                      0.0
# Babyfood, without added fluoride., GERBER, bott...                      0.0
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...                      0.0
#
#                                                     monounsaturated_fatty_acids_g  \
# name
# Beverages, well, tap, water                                                   0.0
# Water, NAYA, non-carbonated, bottled                                          0.0
# Beverages, decaffeinated, brewed, green, tea                                  0.0
# Beverages, EVIAN, non-carbonated, bottled, water                              0.0
# Beverages, CALISTOGA, non-carbonated, bottled, ...                            0.0
# Beverages, DANNON, non-carbonated, bottled, water                             0.0
# Sweetener, herbal extract powder from Stevia leaf                             0.0
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...                            0.0
# Babyfood, without added fluoride., GERBER, bott...                            0.0
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...                            0.0
#
#                                                     polyunsaturated_fatty_acids_g  \
# name
# Beverages, well, tap, water                                                   0.0
# Water, NAYA, non-carbonated, bottled                                          0.0
# Beverages, decaffeinated, brewed, green, tea                                  0.0
# Beverages, EVIAN, non-carbonated, bottled, water                              0.0
# Beverages, CALISTOGA, non-carbonated, bottled, ...                            0.0
# Beverages, DANNON, non-carbonated, bottled, water                             0.0
# Sweetener, herbal extract powder from Stevia leaf                             0.0
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...                            0.0
# Babyfood, without added fluoride., GERBER, bott...                            0.0
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...                            0.0
#
#                                                     fatty_acids_total_trans_mg  \
# name
# Beverages, well, tap, water                                                0.0
# Water, NAYA, non-carbonated, bottled                                       0.0
# Beverages, decaffeinated, brewed, green, tea                               0.0
# Beverages, EVIAN, non-carbonated, bottled, water                           0.0
# Beverages, CALISTOGA, non-carbonated, bottled, ...                         0.0
# Beverages, DANNON, non-carbonated, bottled, water                          0.0
# Sweetener, herbal extract powder from Stevia leaf                          0.0
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...                         0.0
# Babyfood, without added fluoride., GERBER, bott...                         0.0
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...                         0.0
#
#                                                     alcohol_g  ash_g  \
# name
# Beverages, well, tap, water                               0.0   0.10
# Water, NAYA, non-carbonated, bottled                      0.0   0.10
# Beverages, decaffeinated, brewed, green, tea              0.0   0.00
# Beverages, EVIAN, non-carbonated, bottled, water          0.0   0.05
# Beverages, CALISTOGA, non-carbonated, bottled, ...        0.0   0.10
# Beverages, DANNON, non-carbonated, bottled, water         0.0   0.00
# Sweetener, herbal extract powder from Stevia leaf         0.0   0.00
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...        0.0   0.10
# Babyfood, without added fluoride., GERBER, bott...        0.0   0.00
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...        0.0   0.00
#
#                                                     caffeine_mg  \
# name
# Beverages, well, tap, water                                 0.0
# Water, NAYA, non-carbonated, bottled                        0.0
# Beverages, decaffeinated, brewed, green, tea                0.0
# Beverages, EVIAN, non-carbonated, bottled, water            0.0
# Beverages, CALISTOGA, non-carbonated, bottled, ...          0.0
# Beverages, DANNON, non-carbonated, bottled, water           0.0
# Sweetener, herbal extract powder from Stevia leaf           0.0
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...          0.0
# Babyfood, without added fluoride., GERBER, bott...          0.0
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...          0.0
#
#                                                     theobromine_mg  water_g
# name
# Beverages, well, tap, water                                    0.0    99.90
# Water, NAYA, non-carbonated, bottled                           0.0   100.00
# Beverages, decaffeinated, brewed, green, tea                   0.0    99.93
# Beverages, EVIAN, non-carbonated, bottled, water               0.0    99.97
# Beverages, CALISTOGA, non-carbonated, bottled, ...             0.0   100.00
# Beverages, DANNON, non-carbonated, bottled, water              0.0    99.98
# Sweetener, herbal extract powder from Stevia leaf              0.0     0.00
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...             0.0   100.00
# Babyfood, without added fluoride., GERBER, bott...             0.0    99.90
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...             0.0    99.97
#
# [10 rows x 75 columns]

# %% [markdown]
# # Challenge exercise

# %% [markdown]
# Find the 10 foods that have the most Vitamin B12. What do they have in common?

# %%
nutrition.head(3)
# Out:
#                serving_size_g  calories  total_fat_g  saturated_fat_g  \
# name
# Cornstarch              100.0     381.0          0.1              NaN
# Nuts, pecans            100.0     691.0         72.0              6.2
# Eggplant, raw           100.0      25.0          0.2              NaN
#
#                cholesterol_mg  sodium_mg  choline_mg  folate_mcg  \
# name
# Cornstarch                0.0        9.0         0.4         0.0
# Nuts, pecans              0.0        0.0        40.5        22.0
# Eggplant, raw             0.0        2.0         6.9        22.0
#
#                folic_acid_mcg  niacin_mg  ...  fat_g  saturated_fatty_acids_g  \
# name                                      ...
# Cornstarch                0.0      0.000  ...   0.05                    0.009
# Nuts, pecans              0.0      1.167  ...  71.97                    6.180
# Eggplant, raw             0.0      0.649  ...   0.18                    0.034
#
#                monounsaturated_fatty_acids_g  polyunsaturated_fatty_acids_g  \
# name
# Cornstarch                             0.016                          0.025
# Nuts, pecans                          40.801                         21.614
# Eggplant, raw                          0.016                          0.076
#
#                fatty_acids_total_trans_mg  alcohol_g  ash_g  caffeine_mg  \
# name
# Cornstarch                            0.0        0.0   0.09          0.0
# Nuts, pecans                          0.0        0.0   1.49          0.0
# Eggplant, raw                         0.0        0.0   0.66          0.0
#
#                theobromine_mg  water_g
# name
# Cornstarch                0.0     8.32
# Nuts, pecans              0.0     3.52
# Eggplant, raw             0.0    92.30
#
# [3 rows x 75 columns]

# %%
nutrition.filter(like='vitamin', axis=1).head(3)
# Out:
#                vitamin_a_IU  vitamin_a_rae_mcg  vitamin_b12_mcg  \
# name
# Cornstarch              0.0                0.0              0.0
# Nuts, pecans           56.0                3.0              0.0
# Eggplant, raw          23.0                1.0              0.0
#
#                vitamin_b6_mg  vitamin_c_mg  vitamin_d_IU  vitamin_e_mg  \
# name
# Cornstarch             0.000           0.0           0.0           0.0
# Nuts, pecans           0.210           1.1           0.0           1.4
# Eggplant, raw          0.084           2.2           0.0           0.3
#
#                vitamin_k_mcg
# name
# Cornstarch               0.0
# Nuts, pecans             3.5
# Eggplant, raw            3.5

# %%
nutrition.vitamin_b12_mcg.nlargest(10)
#nutrition.loc[:, vitamin_b12_mcg].nlargest(10)
# Out:
# name
# Mollusks, moist heat, cooked, mixed species, clam                                   98.89
# Beef, boiled, cooked, variety meats and by-products liver, imported, New Zealand    96.00
# Lamb, raw, liver, variety meats and by-products                                     90.05
# Lamb, pan-fried, cooked, liver, variety meats and by-products                       85.70
# Veal, braised, cooked, liver, variety meats and by-products                         84.60
# Beef, raw, liver, variety meats and by-products, imported, New Zealand              84.50
# Beef, pan-fried, cooked, liver, variety meats and by-products                       83.13
# Lamb, braised, cooked, kidneys, variety meats and by-products                       78.90
# Lamb, braised, cooked, liver, variety meats and by-products                         76.50
# Veal, pan-fried, cooked, liver, variety meats and by-products                       72.50
# Name: vitamin_b12_mcg, dtype: float64

# %% [markdown]
# ---
# Isolate the foods in the dataset that contain, or are based on, eggplant. Which of them has the most sodium?

# %%
nutrition.filter(regex='(?i)eggplant', axis=0)
# Out:
#                                                  serving_size_g  calories  \
# name
# Eggplant, raw                                             100.0      25.0
# Eggplant, pickled                                         100.0      49.0
# Eggplant, with salt, drained, boiled, cooked              100.0      33.0
# Eggplant, without salt, drained, boiled, cooked           100.0      35.0
#
#                                                  total_fat_g  saturated_fat_g  \
# name
# Eggplant, raw                                            0.2              NaN
# Eggplant, pickled                                        0.7              0.1
# Eggplant, with salt, drained, boiled, cooked             0.2              NaN
# Eggplant, without salt, drained, boiled, cooked          0.2              NaN
#
#                                                  cholesterol_mg  sodium_mg  \
# name
# Eggplant, raw                                               0.0        2.0
# Eggplant, pickled                                           0.0     1674.0
# Eggplant, with salt, drained, boiled, cooked                0.0      239.0
# Eggplant, without salt, drained, boiled, cooked             0.0        1.0
#
#                                                  choline_mg  folate_mcg  \
# name
# Eggplant, raw                                           6.9        22.0
# Eggplant, pickled                                      11.9        20.0
# Eggplant, with salt, drained, boiled, cooked            9.4        14.0
# Eggplant, without salt, drained, boiled, cooked         9.4        14.0
#
#                                                  folic_acid_mcg  niacin_mg  \
# name
# Eggplant, raw                                               0.0      0.649
# Eggplant, pickled                                           0.0      0.660
# Eggplant, with salt, drained, boiled, cooked                0.0      0.600
# Eggplant, without salt, drained, boiled, cooked             0.0      0.600
#
#                                                  ...  fat_g  \
# name                                             ...
# Eggplant, raw                                    ...   0.18
# Eggplant, pickled                                ...   0.70
# Eggplant, with salt, drained, boiled, cooked     ...   0.23
# Eggplant, without salt, drained, boiled, cooked  ...   0.23
#
#                                                  saturated_fatty_acids_g  \
# name
# Eggplant, raw                                                      0.034
# Eggplant, pickled                                                  0.140
# Eggplant, with salt, drained, boiled, cooked                       0.044
# Eggplant, without salt, drained, boiled, cooked                    0.044
#
#                                                  monounsaturated_fatty_acids_g  \
# name
# Eggplant, raw                                                            0.016
# Eggplant, pickled                                                        0.063
# Eggplant, with salt, drained, boiled, cooked                             0.020
# Eggplant, without salt, drained, boiled, cooked                          0.020
#
#                                                  polyunsaturated_fatty_acids_g  \
# name
# Eggplant, raw                                                            0.076
# Eggplant, pickled                                                        0.294
# Eggplant, with salt, drained, boiled, cooked                             0.093
# Eggplant, without salt, drained, boiled, cooked                          0.093
#
#                                                  fatty_acids_total_trans_mg  \
# name
# Eggplant, raw                                                           0.0
# Eggplant, pickled                                                       0.0
# Eggplant, with salt, drained, boiled, cooked                            0.0
# Eggplant, without salt, drained, boiled, cooked                         0.0
#
#                                                  alcohol_g  ash_g  \
# name
# Eggplant, raw                                          0.0   0.66
# Eggplant, pickled                                      0.0   1.73
# Eggplant, with salt, drained, boiled, cooked           0.0   1.13
# Eggplant, without salt, drained, boiled, cooked        0.0   0.54
#
#                                                  caffeine_mg  theobromine_mg  \
# name
# Eggplant, raw                                            0.0             0.0
# Eggplant, pickled                                        0.0             0.0
# Eggplant, with salt, drained, boiled, cooked             0.0             0.0
# Eggplant, without salt, drained, boiled, cooked          0.0             0.0
#
#                                                  water_g
# name
# Eggplant, raw                                      92.30
# Eggplant, pickled                                  86.90
# Eggplant, with salt, drained, boiled, cooked       89.67
# Eggplant, without salt, drained, boiled, cooked    89.67
#
# [4 rows x 75 columns]

# %%
nutrition.filter(regex='(?i)eggplant', axis=0).sodium_mg.nlargest(1)
# Out:
# name
# Eggplant, pickled    1674.0
# Name: sodium_mg, dtype: float64

# %% [markdown]
# ---
# Select a slice of the dataframe that contains 4 random rows and 2 random columns.

# %%
nutrition.sample(4, axis=0).sample(2, axis=1)
# Out:
#                                                     thiamin_mg  \
# name
# Crackers, reduced fat, cheese                            1.087
# Flan, prepared with whole milk, dry mix, carame...       0.031
# Pancakes, prepared from recipe, blueberry                0.195
# Cheese, cream                                            0.023
#
#                                                     fatty_acids_total_trans_mg
# name
# Crackers, reduced fat, cheese                                              0.0
# Flan, prepared with whole milk, dry mix, carame...                        12.0
# Pancakes, prepared from recipe, blueberry                                 56.0
# Cheese, cream                                                            101.0

# %% [markdown]
# # Challenge Exercise

# %% [markdown]
# Remove all the food items that contain at least one NaN. Do this in a way that modifies the dataframe, i.e. the changes stick.
#
# How many food items remain after the exclusions?

# %%
nutrition_modified = nutrition.dropna()
nutrition_modified
# Out:
#                                                     serving_size_g  calories  \
# name
# Nuts, pecans                                                 100.0     691.0
# Teff, uncooked                                               100.0     367.0
# Sherbet, orange                                              100.0     144.0
# Cauliflower, raw                                             100.0      25.0
# Taro leaves, raw                                             100.0      42.0
# ...                                                            ...       ...
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     125.0
# Lamb, cooked, separable lean only, composite of...           100.0     206.0
# Lamb, raw, separable lean and fat, composite of...           100.0     277.0
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     121.0
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     121.0
#
#                                                     total_fat_g  \
# name
# Nuts, pecans                                               72.0
# Teff, uncooked                                              2.4
# Sherbet, orange                                             2.0
# Cauliflower, raw                                            0.3
# Taro leaves, raw                                            0.7
# ...                                                         ...
# Beef, raw, all grades, trimmed to 0" fat, separ...          3.5
# Lamb, cooked, separable lean only, composite of...          8.9
# Lamb, raw, separable lean and fat, composite of...         23.0
# Beef, raw, all grades, trimmed to 0" fat, separ...          3.0
# Beef, raw, all grades, trimmed to 0" fat, separ...          3.0
#
#                                                     saturated_fat_g  \
# name
# Nuts, pecans                                                    6.2
# Teff, uncooked                                                  0.4
# Sherbet, orange                                                 1.2
# Cauliflower, raw                                                0.1
# Taro leaves, raw                                                0.2
# ...                                                             ...
# Beef, raw, all grades, trimmed to 0" fat, separ...              1.4
# Lamb, cooked, separable lean only, composite of...              3.9
# Lamb, raw, separable lean and fat, composite of...             12.0
# Beef, raw, all grades, trimmed to 0" fat, separ...              1.1
# Beef, raw, all grades, trimmed to 0" fat, separ...              1.1
#
#                                                     cholesterol_mg  sodium_mg  \
# name
# Nuts, pecans                                                   0.0        0.0
# Teff, uncooked                                                 0.0       12.0
# Sherbet, orange                                                1.0       46.0
# Cauliflower, raw                                               0.0       30.0
# Taro leaves, raw                                               0.0        3.0
# ...                                                            ...        ...
# Beef, raw, all grades, trimmed to 0" fat, separ...            62.0       54.0
# Lamb, cooked, separable lean only, composite of...           109.0       50.0
# Lamb, raw, separable lean and fat, composite of...            78.0       39.0
# Beef, raw, all grades, trimmed to 0" fat, separ...            60.0       53.0
# Beef, raw, all grades, trimmed to 0" fat, separ...            60.0       53.0
#
#                                                     choline_mg  folate_mcg  \
# name
# Nuts, pecans                                              40.5        22.0
# Teff, uncooked                                            13.1         0.0
# Sherbet, orange                                            7.7         4.0
# Cauliflower, raw                                          44.3        57.0
# Taro leaves, raw                                          12.8       126.0
# ...                                                        ...         ...
# Beef, raw, all grades, trimmed to 0" fat, separ...        64.5         4.0
# Lamb, cooked, separable lean only, composite of...         0.0         0.0
# Lamb, raw, separable lean and fat, composite of...         0.0         1.0
# Beef, raw, all grades, trimmed to 0" fat, separ...        64.2         4.0
# Beef, raw, all grades, trimmed to 0" fat, separ...        64.2         4.0
#
#                                                     folic_acid_mcg  niacin_mg  \
# name
# Nuts, pecans                                                   0.0      1.167
# Teff, uncooked                                                 0.0      3.363
# Sherbet, orange                                                0.0      0.063
# Cauliflower, raw                                               0.0      0.507
# Taro leaves, raw                                               0.0      1.513
# ...                                                            ...        ...
# Beef, raw, all grades, trimmed to 0" fat, separ...             0.0      6.422
# Lamb, cooked, separable lean only, composite of...             0.0      7.680
# Lamb, raw, separable lean and fat, composite of...             0.0      6.550
# Beef, raw, all grades, trimmed to 0" fat, separ...             0.0      6.720
# Beef, raw, all grades, trimmed to 0" fat, separ...             0.0      6.720
#
#                                                     ...  fat_g  \
# name                                                ...
# Nuts, pecans                                        ...  71.97
# Teff, uncooked                                      ...   2.38
# Sherbet, orange                                     ...   2.00
# Cauliflower, raw                                    ...   0.28
# Taro leaves, raw                                    ...   0.74
# ...                                                 ...    ...
# Beef, raw, all grades, trimmed to 0" fat, separ...  ...   3.50
# Lamb, cooked, separable lean only, composite of...  ...   8.86
# Lamb, raw, separable lean and fat, composite of...  ...  22.74
# Beef, raw, all grades, trimmed to 0" fat, separ...  ...   3.04
# Beef, raw, all grades, trimmed to 0" fat, separ...  ...   3.04
#
#                                                     saturated_fatty_acids_g  \
# name
# Nuts, pecans                                                          6.180
# Teff, uncooked                                                        0.449
# Sherbet, orange                                                       1.160
# Cauliflower, raw                                                      0.130
# Taro leaves, raw                                                      0.151
# ...                                                                     ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                    1.353
# Lamb, cooked, separable lean only, composite of...                    3.860
# Lamb, raw, separable lean and fat, composite of...                   11.570
# Beef, raw, all grades, trimmed to 0" fat, separ...                    1.086
# Beef, raw, all grades, trimmed to 0" fat, separ...                    1.086
#
#                                                     monounsaturated_fatty_acids_g  \
# name
# Nuts, pecans                                                               40.801
# Teff, uncooked                                                              0.589
# Sherbet, orange                                                             0.530
# Cauliflower, raw                                                            0.034
# Taro leaves, raw                                                            0.060
# ...                                                                           ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                          1.554
# Lamb, cooked, separable lean only, composite of...                          3.480
# Lamb, raw, separable lean and fat, composite of...                          8.720
# Beef, raw, all grades, trimmed to 0" fat, separ...                          1.266
# Beef, raw, all grades, trimmed to 0" fat, separ...                          1.266
#
#                                                     polyunsaturated_fatty_acids_g  \
# name
# Nuts, pecans                                                               21.614
# Teff, uncooked                                                              1.071
# Sherbet, orange                                                             0.080
# Cauliflower, raw                                                            0.031
# Taro leaves, raw                                                            0.307
# ...                                                                           ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                          0.244
# Lamb, cooked, separable lean only, composite of...                          0.520
# Lamb, raw, separable lean and fat, composite of...                          0.980
# Beef, raw, all grades, trimmed to 0" fat, separ...                          0.233
# Beef, raw, all grades, trimmed to 0" fat, separ...                          0.233
#
#                                                     fatty_acids_total_trans_mg  \
# name
# Nuts, pecans                                                               0.0
# Teff, uncooked                                                             0.0
# Sherbet, orange                                                            1.0
# Cauliflower, raw                                                           0.0
# Taro leaves, raw                                                           0.0
# ...                                                                        ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                        62.0
# Lamb, cooked, separable lean only, composite of...                       109.0
# Lamb, raw, separable lean and fat, composite of...                        78.0
# Beef, raw, all grades, trimmed to 0" fat, separ...                        60.0
# Beef, raw, all grades, trimmed to 0" fat, separ...                        60.0
#
#                                                     alcohol_g  ash_g  \
# name
# Nuts, pecans                                              0.0   1.49
# Teff, uncooked                                            0.0   2.37
# Sherbet, orange                                           0.0   0.40
# Cauliflower, raw                                          0.0   0.76
# Taro leaves, raw                                          0.0   1.92
# ...                                                       ...    ...
# Beef, raw, all grades, trimmed to 0" fat, separ...        0.0   1.11
# Lamb, cooked, separable lean only, composite of...        0.0   1.60
# Lamb, raw, separable lean and fat, composite of...        0.0   0.92
# Beef, raw, all grades, trimmed to 0" fat, separ...        0.0   1.10
# Beef, raw, all grades, trimmed to 0" fat, separ...        0.0   1.10
#
#                                                     caffeine_mg  \
# name
# Nuts, pecans                                                0.0
# Teff, uncooked                                              0.0
# Sherbet, orange                                             0.0
# Cauliflower, raw                                            0.0
# Taro leaves, raw                                            0.0
# ...                                                         ...
# Beef, raw, all grades, trimmed to 0" fat, separ...          0.0
# Lamb, cooked, separable lean only, composite of...          0.0
# Lamb, raw, separable lean and fat, composite of...          0.0
# Beef, raw, all grades, trimmed to 0" fat, separ...          0.0
# Beef, raw, all grades, trimmed to 0" fat, separ...          0.0
#
#                                                     theobromine_mg  water_g
# name
# Nuts, pecans                                                   0.0     3.52
# Teff, uncooked                                                 0.0     8.82
# Sherbet, orange                                                0.0    66.10
# Cauliflower, raw                                               0.0    92.07
# Taro leaves, raw                                               0.0    85.66
# ...                                                            ...      ...
# Beef, raw, all grades, trimmed to 0" fat, separ...             0.0    72.51
# Lamb, cooked, separable lean only, composite of...             0.0    59.95
# Lamb, raw, separable lean and fat, composite of...             0.0    59.80
# Beef, raw, all grades, trimmed to 0" fat, separ...             0.0    73.43
# Beef, raw, all grades, trimmed to 0" fat, separ...             0.0    73.43
#
# [7199 rows x 75 columns]

# %% [markdown]
# From the remaining records, isolate those that have between 20 and 40 mg of Vitamin C per 100 g serving. Of these foods, which one is the least caloric, i.e. has the minimum calories?

# %%
nutrition_modified.vitamin_c_mg.between(20,40)
# Out:
# name
# Nuts, pecans                                                                                          False
# Teff, uncooked                                                                                        False
# Sherbet, orange                                                                                       False
# Cauliflower, raw                                                                                      False
# Taro leaves, raw                                                                                      False
#                                                                                                       ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    False
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round roast, round    False
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round    False
# Name: vitamin_c_mg, Length: 7199, dtype: bool

# %%
nutrition_modified[nutrition_modified.vitamin_c_mg.between(20,40)]
# Out:
#                                                     serving_size_g  calories  \
# name
# Broccoli, raw, chinese                                       100.0      30.0
# Broccoli raab, cooked                                        100.0      33.0
# Horseradish, prepared                                        100.0      48.0
# Spices, white, pepper                                        100.0     296.0
# Dandelion greens, raw                                        100.0      45.0
# ...                                                            ...       ...
# Beverages, fortified, ready to drink, milk and ...           100.0     101.0
# Cereals ready-to-eat, Peanut Butter, Multi Grai...           100.0     390.0
# Infant formula, with ARA and DHA, ready-to-feed...           100.0      78.0
# Cereals ready-to-eat, KELLOGG'S SMART START Str...           100.0     371.0
# Infant formula, with ARA and DHA, ready-to-feed...           100.0      71.0
#
#                                                     total_fat_g  \
# name
# Broccoli, raw, chinese                                      0.8
# Broccoli raab, cooked                                       0.5
# Horseradish, prepared                                       0.7
# Spices, white, pepper                                       2.1
# Dandelion greens, raw                                       0.7
# ...                                                         ...
# Beverages, fortified, ready to drink, milk and ...          1.7
# Cereals ready-to-eat, Peanut Butter, Multi Grai...          6.2
# Infant formula, with ARA and DHA, ready-to-feed...          4.2
# Cereals ready-to-eat, KELLOGG'S SMART START Str...          1.5
# Infant formula, with ARA and DHA, ready-to-feed...          3.3
#
#                                                     saturated_fat_g  \
# name
# Broccoli, raw, chinese                                          0.1
# Broccoli raab, cooked                                           0.1
# Horseradish, prepared                                           0.1
# Spices, white, pepper                                           0.6
# Dandelion greens, raw                                           0.2
# ...                                                             ...
# Beverages, fortified, ready to drink, milk and ...              0.4
# Cereals ready-to-eat, Peanut Butter, Multi Grai...              0.9
# Infant formula, with ARA and DHA, ready-to-feed...              2.5
# Cereals ready-to-eat, KELLOGG'S SMART START Str...              0.3
# Infant formula, with ARA and DHA, ready-to-feed...              2.1
#
#                                                     cholesterol_mg  sodium_mg  \
# name
# Broccoli, raw, chinese                                         0.0        7.0
# Broccoli raab, cooked                                          0.0       56.0
# Horseradish, prepared                                          0.0      420.0
# Spices, white, pepper                                          0.0        5.0
# Dandelion greens, raw                                          0.0       76.0
# ...                                                            ...        ...
# Beverages, fortified, ready to drink, milk and ...             4.0       63.0
# Cereals ready-to-eat, Peanut Butter, Multi Grai...             0.0      447.0
# Infant formula, with ARA and DHA, ready-to-feed...             2.0       34.0
# Cereals ready-to-eat, KELLOGG'S SMART START Str...             0.0      398.0
# Infant formula, with ARA and DHA, ready-to-feed...             2.0       34.0
#
#                                                     choline_mg  folate_mcg  \
# name
# Broccoli, raw, chinese                                    26.5       104.0
# Broccoli raab, cooked                                     33.6        71.0
# Horseradish, prepared                                      6.5        57.0
# Spices, white, pepper                                      0.0        10.0
# Dandelion greens, raw                                     35.3        27.0
# ...                                                        ...         ...
# Beverages, fortified, ready to drink, milk and ...         1.6        42.0
# Cereals ready-to-eat, Peanut Butter, Multi Grai...         0.0       714.0
# Infant formula, with ARA and DHA, ready-to-feed...         6.0        29.0
# Cereals ready-to-eat, KELLOGG'S SMART START Str...        14.9       800.0
# Infant formula, with ARA and DHA, ready-to-feed...         7.0        29.0
#
#                                                     folic_acid_mcg  niacin_mg  \
# name
# Broccoli, raw, chinese                                         0.0      0.459
# Broccoli raab, cooked                                          0.0      2.015
# Horseradish, prepared                                          0.0      0.386
# Spices, white, pepper                                          0.0      0.212
# Dandelion greens, raw                                          0.0      0.806
# ...                                                            ...        ...
# Beverages, fortified, ready to drink, milk and ...            42.0      1.688
# Cereals ready-to-eat, Peanut Butter, Multi Grai...             0.0     17.890
# Infant formula, with ARA and DHA, ready-to-feed...            29.0      3.902
# Cereals ready-to-eat, KELLOGG'S SMART START Str...           781.0     40.000
# Infant formula, with ARA and DHA, ready-to-feed...            29.0      3.927
#
#                                                     ...  fat_g  \
# name                                                ...
# Broccoli, raw, chinese                              ...   0.76
# Broccoli raab, cooked                               ...   0.52
# Horseradish, prepared                               ...   0.69
# Spices, white, pepper                               ...   2.12
# Dandelion greens, raw                               ...   0.70
# ...                                                 ...    ...
# Beverages, fortified, ready to drink, milk and ...  ...   1.69
# Cereals ready-to-eat, Peanut Butter, Multi Grai...  ...   6.19
# Infant formula, with ARA and DHA, ready-to-feed...  ...   4.24
# Cereals ready-to-eat, KELLOGG'S SMART START Str...  ...   1.50
# Infant formula, with ARA and DHA, ready-to-feed...  ...   3.26
#
#                                                     saturated_fatty_acids_g  \
# name
# Broccoli, raw, chinese                                                0.116
# Broccoli raab, cooked                                                 0.057
# Horseradish, prepared                                                 0.090
# Spices, white, pepper                                                 0.626
# Dandelion greens, raw                                                 0.170
# ...                                                                     ...
# Beverages, fortified, ready to drink, milk and ...                    0.422
# Cereals ready-to-eat, Peanut Butter, Multi Grai...                    0.890
# Infant formula, with ARA and DHA, ready-to-feed...                    2.544
# Cereals ready-to-eat, KELLOGG'S SMART START Str...                    0.300
# Infant formula, with ARA and DHA, ready-to-feed...                    2.120
#
#                                                     monounsaturated_fatty_acids_g  \
# name
# Broccoli, raw, chinese                                                      0.053
# Broccoli raab, cooked                                                       0.030
# Horseradish, prepared                                                       0.130
# Spices, white, pepper                                                       0.789
# Dandelion greens, raw                                                       0.014
# ...                                                                           ...
# Beverages, fortified, ready to drink, milk and ...                          1.154
# Cereals ready-to-eat, Peanut Butter, Multi Grai...                          2.700
# Infant formula, with ARA and DHA, ready-to-feed...                          0.402
# Cereals ready-to-eat, KELLOGG'S SMART START Str...                          0.100
# Infant formula, with ARA and DHA, ready-to-feed...                          0.324
#
#                                                     polyunsaturated_fatty_acids_g  \
# name
# Broccoli, raw, chinese                                                      0.347
# Broccoli raab, cooked                                                       0.150
# Horseradish, prepared                                                       0.339
# Spices, white, pepper                                                       0.616
# Dandelion greens, raw                                                       0.306
# ...                                                                           ...
# Beverages, fortified, ready to drink, milk and ...                          0.057
# Cereals ready-to-eat, Peanut Butter, Multi Grai...                          2.290
# Infant formula, with ARA and DHA, ready-to-feed...                          0.842
# Cereals ready-to-eat, KELLOGG'S SMART START Str...                          0.500
# Infant formula, with ARA and DHA, ready-to-feed...                          0.737
#
#                                                     fatty_acids_total_trans_mg  \
# name
# Broccoli, raw, chinese                                                     0.0
# Broccoli raab, cooked                                                      0.0
# Horseradish, prepared                                                      0.0
# Spices, white, pepper                                                      0.0
# Dandelion greens, raw                                                      0.0
# ...                                                                        ...
# Beverages, fortified, ready to drink, milk and ...                         4.0
# Cereals ready-to-eat, Peanut Butter, Multi Grai...                         0.0
# Infant formula, with ARA and DHA, ready-to-feed...                         2.0
# Cereals ready-to-eat, KELLOGG'S SMART START Str...                         0.0
# Infant formula, with ARA and DHA, ready-to-feed...                         2.0
#
#                                                     alcohol_g  ash_g  \
# name
# Broccoli, raw, chinese                                    0.0   0.83
# Broccoli raab, cooked                                     0.0   1.11
# Horseradish, prepared                                     0.0   1.76
# Spices, white, pepper                                     0.0   1.59
# Dandelion greens, raw                                     0.0   1.80
# ...                                                       ...    ...
# Beverages, fortified, ready to drink, milk and ...        0.0   0.97
# Cereals ready-to-eat, Peanut Butter, Multi Grai...        0.0   3.09
# Infant formula, with ARA and DHA, ready-to-feed...        0.0   0.75
# Cereals ready-to-eat, KELLOGG'S SMART START Str...        0.0   1.70
# Infant formula, with ARA and DHA, ready-to-feed...        0.0   0.60
#
#                                                     caffeine_mg  \
# name
# Broccoli, raw, chinese                                      0.0
# Broccoli raab, cooked                                       0.0
# Horseradish, prepared                                       0.0
# Spices, white, pepper                                       0.0
# Dandelion greens, raw                                       0.0
# ...                                                         ...
# Beverages, fortified, ready to drink, milk and ...          0.0
# Cereals ready-to-eat, Peanut Butter, Multi Grai...          0.0
# Infant formula, with ARA and DHA, ready-to-feed...          0.0
# Cereals ready-to-eat, KELLOGG'S SMART START Str...          0.0
# Infant formula, with ARA and DHA, ready-to-feed...          0.0
#
#                                                     theobromine_mg  water_g
# name
# Broccoli, raw, chinese                                         0.0    92.55
# Broccoli raab, cooked                                          0.0    91.41
# Horseradish, prepared                                          0.0    85.08
# Spices, white, pepper                                          0.0    11.42
# Dandelion greens, raw                                          0.0    85.60
# ...                                                            ...      ...
# Beverages, fortified, ready to drink, milk and ...            13.0    75.82
# Cereals ready-to-eat, Peanut Butter, Multi Grai...             0.0     2.00
# Infant formula, with ARA and DHA, ready-to-feed...             0.0    85.07
# Cereals ready-to-eat, KELLOGG'S SMART START Str...             0.0     2.50
# Infant formula, with ARA and DHA, ready-to-feed...             0.0    85.61
#
# [242 rows x 75 columns]

# %%
nutrition_modified[nutrition_modified.vitamin_c_mg.between(20,40)].calories.nsmallest(1)
# Out:
# name
# Asparagus, with salt, drained, boiled, cooked, frozen    18.0
# Name: calories, dtype: float64

# %% [markdown]
# ---
# How many food items in the dataframe have Vitamin C levels of between 2 and 3 standard deviations (inclusive) above the mean?

# %%
#Mean of vitamin c
m = nutrition_modified.vitamin_c_mg.mean()
m
# Out:
# 5.553368523406029

# %%
# 2 & 3 stdev's above mean
m2sd = m + (nutrition_modified.vitamin_c_mg.mean()*2)
m3sd = m + (nutrition_modified.vitamin_c_mg.mean()*3)

# %%
print(m, m2sd, m3sd)
# Out:
# 5.553368523406029 16.660105570218086 22.213474093624114

# %%
nutrition_modified.vitamin_c_mg.between(m2sd, m3sd)
# Out:
# name
# Nuts, pecans                                                                                          False
# Teff, uncooked                                                                                        False
# Sherbet, orange                                                                                       False
# Cauliflower, raw                                                                                      False
# Taro leaves, raw                                                                                      False
#                                                                                                       ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    False
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round roast, round    False
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round    False
# Name: vitamin_c_mg, Length: 7199, dtype: bool

# %%
nutrition_modified[nutrition_modified.vitamin_c_mg.between(m2sd, m3sd)]
# Out:
#                                                     serving_size_g  calories  \
# name
# Spices, white, pepper                                        100.0     296.0
# Spices, caraway seed                                         100.0     333.0
# Spices, ground, mace                                         100.0     475.0
# Spices, celery seed                                          100.0     392.0
# Spices, fennel seed                                          100.0     345.0
# ...                                                            ...       ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...           100.0     390.0
# Beans, with salt, drained, boiled, cooked, spro...           100.0      78.0
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...           100.0      58.0
# Potatoes, as purchased, frozen, salt not added ...           100.0     150.0
# Beverages,  3-2-1 Plan, ready-to-drink, regular...           100.0      57.0
#
#                                                     total_fat_g  \
# name
# Spices, white, pepper                                       2.1
# Spices, caraway seed                                       15.0
# Spices, ground, mace                                       32.0
# Spices, celery seed                                        25.0
# Spices, fennel seed                                        15.0
# ...                                                         ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...          6.2
# Beans, with salt, drained, boiled, cooked, spro...          0.8
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...          2.9
# Potatoes, as purchased, frozen, salt not added ...          4.7
# Beverages,  3-2-1 Plan, ready-to-drink, regular...          1.9
#
#                                                     saturated_fat_g  \
# name
# Spices, white, pepper                                           0.6
# Spices, caraway seed                                            0.6
# Spices, ground, mace                                            9.5
# Spices, celery seed                                             2.2
# Spices, fennel seed                                             0.5
# ...                                                             ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...              0.9
# Beans, with salt, drained, boiled, cooked, spro...              0.1
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...              0.5
# Potatoes, as purchased, frozen, salt not added ...              0.9
# Beverages,  3-2-1 Plan, ready-to-drink, regular...              0.5
#
#                                                     cholesterol_mg  sodium_mg  \
# name
# Spices, white, pepper                                          0.0        5.0
# Spices, caraway seed                                           0.0       17.0
# Spices, ground, mace                                           0.0       80.0
# Spices, celery seed                                            0.0      160.0
# Spices, fennel seed                                            0.0       88.0
# ...                                                            ...        ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...             0.0      447.0
# Beans, with salt, drained, boiled, cooked, spro...             0.0      250.0
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...             4.0       72.0
# Potatoes, as purchased, frozen, salt not added ...             0.0       23.0
# Beverages,  3-2-1 Plan, ready-to-drink, regular...             3.0       68.0
#
#                                                     choline_mg  folate_mcg  \
# name
# Spices, white, pepper                                      0.0        10.0
# Spices, caraway seed                                      24.7        10.0
# Spices, ground, mace                                       0.0        76.0
# Spices, celery seed                                       24.7        10.0
# Spices, fennel seed                                        0.0         0.0
# ...                                                        ...         ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...         0.0       714.0
# Beans, with salt, drained, boiled, cooked, spro...         0.0       106.0
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...         0.0        39.0
# Potatoes, as purchased, frozen, salt not added ...         0.0        35.0
# Beverages,  3-2-1 Plan, ready-to-drink, regular...        14.8        39.0
#
#                                                     folic_acid_mcg  niacin_mg  \
# name
# Spices, white, pepper                                          0.0      0.212
# Spices, caraway seed                                           0.0      3.606
# Spices, ground, mace                                           0.0      1.350
# Spices, celery seed                                            0.0      3.060
# Spices, fennel seed                                            0.0      6.050
# ...                                                            ...        ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...             0.0     17.890
# Beans, with salt, drained, boiled, cooked, spro...             0.0      1.263
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...            41.0      2.390
# Potatoes, as purchased, frozen, salt not added ...             0.0      2.038
# Beverages,  3-2-1 Plan, ready-to-drink, regular...            39.0      2.260
#
#                                                     ...  fat_g  \
# name                                                ...
# Spices, white, pepper                               ...   2.12
# Spices, caraway seed                                ...  14.59
# Spices, ground, mace                                ...  32.38
# Spices, celery seed                                 ...  25.27
# Spices, fennel seed                                 ...  14.87
# ...                                                 ...    ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...  ...   6.19
# Beans, with salt, drained, boiled, cooked, spro...  ...   0.81
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...  ...   2.88
# Potatoes, as purchased, frozen, salt not added ...  ...   4.66
# Beverages,  3-2-1 Plan, ready-to-drink, regular...  ...   1.93
#
#                                                     saturated_fatty_acids_g  \
# name
# Spices, white, pepper                                                 0.626
# Spices, caraway seed                                                  0.620
# Spices, ground, mace                                                  9.510
# Spices, celery seed                                                   2.190
# Spices, fennel seed                                                   0.480
# ...                                                                     ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...                    0.890
# Beans, with salt, drained, boiled, cooked, spro...                    0.098
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...                    0.450
# Potatoes, as purchased, frozen, salt not added ...                    0.940
# Beverages,  3-2-1 Plan, ready-to-drink, regular...                    0.540
#
#                                                     monounsaturated_fatty_acids_g  \
# name
# Spices, white, pepper                                                       0.789
# Spices, caraway seed                                                        7.125
# Spices, ground, mace                                                       11.170
# Spices, celery seed                                                        15.930
# Spices, fennel seed                                                         9.910
# ...                                                                           ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...                          2.700
# Beans, with salt, drained, boiled, cooked, spro...                          0.060
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...                          2.100
# Potatoes, as purchased, frozen, salt not added ...                          2.960
# Beverages,  3-2-1 Plan, ready-to-drink, regular...                          0.970
#
#                                                     polyunsaturated_fatty_acids_g  \
# name
# Spices, white, pepper                                                       0.616
# Spices, caraway seed                                                        3.272
# Spices, ground, mace                                                        4.390
# Spices, celery seed                                                         3.720
# Spices, fennel seed                                                         1.690
# ...                                                                           ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...                          2.290
# Beans, with salt, drained, boiled, cooked, spro...                          0.468
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...                          0.290
# Potatoes, as purchased, frozen, salt not added ...                          0.265
# Beverages,  3-2-1 Plan, ready-to-drink, regular...                          0.320
#
#                                                     fatty_acids_total_trans_mg  \
# name
# Spices, white, pepper                                                      0.0
# Spices, caraway seed                                                       0.0
# Spices, ground, mace                                                       0.0
# Spices, celery seed                                                        0.0
# Spices, fennel seed                                                        0.0
# ...                                                                        ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...                         0.0
# Beans, with salt, drained, boiled, cooked, spro...                         0.0
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...                         4.0
# Potatoes, as purchased, frozen, salt not added ...                         0.0
# Beverages,  3-2-1 Plan, ready-to-drink, regular...                         3.0
#
#                                                     alcohol_g  ash_g  \
# name
# Spices, white, pepper                                     0.0   1.59
# Spices, caraway seed                                      0.0   5.87
# Spices, ground, mace                                      0.0   2.23
# Spices, celery seed                                       0.0   9.27
# Spices, fennel seed                                       0.0   8.22
# ...                                                       ...    ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...        0.0   3.09
# Beans, with salt, drained, boiled, cooked, spro...        0.0   1.09
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...        0.0   0.61
# Potatoes, as purchased, frozen, salt not added ...        0.0   1.68
# Beverages,  3-2-1 Plan, ready-to-drink, regular...        0.0   0.86
#
#                                                     caffeine_mg  \
# name
# Spices, white, pepper                                       0.0
# Spices, caraway seed                                        0.0
# Spices, ground, mace                                        0.0
# Spices, celery seed                                         0.0
# Spices, fennel seed                                         0.0
# ...                                                         ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...          0.0
# Beans, with salt, drained, boiled, cooked, spro...          0.0
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...          0.0
# Potatoes, as purchased, frozen, salt not added ...          0.0
# Beverages,  3-2-1 Plan, ready-to-drink, regular...          0.0
#
#                                                     theobromine_mg  water_g
# name
# Spices, white, pepper                                          0.0    11.42
# Spices, caraway seed                                           0.0     9.87
# Spices, ground, mace                                           0.0     8.17
# Spices, celery seed                                            0.0     6.04
# Spices, fennel seed                                            0.0     8.81
# ...                                                            ...      ...
# Cereals ready-to-eat, Peanut Butter, Multi Grai...             0.0     2.00
# Beans, with salt, drained, boiled, cooked, spro...             0.0    76.02
# Beverages, 3-2-1 plan, Ready-To-Drink,  High Pr...             0.0    88.33
# Potatoes, as purchased, frozen, salt not added ...             0.0    66.61
# Beverages,  3-2-1 Plan, ready-to-drink, regular...             0.0    85.69
#
# [146 rows x 75 columns]

# %%
results = nutrition_modified[nutrition_modified.vitamin_c_mg.between(m2sd, m3sd)]
results.describe()
# Out:
#        serving_size_g    calories  total_fat_g  saturated_fat_g  \
# count           146.0  146.000000   146.000000       146.000000
# mean            100.0  251.815068     5.301370         1.147260
# std               0.0  148.630020     6.698667         1.821905
# min             100.0   17.000000     0.200000         0.100000
# 25%             100.0   91.250000     0.700000         0.100000
# 50%             100.0  308.000000     3.350000         0.600000
# 75%             100.0  385.750000     5.850000         1.000000
# max             100.0  532.000000    34.000000         9.700000
#
#        cholesterol_mg    sodium_mg  choline_mg   folate_mcg  folic_acid_mcg  \
# count      146.000000   146.000000  146.000000   146.000000      146.000000
# mean        14.041096   329.609589   12.006849   268.212329      197.171233
# std         58.909384   284.029779   19.955812   296.868047      291.280321
# min          0.000000     0.000000    0.000000     0.000000        0.000000
# 25%          0.000000    37.250000    0.000000    24.500000        0.000000
# 50%          0.000000   302.000000    7.550000   107.500000        0.000000
# 75%          0.000000   537.500000   15.975000   373.750000      337.000000
# max        400.000000  1202.000000  194.400000  1333.000000     1292.000000
#
#         niacin_mg  ...       fat_g  saturated_fatty_acids_g  \
# count  146.000000  ...  146.000000               146.000000
# mean     8.662021  ...    5.299521                 1.146630
# std      8.270251  ...    6.717493                 1.824336
# min      0.000000  ...    0.150000                 0.050000
# 25%      1.184000  ...    0.707500                 0.143750
# 50%      3.503000  ...    3.360000                 0.600000
# 75%     16.700000  ...    5.820000                 1.003750
# max     37.000000  ...   33.980000                 9.684000
#
#        monounsaturated_fatty_acids_g  polyunsaturated_fatty_acids_g  \
# count                     146.000000                     146.000000
# mean                        2.259541                       1.258144
# std                         3.421132                       1.441806
# min                         0.000000                       0.000000
# 25%                         0.092500                       0.200000
# 50%                         1.024000                       0.715000
# 75%                         2.354500                       1.697500
# max                        18.963000                       8.282000
#
#        fatty_acids_total_trans_mg  alcohol_g       ash_g  caffeine_mg  \
# count                  146.000000      146.0  146.000000   146.000000
# mean                    14.041096        0.0    2.585342     0.253425
# std                     58.909384        0.0    1.760547     1.274750
# min                      0.000000        0.0    0.000000     0.000000
# 25%                      0.000000        0.0    1.065000     0.000000
# 50%                      0.000000        0.0    2.400000     0.000000
# 75%                      0.000000        0.0    3.692500     0.000000
# max                    400.000000        0.0    9.270000    11.000000
#
#        theobromine_mg     water_g
# count      146.000000  146.000000
# mean         4.609589   36.779110
# std         24.411804   37.463868
# min          0.000000    1.200000
# 25%          0.000000    2.522500
# 50%          0.000000    8.835000
# 75%          0.000000   76.275000
# max        198.000000   94.790000
#
# [8 rows x 75 columns]

# %%
results.vitamin_c_mg.describe()
# Out:
# count    146.000000
# mean      19.714384
# std        1.572084
# min       16.700000
# 25%       18.400000
# 50%       20.000000
# 75%       21.000000
# max       22.200000
# Name: vitamin_c_mg, dtype: float64
