# %%
import pandas as pd
import numpy as np
import datetime
from openbb_terminal.sdk import openbb

# %%
# define start and end for the range to pull data

# end date is going to be today
end = datetime.datetime.now()

# start is going to be how far back to go, here we use 10 years
start = end - datetime.timedelta(days=365*10)

aapl = openbb.stocks.load('AAPL', start_date=start, end_date=end)
aapl
# Out:
# Loading Daily data for AAPL with starting period 2013-12-02.
#                   Open        High         Low       Close   Adj Close  \
# date
# 2013-12-02   17.471210   17.669404   17.246402   17.259239   17.259239
# 2013-12-03   17.480603   17.733592   17.461191   17.731712   17.731712
# 2013-12-04   17.706033   17.821569   17.559500   17.690378   17.690378
# 2013-12-05   17.929906   18.007869   17.734530   17.781181   17.781181
# 2013-12-06   17.715120   17.745178   17.520370   17.534458   17.534458
# ...                ...         ...         ...         ...         ...
# 2023-11-24  190.869995  190.899994  189.250000  189.970001  189.970001
# 2023-11-27  189.919998  190.669998  188.899994  189.789993  189.789993
# 2023-11-28  189.779999  191.080002  189.399994  190.399994  190.399994
# 2023-11-29  190.899994  192.089996  188.970001  189.369995  189.369995
# 2023-11-30  189.839996  190.320007  188.190002  188.470001  188.470001
#
#                Volume  Dividends  Stock Splits
# date
# 2013-12-02  472544800        0.0           0.0
# 2013-12-03  450968000        0.0           0.0
# 2013-12-04  377809600        0.0           0.0
# 2013-12-05  447580000        0.0           0.0
# 2013-12-06  344352400        0.0           0.0
# ...               ...        ...           ...
# 2023-11-24   24048300        0.0           0.0
# 2023-11-27   40552600        0.0           0.0
# 2023-11-28   38415400        0.0           0.0
# 2023-11-29   42967700        0.0           0.0
# 2023-11-30   20363072        0.0           0.0
#
# [2517 rows x 8 columns]

# %%
#drop dividends and splits & reset the index
aapl_df = aapl.copy()
aapl_df = aapl_df.drop(columns=['Dividends', 'Stock Splits']).reset_index()
aapl_df
# Out:
#            date        Open        High         Low       Close   Adj Close  \
# 0    2013-12-02   17.471210   17.669404   17.246402   17.259239   17.259239
# 1    2013-12-03   17.480603   17.733592   17.461191   17.731712   17.731712
# 2    2013-12-04   17.706033   17.821569   17.559500   17.690378   17.690378
# 3    2013-12-05   17.929906   18.007869   17.734530   17.781181   17.781181
# 4    2013-12-06   17.715120   17.745178   17.520370   17.534458   17.534458
# ...         ...         ...         ...         ...         ...         ...
# 2512 2023-11-24  190.869995  190.899994  189.250000  189.970001  189.970001
# 2513 2023-11-27  189.919998  190.669998  188.899994  189.789993  189.789993
# 2514 2023-11-28  189.779999  191.080002  189.399994  190.399994  190.399994
# 2515 2023-11-29  190.899994  192.089996  188.970001  189.369995  189.369995
# 2516 2023-11-30  189.839996  190.320007  188.190002  188.470001  188.470001
#
#          Volume
# 0     472544800
# 1     450968000
# 2     377809600
# 3     447580000
# 4     344352400
# ...         ...
# 2512   24048300
# 2513   40552600
# 2514   38415400
# 2515   42967700
# 2516   20363072
#
# [2517 rows x 7 columns]

# %%
# take a quick look at the daily closing price over the timeframe selected

aapl_df.plot(kind='line',
             x='date',
             y='Close'
            
            )
# Out:
# <AxesSubplot: xlabel='date'>

# %% [markdown]
# ---
# ## Add features

# %%
# Look at the distance from the SMA's in PERCENTAGE terms to aleviate any concern with a specific price value (round # for ex)

for ma in [10, 20, 30, 50, 100]:
    aapl_df[f'feat_dist_from_ma_{ma}'] = aapl_df['Close'] / aapl_df['Close'].rolling(ma).mean()-1
    
# Calculating the Distance from the Moving Average:

# This part of the code calculates how far (in percentage terms) the current closing price is from the moving average 
# The current 'Close' price is divided by the moving average of the 'Close' price. 
# Subtracting 1 from this quotient converts the ratio into a percentage difference. 
# A result of 0 indicates that the current price is exactly at the moving average, a positive value indicates the current price is above 
# the moving average, and a negative value indicates it's below.

# %%
aapl_df
# Out:
#            date        Open        High         Low       Close   Adj Close  \
# 0    2013-12-02   17.471210   17.669404   17.246402   17.259239   17.259239
# 1    2013-12-03   17.480603   17.733592   17.461191   17.731712   17.731712
# 2    2013-12-04   17.706033   17.821569   17.559500   17.690378   17.690378
# 3    2013-12-05   17.929906   18.007869   17.734530   17.781181   17.781181
# 4    2013-12-06   17.715120   17.745178   17.520370   17.534458   17.534458
# ...         ...         ...         ...         ...         ...         ...
# 2512 2023-11-24  190.869995  190.899994  189.250000  189.970001  189.970001
# 2513 2023-11-27  189.919998  190.669998  188.899994  189.789993  189.789993
# 2514 2023-11-28  189.779999  191.080002  189.399994  190.399994  190.399994
# 2515 2023-11-29  190.899994  192.089996  188.970001  189.369995  189.369995
# 2516 2023-11-30  189.839996  190.320007  188.190002  188.470001  188.470001
#
#          Volume  feat_dist_from_ma_10  feat_dist_from_ma_20  \
# 0     472544800                   NaN                   NaN
# 1     450968000                   NaN                   NaN
# 2     377809600                   NaN                   NaN
# 3     447580000                   NaN                   NaN
# 4     344352400                   NaN                   NaN
# ...         ...                   ...                   ...
# 2512   24048300              0.005441              0.040669
# 2513   40552600              0.002689              0.033515
# 2514   38415400              0.002945              0.031127
# 2515   42967700             -0.003494              0.020348
# 2516   20363072             -0.008470              0.011485
#
#       feat_dist_from_ma_30  feat_dist_from_ma_50  feat_dist_from_ma_100
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2512              0.056963              0.067959               0.047935
# 2513              0.053778              0.065149               0.047029
# 2514              0.054839              0.067056               0.050381
# 2515              0.046725              0.060031               0.044626
# 2516              0.039288              0.053436               0.039610
#
# [2517 rows x 12 columns]

# %%
# Look at the distance from the rolling daily high & low

for mm in [3, 5, 10, 15, 30, 50, 100]:  # so 3 would be the rolling 3 day high and low
    aapl_df[f'feat_dist_from_high_{mm}'] = aapl_df['Close'] / aapl_df['High'].rolling(mm).max()-1
    aapl_df[f'feat_dist_from_low_{mm}'] = aapl_df['Close'] / aapl_df['Low'].rolling(mm).min()-1

# Calculating the Distance from the rolling high and low price:

# This part of the code calculates how far (in percentage terms) the current closing price is from the rolling high&low 
# The current 'Close' price is divided by the rolling high/low. 
# Subtracting 1 from this quotient converts the ratio into a percentage difference. 
# A result of 0 indicates that the current price is exactly at the high/low, a positive value indicates the current price is above 
# the high/low, and a negative value indicates it's below.    
    
    
aapl_df
# Out:
#            date        Open        High         Low       Close   Adj Close  \
# 0    2013-12-02   17.471210   17.669404   17.246402   17.259239   17.259239
# 1    2013-12-03   17.480603   17.733592   17.461191   17.731712   17.731712
# 2    2013-12-04   17.706033   17.821569   17.559500   17.690378   17.690378
# 3    2013-12-05   17.929906   18.007869   17.734530   17.781181   17.781181
# 4    2013-12-06   17.715120   17.745178   17.520370   17.534458   17.534458
# ...         ...         ...         ...         ...         ...         ...
# 2512 2023-11-24  190.869995  190.899994  189.250000  189.970001  189.970001
# 2513 2023-11-27  189.919998  190.669998  188.899994  189.789993  189.789993
# 2514 2023-11-28  189.779999  191.080002  189.399994  190.399994  190.399994
# 2515 2023-11-29  190.899994  192.089996  188.970001  189.369995  189.369995
# 2516 2023-11-30  189.839996  190.320007  188.190002  188.470001  188.470001
#
#          Volume  feat_dist_from_ma_10  feat_dist_from_ma_20  \
# 0     472544800                   NaN                   NaN
# 1     450968000                   NaN                   NaN
# 2     377809600                   NaN                   NaN
# 3     447580000                   NaN                   NaN
# 4     344352400                   NaN                   NaN
# ...         ...                   ...                   ...
# 2512   24048300              0.005441              0.040669
# 2513   40552600              0.002689              0.033515
# 2514   38415400              0.002945              0.031127
# 2515   42967700             -0.003494              0.020348
# 2516   20363072             -0.008470              0.011485
#
#       feat_dist_from_ma_30  ...  feat_dist_from_high_10  \
# 0                      NaN  ...                     NaN
# 1                      NaN  ...                     NaN
# 2                      NaN  ...                     NaN
# 3                      NaN  ...                     NaN
# 4                      NaN  ...                     NaN
# ...                    ...  ...                     ...
# 2512              0.056963  ...               -0.015342
# 2513              0.053778  ...               -0.016275
# 2514              0.054839  ...               -0.013114
# 2515              0.046725  ...               -0.018452
# 2516              0.039288  ...               -0.023117
#
#       feat_dist_from_low_10  feat_dist_from_high_15  feat_dist_from_low_15  \
# 0                       NaN                     NaN                    NaN
# 1                       NaN                     NaN                    NaN
# 2                       NaN                     NaN                    NaN
# 3                       NaN                     NaN                    NaN
# 4                       NaN                     NaN                    NaN
# ...                     ...                     ...                    ...
# 2512               0.035090               -0.015342               0.097319
# 2513               0.030291               -0.016275               0.078486
# 2514               0.022007               -0.013114               0.065267
# 2515               0.008467               -0.018452               0.044218
# 2516               0.001488               -0.023117               0.037997
#
#       feat_dist_from_high_30  feat_dist_from_low_30  feat_dist_from_high_50  \
# 0                        NaN                    NaN                     NaN
# 1                        NaN                    NaN                     NaN
# 2                        NaN                    NaN                     NaN
# 3                        NaN                    NaN                     NaN
# 4                        NaN                    NaN                     NaN
# ...                      ...                    ...                     ...
# 2512               -0.015342               0.148188               -0.015342
# 2513               -0.016275               0.147100               -0.016275
# 2514               -0.013114               0.150787               -0.013114
# 2515               -0.018452               0.144561               -0.018452
# 2516               -0.023117               0.139122               -0.023117
#
#       feat_dist_from_low_50  feat_dist_from_high_100  feat_dist_from_low_100
# 0                       NaN                      NaN                     NaN
# 1                       NaN                      NaN                     NaN
# 2                       NaN                      NaN                     NaN
# 3                       NaN                      NaN                     NaN
# 4                       NaN                      NaN                     NaN
# ...                     ...                      ...                     ...
# 2512               0.148188                -0.039110                0.148188
# 2513               0.147100                -0.040021                0.147100
# 2514               0.150787                -0.036935                0.150787
# 2515               0.144561                -0.042145                0.144561
# 2516               0.139122                -0.046698                0.139122
#
# [2517 rows x 26 columns]

# %%
# price distance from a defined period --> time delay

for d in [1, 2, 3, 4, 5, 10, 15, 20, 30, 50, 100]:
    aapl_df[f'feat_price_distance_{d}'] = aapl_df['Close'] / aapl_df['Close'].shift(d)-1
    
    
# This loop iterates over a list of integers, each representing a different time delay (in days) for comparing the 'Close' prices.
# .shift(d): This function shifts the 'Close' prices down by d positions (or d days). 
# This means that for each row, it fetches the 'Close' price from d days ago. 
# For example, when d is 1, it will fetch the previous day's closing price for each row.
# So you can look at todays close as compared to what is was 1, 2, 3 ... days ago

aapl_df
# Out:
#            date        Open        High         Low       Close   Adj Close  \
# 0    2013-12-02   17.471210   17.669404   17.246402   17.259239   17.259239
# 1    2013-12-03   17.480603   17.733592   17.461191   17.731712   17.731712
# 2    2013-12-04   17.706033   17.821569   17.559500   17.690378   17.690378
# 3    2013-12-05   17.929906   18.007869   17.734530   17.781181   17.781181
# 4    2013-12-06   17.715120   17.745178   17.520370   17.534458   17.534458
# ...         ...         ...         ...         ...         ...         ...
# 2512 2023-11-24  190.869995  190.899994  189.250000  189.970001  189.970001
# 2513 2023-11-27  189.919998  190.669998  188.899994  189.789993  189.789993
# 2514 2023-11-28  189.779999  191.080002  189.399994  190.399994  190.399994
# 2515 2023-11-29  190.899994  192.089996  188.970001  189.369995  189.369995
# 2516 2023-11-30  189.839996  190.320007  188.190002  188.470001  188.470001
#
#          Volume  feat_dist_from_ma_10  feat_dist_from_ma_20  \
# 0     472544800                   NaN                   NaN
# 1     450968000                   NaN                   NaN
# 2     377809600                   NaN                   NaN
# 3     447580000                   NaN                   NaN
# 4     344352400                   NaN                   NaN
# ...         ...                   ...                   ...
# 2512   24048300              0.005441              0.040669
# 2513   40552600              0.002689              0.033515
# 2514   38415400              0.002945              0.031127
# 2515   42967700             -0.003494              0.020348
# 2516   20363072             -0.008470              0.011485
#
#       feat_dist_from_ma_30  ...  feat_price_distance_2  feat_price_distance_3  \
# 0                      NaN  ...                    NaN                    NaN
# 1                      NaN  ...                    NaN                    NaN
# 2                      NaN  ...               0.024980                    NaN
# 3                      NaN  ...               0.002790               0.030241
# 4                      NaN  ...              -0.008814              -0.011124
# ...                    ...  ...                    ...                    ...
# 2512              0.056963  ...              -0.003514              -0.007730
# 2513              0.053778  ...              -0.007945              -0.004459
# 2514              0.054839  ...               0.002263              -0.004757
# 2515              0.046725  ...              -0.002213              -0.003158
# 2516              0.039288  ...              -0.010137              -0.006955
#
#       feat_price_distance_4  feat_price_distance_5  feat_price_distance_10  \
# 0                       NaN                    NaN                     NaN
# 1                       NaN                    NaN                     NaN
# 2                       NaN                    NaN                     NaN
# 3                       NaN                    NaN                     NaN
# 4                  0.015946                    NaN                     NaN
# ...                     ...                    ...                     ...
# 2512               0.001476               0.001370                0.042817
# 2513              -0.008671               0.000527                0.018187
# 2514              -0.001259              -0.005484                0.030303
# 2515              -0.010141              -0.006662                0.010297
# 2516              -0.007896              -0.014845                0.002447
#
#       feat_price_distance_15  feat_price_distance_20  feat_price_distance_30  \
# 0                        NaN                     NaN                     NaN
# 1                        NaN                     NaN                     NaN
# 2                        NaN                     NaN                     NaN
# 3                        NaN                     NaN                     NaN
# 4                        NaN                     NaN                     NaN
# ...                      ...                     ...                     ...
# 2512                0.071241                0.139794                0.052627
# 2513                0.075800                0.129711                0.062567
# 2514                0.063722                0.119566                0.066757
# 2515                0.042897                0.110379                0.070389
# 2516                0.031868                0.084775                0.073239
#
#       feat_price_distance_50  feat_price_distance_100
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2512                0.082396                -0.004458
# 2513                0.085881                -0.007890
# 2514                0.071253                 0.001197
# 2515                0.058913                 0.006710
# 2516                0.075379                 0.004749
#
# [2517 rows x 37 columns]

# %% [markdown]
# ## Using %chg (the -1) keeps features generic over time scales

# %% [markdown]
# ---
# ## Target
# * predict if above the 20SMA in 5 days

# %%
# define the 20 SMA col
aapl_df['target_sma'] = aapl_df['Close'].rolling(20).mean()

# define if the close is above the 20ma col --> bool value
aapl_df['price_above_ma'] = aapl_df['Close'] > aapl_df['target_sma']

# define the target col for 5 days from now
# this brings the T or F up 5 rows (5 days) and gives a values of 0 or 1
aapl_df['target'] = aapl_df['price_above_ma'].astype(int).shift(-5)

aapl_df
# Out:
#            date        Open        High         Low       Close   Adj Close  \
# 0    2013-12-02   17.471210   17.669404   17.246402   17.259239   17.259239
# 1    2013-12-03   17.480603   17.733592   17.461191   17.731712   17.731712
# 2    2013-12-04   17.706033   17.821569   17.559500   17.690378   17.690378
# 3    2013-12-05   17.929906   18.007869   17.734530   17.781181   17.781181
# 4    2013-12-06   17.715120   17.745178   17.520370   17.534458   17.534458
# ...         ...         ...         ...         ...         ...         ...
# 2512 2023-11-24  190.869995  190.899994  189.250000  189.970001  189.970001
# 2513 2023-11-27  189.919998  190.669998  188.899994  189.789993  189.789993
# 2514 2023-11-28  189.779999  191.080002  189.399994  190.399994  190.399994
# 2515 2023-11-29  190.899994  192.089996  188.970001  189.369995  189.369995
# 2516 2023-11-30  189.839996  190.320007  188.190002  188.470001  188.470001
#
#          Volume  feat_dist_from_ma_10  feat_dist_from_ma_20  \
# 0     472544800                   NaN                   NaN
# 1     450968000                   NaN                   NaN
# 2     377809600                   NaN                   NaN
# 3     447580000                   NaN                   NaN
# 4     344352400                   NaN                   NaN
# ...         ...                   ...                   ...
# 2512   24048300              0.005441              0.040669
# 2513   40552600              0.002689              0.033515
# 2514   38415400              0.002945              0.031127
# 2515   42967700             -0.003494              0.020348
# 2516   20363072             -0.008470              0.011485
#
#       feat_dist_from_ma_30  ...  feat_price_distance_5  \
# 0                      NaN  ...                    NaN
# 1                      NaN  ...                    NaN
# 2                      NaN  ...                    NaN
# 3                      NaN  ...                    NaN
# 4                      NaN  ...                    NaN
# ...                    ...  ...                    ...
# 2512              0.056963  ...               0.001370
# 2513              0.053778  ...               0.000527
# 2514              0.054839  ...              -0.005484
# 2515              0.046725  ...              -0.006662
# 2516              0.039288  ...              -0.014845
#
#       feat_price_distance_10  feat_price_distance_15  feat_price_distance_20  \
# 0                        NaN                     NaN                     NaN
# 1                        NaN                     NaN                     NaN
# 2                        NaN                     NaN                     NaN
# 3                        NaN                     NaN                     NaN
# 4                        NaN                     NaN                     NaN
# ...                      ...                     ...                     ...
# 2512                0.042817                0.071241                0.139794
# 2513                0.018187                0.075800                0.129711
# 2514                0.030303                0.063722                0.119566
# 2515                0.010297                0.042897                0.110379
# 2516                0.002447                0.031868                0.084775
#
#       feat_price_distance_30  feat_price_distance_50  feat_price_distance_100  \
# 0                        NaN                     NaN                      NaN
# 1                        NaN                     NaN                      NaN
# 2                        NaN                     NaN                      NaN
# 3                        NaN                     NaN                      NaN
# 4                        NaN                     NaN                      NaN
# ...                      ...                     ...                      ...
# 2512                0.052627                0.082396                -0.004458
# 2513                0.062567                0.085881                -0.007890
# 2514                0.066757                0.071253                 0.001197
# 2515                0.070389                0.058913                 0.006710
# 2516                0.073239                0.075379                 0.004749
#
#       target_sma  price_above_ma  target
# 0            NaN           False     0.0
# 1            NaN           False     0.0
# 2            NaN           False     0.0
# 3            NaN           False     0.0
# 4            NaN           False     0.0
# ...          ...             ...     ...
# 2512  182.545966            True     NaN
# 2513  183.635532            True     NaN
# 2514  184.652235            True     NaN
# 2515  185.593468            True     NaN
# 2516  186.329913            True     NaN
#
# [2517 rows x 40 columns]

# %% [markdown]
# ---
# ## Clean up the df for ML prep
# ## Define the train and test
# * note for time series its better to split on a given date

# %%
aapl_df = aapl_df.copy()

# %%
# Drop nulls
aapl_df = aapl_df.dropna()

# %%
# Define feature columns
feat_cols = [col for col in aapl_df.columns if 'feat' in col]

#uses list comp to id all the columns with 'feat' in them
#generic form of list comp:
    # new_lsit = [some_expression for item in iterable if some_condition]

feat_cols
# Out:
# ['feat_dist_from_ma_10',
#  'feat_dist_from_ma_20',
#  'feat_dist_from_ma_30',
#  'feat_dist_from_ma_50',
#  'feat_dist_from_ma_100',
#  'feat_dist_from_high_3',
#  'feat_dist_from_low_3',
#  'feat_dist_from_high_5',
#  'feat_dist_from_low_5',
#  'feat_dist_from_high_10',
#  'feat_dist_from_low_10',
#  'feat_dist_from_high_15',
#  'feat_dist_from_low_15',
#  'feat_dist_from_high_30',
#  'feat_dist_from_low_30',
#  'feat_dist_from_high_50',
#  'feat_dist_from_low_50',
#  'feat_dist_from_high_100',
#  'feat_dist_from_low_100',
#  'feat_price_distance_1',
#  'feat_price_distance_2',
#  'feat_price_distance_3',
#  'feat_price_distance_4',
#  'feat_price_distance_5',
#  'feat_price_distance_10',
#  'feat_price_distance_15',
#  'feat_price_distance_20',
#  'feat_price_distance_30',
#  'feat_price_distance_50',
#  'feat_price_distance_100']

# %% [markdown]
# ### Training data definition

# %%
# Recall we previously defined start as now - 10 years, now we can add to that how many years of training data we want
train_until = start + datetime.timedelta(days=365*7)
train_until
# Out:
# datetime.datetime(2020, 11, 30, 13, 47, 13, 810462)
